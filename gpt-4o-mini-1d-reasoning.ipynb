# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/csqa-pairs-baselines/QA_Mixed.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_NEITHER_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_NEITHER.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_OR_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_AND.csv
# /kaggle/input/csqa-pairs-baselines/__huggingface_repos__.json
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_MIXED_results.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_AND_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_OR.csv
# /kaggle/input/csqa-pairs-baselines/logical_combinations_output.csv
# /kaggle/input/csqa-dataset/csqa_second_stage-5000.csv

# %%
qa_df = pd.read_csv('/kaggle/input/csqa-pairs-baselines/QA_AND.csv')

# %%
qa_df.head()
# Out:
#                                             question  \
# 0  The sanctions against the school were a punish...
# 1  Sammy wanted to go to where the people were.  ...
# 2  To locate a choker not located in a jewelry bo...
# 3  Google Maps and other highway and street GPS s...
# 4  The fox walked from the city into the forest, ...
#
#                                               A  \
# 0                         invalidate AND negate
# 1              social venues AND quiet retreats
# 2     home decor store AND personal accessories
# 3  printed road maps AND urban planning manuals
# 4   suitable prey AND shelter from disturbances
#
#                                                   B  \
# 0                     negate AND promote discipline
# 1                    local events AND social venues
# 2           fashion outlet AND personal accessories
# 3  printed road maps AND historical navigation logs
# 4                      urban garden AND farm fields
#
#                                                    C  \
# 0               enforce rules AND promote discipline
# 1                   sports arenas AND quiet retreats
# 2              artisan market AND online marketplace
# 3  route planning software AND urban planning man...
# 4                    natural habitat AND farm fields
#
#                                                D correct_label  \
# 0                    undermine AND enforce rules             A
# 1              sports arenas AND train platforms             B
# 2            artisan market AND home decor store             C
# 3  printed road maps AND route planning software             D
# 4            suitable prey AND neighborhood pets             A
#
#                              correct_answer_text qa_type
# 0                          invalidate AND negate     AND
# 1                 local events AND social venues     AND
# 2          artisan market AND online marketplace     AND
# 3  printed road maps AND route planning software     AND
# 4    suitable prey AND shelter from disturbances     AND

# %%
# !pip install -q transformers accelerate bitsandbytes peft trl datasets

# %%
import os
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

os.environ['HF_TOKEN'] = user_secrets.get_secret("hugging_face")

# %%
from huggingface_hub import login
login(new_session=False)

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# MODEL_NAME = "meta-llama/Llama-3.1-8B-Instruct"

# # Load tokenizer
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# tokenizer.pad_token = tokenizer.eos_token

# # Load model in 4-bit for QLoRA
# model = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME,
#     load_in_4bit=True,              # 4-bit quantization
#     device_map="auto",              # Automatically split layers to GPU
#     bnb_4bit_quant_type="nf4",      # NormalFloat4 (better for QLoRA)
#     bnb_4bit_use_double_quant=True, # More compression
#     torch_dtype="auto"
# )

# # Prepare for LoRA fine-tuning
# model = prepare_model_for_kbit_training(model)

# # Configure LoRA
# lora_config = LoraConfig(
#     r=8,            # Rank
#     lora_alpha=16,  # Scaling factor
#     target_modules=["q_proj", "v_proj"],  # Apply LoRA to attention layers
#     lora_dropout=0.05,
#     bias="none",
#     task_type="CAUSAL_LM"
# )

# # Wrap model with LoRA
# model = get_peft_model(model, lora_config)

# print("Model ready for QLoRA fine-tuning!")

# %%
# import random
# import ast
# import pandas as pd
# import numpy as np


# def safe_eval(val):
#     if isinstance(val, list):  # already list
#         return val
#     if pd.isna(val):  # NaN
#         return []
#     if isinstance(val, str):  # string that looks like a list
#         return ast.literal_eval(val)
#     return []  # fallback

# df['correct_combinations'] = df['correct_combinations'].apply(safe_eval)
# df['incorrect_combinations'] = df['incorrect_combinations'].apply(safe_eval)


# qa_pairs = []
# correct_label_cycle = ['A', 'B', 'C', 'D']
# label_index = 0  # To cycle through correct answer positions


# for idx, row in df.iterrows():
#     if len(row['correct_combinations']) == 0 or len(row['incorrect_combinations']) == 0:
#         continue  # skip if missing answers
    
#     question = row['question']
#     # if len(row['correct_combinations']) > 1:
#     #     correct_ans = row['correct_combinations'][1]
#     # else:
#     correct_ans = row['correct_combinations'][0]
#     /
#     incorrect_list = row['incorrect_combinations']
#     if len(incorrect_list) >= 3:
#         incorrect_ans = random.sample(incorrect_list, 3)
#     else:
#         incorrect_ans = random.choices(incorrect_list, k=3)
    
#     # We'll fix the correct answer position according to label_index
#     labels = ['A', 'B', 'C', 'D']
#     correct_label = correct_label_cycle[label_index % 4]
#     label_index += 1
    
#     # Place correct answer in the position indicated by correct_label
#     options = incorrect_ans.copy()
#     options.insert(labels.index(correct_label), correct_ans)
    
#     qa_pairs.append({
#         'question': question,
#         'A': options[0],
#         'B': options[1],
#         'C': options[2],
#         'D': options[3],
#         'correct_label': correct_label,
#         'correct_answer_text': correct_ans
#     })

# qa_df = pd.DataFrame(qa_pairs)
# print(f"Generated {len(qa_df)} QA pairs with balanced correct answer positions.")

# qa_df.to_csv('csqa_pairs.csv',index=False)

# %%
qa_df.head()
# Out:
#                                             question  \
# 0  The sanctions against the school were a punish...
# 1  Sammy wanted to go to where the people were.  ...
# 2  To locate a choker not located in a jewelry bo...
# 3  Google Maps and other highway and street GPS s...
# 4  The fox walked from the city into the forest, ...
#
#                                               A  \
# 0                         invalidate AND negate
# 1              social venues AND quiet retreats
# 2     home decor store AND personal accessories
# 3  printed road maps AND urban planning manuals
# 4   suitable prey AND shelter from disturbances
#
#                                                   B  \
# 0                     negate AND promote discipline
# 1                    local events AND social venues
# 2           fashion outlet AND personal accessories
# 3  printed road maps AND historical navigation logs
# 4                      urban garden AND farm fields
#
#                                                    C  \
# 0               enforce rules AND promote discipline
# 1                   sports arenas AND quiet retreats
# 2              artisan market AND online marketplace
# 3  route planning software AND urban planning man...
# 4                    natural habitat AND farm fields
#
#                                                D correct_label  \
# 0                    undermine AND enforce rules             A
# 1              sports arenas AND train platforms             B
# 2            artisan market AND home decor store             C
# 3  printed road maps AND route planning software             D
# 4            suitable prey AND neighborhood pets             A
#
#                              correct_answer_text qa_type
# 0                          invalidate AND negate     AND
# 1                 local events AND social venues     AND
# 2          artisan market AND online marketplace     AND
# 3  printed road maps AND route planning software     AND
# 4    suitable prey AND shelter from disturbances     AND

# %%
# import json

# def one_shot_one_depth_reasoning(model, tokenizer, qa_dataframe):
#     results = []
#     required_cols = ['question', 'A', 'B', 'C', 'D', 'correct_label']
#     if not all(col in qa_dataframe.columns for col in required_cols):
#         raise ValueError(f"DataFrame must contain the following columns: {required_cols}")

#     valid_choices = {'A', 'B', 'C', 'D'}

#     for idx, row in qa_dataframe.iterrows():
#         predicted_label = None
#         try:
#             # Construct the prompt
#             prompt = f"""
#             You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.
#             Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:
            
#             1. Start with a Hypothesis that reflects the overall goal of the question.
            
#             2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) that correspond to the two factors mentioned in the question.
            
#             3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.
            
#             4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option's effectiveness.

#             5. At the end, provide the right choice (just the letter and not the full sentence).
            
#             Below is an example for your reference:
            
#             Question: What are ways someone can get warm?
#             A. Wearing thick clothing and turning off the lights
#             B. Drinking hot tea and sitting near an open window
#             C. Turning on a heater and closing windows
#             D. Eating spicy food and taking a cold shower

#             Output: {{
#                 "output_breakdown": [
#                     {{
#                         "option": "A",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via thick clothing)",
#                                 "premise": "Thick clothing traps the body's natural heat by creating a layer of insulation.",
#                                 "conclusion": "Wearing thick clothing effectively helps retain internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via turning off lights)",
#                                 "premise": "Turning off lights does not significantly change external cold exposure.",
#                                 "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",
#                         "therefore": "This combination is not the best choice."
#                     }},
#                     {{
#                         "option": "B",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via hot tea)",
#                                 "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",
#                                 "conclusion": "Drinking hot tea provides a temporary increase in internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via sitting near an open window)",
#                                 "premise": "Sitting near an open window allows cold air to enter and increases the body's exposure to cold, causing rapid heat loss.",
#                                 "conclusion": "Sitting near an open window increases heat loss and contradicts the goal of reducing cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss.",
#                         "therefore": "This combination is contradictory and not the best choice."
#                     }},
#                     {{
#                         "option": "C",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via heater)",
#                                 "premise": "A heater generates and adds heat to the indoor environment.",
#                                 "conclusion": "Turning on a heater increases heat retention."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via closed windows)",
#                                 "premise": "Closing windows prevents cold air from entering and warm air from escaping.",
#                                 "conclusion": "Closing windows effectively reduces external cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "A heater provides heat generation AND closed windows prevent heat from escaping. Both actions work together to maximize warmth.",
#                         "therefore": "This combination is the correct choice."
#                     }},
#                     {{
#                         "option": "D",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via spicy food)",
#                                 "premise": "Eating spicy food induces a warmth sensation but provides no real thermal gain to the body.",
#                                 "conclusion": "Eating spicy food does not effectively help retain internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via a cold shower)",
#                                 "premise": "Taking a cold shower involves direct contact with cold water, which rapidly draws heat away from the body.",
#                                 "conclusion": "Taking a cold shower significantly increases external cold exposure and causes major heat loss."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
#                         "therefore": "This combination is counterproductive and not the best choice."
#                     }}
#                 ],
#                 "final_answer": "C"
#             }}

#             Now your turn:
#             Question:
#             {str(row['question'])}
            
#             Options:
#             A. {str(row['A'])}
#             B. {str(row['B'])}
#             C. {str(row['C'])}
#             D. {str(row['D'])}
            
#             Output: {{
#               "output_breakdown": [
#                 {{
#                   "option": "A",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "B",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "C",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "D",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }}
#               ],
#               "final_answer": ""
#             }}
#             """
            
#             inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True)
#             inputs = {key: value.to(model.device) for key, value in inputs.items()}

#             output_tokens = model.generate(
#                 input_ids=inputs['input_ids'],
#                 attention_mask=inputs['attention_mask'],
#                 max_new_tokens=1024,
#                 do_sample=False
#             )

#             generated_token_ids = output_tokens[0][inputs['input_ids'].shape[1]:]
#             generated_text = tokenizer.decode(generated_token_ids, skip_special_tokens=True)

#             # --- REVISED POST-PROCESSING STEPS ---
#             # 1. Add a placeholder to make the JSON valid if the model's output is incomplete
#             closing_brace_index = generated_text.rfind("}}")
#             if closing_brace_index != -1:
#                 json_string = generated_text[:closing_brace_index+2]
#             else:
#                 json_string = generated_text + "}}" # In case the model's output is completely missing the end

#             # 2. Attempt to parse the JSON output
#             try:
#                 data = json.loads(json_string)
#                 extracted_label = data.get('final_answer')
#                 if extracted_label and extracted_label in valid_choices:
#                     predicted_label = extracted_label
#                 else:
#                     predicted_label = None # Fallback if final_answer is missing or invalid
#             except json.JSONDecodeError:
#                 # Fallback to a less-structured approach if JSON parsing fails
#                 # This could happen if the model's output is malformed
#                 pass
            
#             # The rest of your logging logic remains the same
#             results.append({
#                 'question': str(row['question']),
#                 'options': f"A. {str(row['A'])} B. {str(row['B'])} C. {str(row['C'])} D. {str(row['D'])}",
#                 'reasoning': generated_text,
#                 'generated_label': predicted_label,
#                 'correct_label': str(row['correct_label']).strip().upper()
#             })
            
#         except Exception as e:
#             print(f"Error processing row {idx}: {e}")
#             results.append({
#                 'question': str(row['question']),
#                 'options': f"A. {str(row['A'])} B. {str(row['B'])} C. {str(row['C'])} D. {str(row['D'])}",
#                 'reasoning': "",
#                 'generated_label': None,
#                 'correct_label': str(row['correct_label']).strip().upper()
#             })

#     return results

    

# # Usage example
# results = one_shot_one_depth_reasoning(model,tokenizer, qa_df.iloc[:20])
# my_results = pd.DataFrame(results)
# my_results.to_csv('csqa_oneshot_1d_reasoning.csv',index=False)

# for res in results[:20]:
#     print(f"Q: {res['question']}")
#     print(f"Options: {res['options']}")
#     print(f"Correct answer: {res['correct_label']}")
#     print(f"Reasoning: {res['reasoning']}")
#     print(f"Predicted answer: {res['generated_label']}")
#     print("-----")

# %%
import os
import json
import time
import pandas as pd
import random
from openai import OpenAI, RateLimitError
from tenacity import retry, wait_random_exponential, stop_after_attempt
from datasets import load_dataset
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

# --- 1. Setup and API Call Functions ---

openai_key = user_secrets.get_secret("openai")
if not openai_key:
    raise ValueError("OPENAI_API_KEY environment variable not set.")
client = OpenAI(api_key=openai_key)


def call_gpt4o_mini(messages):
    """Sends a prompt to the GPT-4o-mini API with robustness for errors."""
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            response_format={"type": "json_object"},
            temperature=0,
            n=1
        )
        content = response.choices[0].message.content
        return json.loads(content)
    except RateLimitError as e:
        print(f"Rate limit error: {e}. Retrying...")
        raise
    except json.JSONDecodeError as e:
        print(f"Received invalid JSON from API: {e}. Retrying...")
        raise e
    except Exception as e:
        print(f"An unexpected error occurred during the API call: {e}")
        raise e


def one_shot_one_depth_reasoning(row):
    """
    Creates multi-step reasoning questions where each option is a compound-compound statement:
    - The entire option is joined by AND/OR
    - Each side of the AND/OR is itself a multi-step fused fact
    """
    
        # Construct the prompt
    user_content = f"""
        You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.
        Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:
        
        1. Start with a Hypothesis that reflects the overall goal of the question.
        
        2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) seperated by logical AND that correspond to the two factors mentioned in the question.
        
        3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.
        
        4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option's effectiveness.
    
        5. At the end, provide the right choice (just the letter and not the full sentence).
        
        Below is an example for your reference:
        
        Question: What are ways someone can get warm?
        A. Wearing thick clothing and turning off the lights
        B. Drinking hot tea and sitting near an open window
        C. Turning on a heater and closing windows
        D. Eating spicy food and taking a cold shower
    
        Output: {{
            "output_breakdown": [
                {{
                    "option": "A",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via thick clothing)",
                            "premise": "Thick clothing traps the body's natural heat by creating a layer of insulation.",
                            "conclusion": "Wearing thick clothing effectively helps retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via turning off lights)",
                            "premise": "Turning off lights does not significantly change external cold exposure.",
                            "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",
                    "therefore": "This combination is not the best choice."
                }},
                {{
                    "option": "B",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via hot tea)",
                            "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",
                            "conclusion": "Drinking hot tea provides a temporary increase in internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via sitting near an open window)",
                            "premise": "Sitting near an open window allows cold air to enter and increases the body's exposure to cold, causing rapid heat loss.",
                            "conclusion": "Sitting near an open window increases heat loss and contradicts the goal of reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss.",
                    "therefore": "This combination is contradictory and not the best choice."
                }},
                {{
                    "option": "C",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via heater)",
                            "premise": "A heater generates and adds heat to the indoor environment.",
                            "conclusion": "Turning on a heater increases heat retention."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via closed windows)",
                            "premise": "Closing windows prevents cold air from entering and warm air from escaping.",
                            "conclusion": "Closing windows effectively reduces external cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "A heater provides heat generation AND closed windows prevent heat from escaping. Both actions work together to maximize warmth.",
                    "therefore": "This combination is the correct choice."
                }},
                {{
                    "option": "D",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via spicy food)",
                            "premise": "Eating spicy food induces a warmth sensation but provides no real thermal gain to the body.",
                            "conclusion": "Eating spicy food does not effectively help retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via a cold shower)",
                            "premise": "Taking a cold shower involves direct contact with cold water, which rapidly draws heat away from the body.",
                            "conclusion": "Taking a cold shower significantly increases external cold exposure and causes major heat loss."
                        }}
                    ],
                    "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
                    "therefore": "This combination is counterproductive and not the best choice."
                }}
            ],
            "final_answer": "C"
        }}
    
        Now your turn:
        Question:
        {str(row['question'])}
        
        Options:
        A. {str(row['A'])}
        B. {str(row['B'])}
        C. {str(row['C'])}
        D. {str(row['D'])}
        Generate the response as a JSON object, following the example format.
        Output: {{
          "output_breakdown": [
            {{
              "option": "A",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "B",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "C",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "D",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }}
          ],
          "final_answer": ""
        }}
        """
    
    messages = [
    {"role": "system", "content": "You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the 'AND' combination positively contribute to the overall goal of the question. Your task is to analyze each option and provide a structured, multi-step breakdown."},
    {"role": "user", "content": user_content}
    ]
    return messages


def one_shot_one_depth_reasoning_with_answer(row):
    """
    Creates multi-step reasoning questions where each option is a compound-compound statement:
    - The entire option is joined by AND/OR
    - Each side of the AND/OR is itself a multi-step fused fact
    - Phase 1: Includes correct answer guidance when available
    """
    
    # Check for correct answer (assumes you have 'correct_answer' column)
    correct_answer = row.get('correct_answer_text', None)
    correct_label = row.get('correct_label',None)
    
    # Create answer guidance section if correct answer is provided
    if correct_answer:
        answer_guidance = f"""

        Correct Option Label: {correct_label}
        TRAINING GUIDANCE: The correct answer for this question is option {correct_answer}. 
        Use this information to:
        1. Generate particularly thorough and high-quality reasoning for option {correct_answer}
        2. Ensure your reasoning clearly demonstrates why option {correct_answer} works best.
        3. Still provide complete analysis for all options, but make option {correct_answer}'s reasoning exemplary.
        4. Show clear contrast between why option {correct_answer} succeeds and others fail.
        5. Focus on creating the most detailed and accurate premise-conclusion pairs for the correct option.
        6. Make sure the reasoning for the incorrect answers are clear, logical and are valid.
        7. For every option, go though the question again try to understand the context of the question and then provide your reasoning.
        8. Reasoning shouldn't be like a particular option si sincorrect because it is marked as incorrect or some superficial reason. Instead it has to be thorugh and sensical.
        9. When an incorrect option has partial merit, acknowledge it before explaining why it ultimately fails
        10. Maintain factual accuracy in all premises and ensure your AND logic evaluation genuinely analyzes how the two parts of each option interact together.
        
        This guidance is provided to help you generate the highest quality reasoning trees for training purposes.
        """
    else:
        answer_guidance = ""
    
    # Construct the prompt
    user_content = f"""
        You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.
        
        Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:
        
        1. Start with a Hypothesis that reflects the overall goal of the question.
        
        2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) seperated by logical AND that correspond to the two factors mentioned in the question.
        
        3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.
        
        4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option's effectiveness.
    
        5. At the end, provide the right choice (just the letter and not the full sentence).
        
        Below is an example for your reference:
        
        Question: What are ways someone can get warm?
        A. Wearing thick clothing and turning off the lights
        B. Drinking hot tea and sitting near an open window
        C. Turning on a heater and closing windows
        D. Eating spicy food and taking a cold shower
    
        Output: {{
            "output_breakdown": [
                {{
                    "option": "A",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via thick clothing)",
                            "premise": "Thick clothing traps the body's natural heat by creating a layer of insulation.",
                            "conclusion": "Wearing thick clothing effectively helps retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via turning off lights)",
                            "premise": "Turning off lights does not significantly change external cold exposure.",
                            "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",
                    "therefore": "This combination is not the best choice."
                }},
                {{
                    "option": "B",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via hot tea)",
                            "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",
                            "conclusion": "Drinking hot tea provides a temporary increase in internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via sitting near an open window)",
                            "premise": "Sitting near an open window allows cold air to enter and increases the body's exposure to cold, causing rapid heat loss.",
                            "conclusion": "Sitting near an open window increases heat loss and contradicts the goal of reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss.",
                    "therefore": "This combination is contradictory and not the best choice."
                }},
                {{
                    "option": "C",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via heater)",
                            "premise": "A heater generates and adds heat to the indoor environment.",
                            "conclusion": "Turning on a heater increases heat retention."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via closed windows)",
                            "premise": "Closing windows prevents cold air from entering and warm air from escaping.",
                            "conclusion": "Closing windows effectively reduces external cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "A heater provides heat generation AND closed windows prevent heat from escaping. Both actions work together to maximize warmth.",
                    "therefore": "This combination is the correct choice."
                }},
                {{
                    "option": "D",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via spicy food)",
                            "premise": "Eating spicy food induces a warmth sensation but provides no real thermal gain to the body.",
                            "conclusion": "Eating spicy food does not effectively help retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via a cold shower)",
                            "premise": "Taking a cold shower involves direct contact with cold water, which rapidly draws heat away from the body.",
                            "conclusion": "Taking a cold shower significantly increases external cold exposure and causes major heat loss."
                        }}
                    ],
                    "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
                    "therefore": "This combination is counterproductive and not the best choice."
                }}
            ],
            "final_answer": "C"
        }}
    
        Now your turn:
        Question:
        {str(row['question'])}
        
        Options:
        A. {str(row['A'])}
        B. {str(row['B'])}
        C. {str(row['C'])}
        D. {str(row['D'])}

        {answer_guidance}
        Generate the response as a JSON object, following the example format.
        Output: {{
          "output_breakdown": [
            {{
              "option": "A",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "B",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "C",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "D",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }}
          ],
          "final_answer": ""
        }}
        """
    
    # Update system message to include training context when correct answer is provided
    if correct_answer:
        system_content = "You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions for training purposes. You will be provided with the correct answer to help you generate exemplary reasoning trees. Use this information to create particularly thorough analysis while still reasoning through all options systematically."
    else:
        system_content = "You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the 'AND' combination positively contribute to the overall goal of the question. Your task is to analyze each option and provide a structured, multi-step breakdown."
    
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content}
    ]
    return messages



def one_shot_three_depth_reasoning(row):
    """
    Creates a prompt for a three-depth reasoning task with nested premises.
    
    The prompt instructs the model to analyze each option by:
    1.  Starting with a top-level Hypothesis (H).
    2.  Breaking it down into two Sub-Hypotheses (H1 and H2).
    3.  For each Sub-Hypothesis, analyzing two specific actions (e.g., A1.1 and A1.2).
    4.  Providing a two-premise breakdown for each action.
    5.  The conclusion for each Sub-Hypothesis is explicitly stated as being entailed by the premises.
    6.  Finally, evaluating the AND logic and providing a definitive 'Therefore' statement.
    """
    user_content = f"""
    You are a logical reasoning AI designed to evaluate complex, multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal.

    Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:

    1.  Start with a top-level Hypothesis (H) that reflects the overall goal of the question.
    
    2.  Break down the hypothesis into two Sub-Hypotheses (H1 and H2) that correspond to the two factors mentioned in the question.
    
    3.  For each Sub-Hypothesis, analyze the specific Actions (A1.1, A1.2, etc.) taken in the option.
    
    4.  Provide a two-premise breakdown for each action, detailing the logical steps.
    
    5.  The conclusion for each Sub-Hypothesis is explicitly stated as being entailed by the premises.
    
    6.  Provide an AND Logic Evaluation that summarizes how the two top-level actions work together.
    
    7.  Finally, provide a concluding Therefore statement that definitively judges the option's effectiveness.

    8.  At the end, provide the right choice (just the letter, e.g., 'A', and not the full sentence).
    
    Below is an example for your reference. Note the three-depth logical breakdown for each action and the new conclusion field that represents the entailment.
    
    Question: What are ways someone can get warm?
    A. Wearing thick clothing and turning off the lights
    B. Drinking hot tea and sitting near an open window
    C. Turning on a heater and closing windows
    D. Eating spicy food and taking a cold shower
    
    Output: {{
        "output_breakdown": [
            {{
                "option": "A",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The body retains heat",
                        "actions": [
                            {{
                                "id": "A1.1",
                                "description": "The person wears thick clothing",
                                "premises": [
                                    {{
                                        "id": "A1.1.1",
                                        "text": "Thick clothes act as insulation by trapping air."
                                    }},
                                    {{
                                        "id": "A1.1.2",
                                        "text": "Insulation slows heat loss from the body."
                                    }}
                                ]
                            }},
                            {{
                                "id": "A1.2",
                                "description": "Heat stays close to the body",
                                "premises": [
                                    {{
                                        "id": "A1.2.1",
                                        "text": "Insulated air layers reduce heat transfer from the body to the environment."
                                    }},
                                    {{
                                        "id": "A1.2.2",
                                        "text": "Reduced heat transfer helps maintain body temperature."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the body effectively retains heat due to the insulating properties of thick clothing."
                    }},
                    {{
                        "id": "H2",
                        "factor": "External cold is blocked",
                        "actions": [
                            {{
                                "id": "A2.1",
                                "description": "The person turns off the lights",
                                "premises": [
                                    {{
                                        "id": "A2.1.1",
                                        "text": "Lights produce a negligible amount of heat."
                                    }},
                                    {{
                                        "id": "A2.1.2",
                                        "text": "Turning them off has no significant effect on room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "A2.2",
                                "description": "No cold air is blocked",
                                "premises": [
                                    {{
                                        "id": "A2.2.1",
                                        "text": "Cold drafts and heat loss still occur without a physical barrier."
                                    }},
                                    {{
                                        "id": "A2.2.2",
                                        "text": "Heat is lost even when lights are off."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, external cold is not blocked because turning off the lights is irrelevant to thermal insulation or blocking drafts."
                    }}
                ],
                "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to blocking external cold.",
                "therefore": "This combination is not the best choice because one of the actions is ineffective."
            }},
            {{
                "option": "B",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The person increases internal warmth",
                        "actions": [
                            {{
                                "id": "B1.1",
                                "description": "The person drinks hot tea",
                                "premises": [
                                    {{
                                        "id": "B1.1.1",
                                        "text": "Hot tea briefly warms internal body temperature."
                                    }},
                                    {{
                                        "id": "B1.1.2",
                                        "text": "Warm liquids promote circulation, which can help distribute warmth."
                                    }}
                                ]
                            }},
                            {{
                                "id": "B1.2",
                                "description": "Internal warmth can reduce cold impact",
                                "premises": [
                                    {{
                                        "id": "B1.2.1",
                                        "text": "A higher internal temperature delays the onset of shivering."
                                    }},
                                    {{
                                        "id": "B1.2.2",
                                        "text": "Better circulation helps distribute warmth throughout the body."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, drinking hot tea provides a temporary increase in internal warmth, which helps reduce the impact of the cold."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold exposure is avoided",
                        "actions": [
                            {{
                                "id": "B2.1",
                                "description": "The person sits near an open window",
                                "premises": [
                                    {{
                                        "id": "B2.1.1",
                                        "text": "Cold air enters through the open window."
                                    }},
                                    {{
                                        "id": "B2.1.2",
                                        "text": "Cold drafts lower the ambient room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "B2.2",
                                "description": "Cold air exposure causes heat loss",
                                "premises": [
                                    {{
                                        "id": "B2.2.1",
                                        "text": "Drafts cool the body directly, causing discomfort."
                                    }},
                                    {{
                                        "id": "B2.2.2",
                                        "text": "Body heat escapes faster in cold, moving air."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold exposure is not avoided, and the person's body will lose heat faster."
                    }}
                ],
                "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss, directly contradicting the goal.",
                "therefore": "This combination is counterproductive and not the best choice."
            }},
            {{
                "option": "C",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The room is kept warm",
                        "actions": [
                            {{
                                "id": "C1.1",
                                "description": "The person turns on a heater",
                                "premises": [
                                    {{
                                        "id": "C1.1.1",
                                        "text": "Heaters convert electrical energy into thermal energy."
                                    }},
                                    {{
                                        "id": "C1.1.2",
                                        "text": "The warmer air increases the room’s temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "C1.2",
                                "description": "The warm room helps maintain body heat",
                                "premises": [
                                    {{
                                        "id": "C1.2.1",
                                        "text": "A warm environment reduces body heat loss to the surrounding air."
                                    }},
                                    {{
                                        "id": "C1.2.2",
                                        "text": "Less heat loss helps the person stay warm and comfortable."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the room is effectively kept warm, which helps the body retain heat."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold air from outside is blocked",
                        "actions": [
                            {{
                                "id": "C2.1",
                                "description": "The person closes the windows",
                                "premises": [
                                    {{
                                        "id": "C2.1.1",
                                        "text": "Open windows allow cold drafts to enter the room."
                                    }},
                                    {{
                                        "id": "C2.1.2",
                                        "text": "Cold drafts lower the room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "C2.2",
                                "description": "No drafts means indoor heat is retained",
                                "premises": [
                                    {{
                                        "id": "C2.2.1",
                                        "text": "Closing windows stops cold air inflow."
                                    }},
                                    {{
                                        "id": "C2.2.2",
                                        "text": "A stable room temperature helps maintain warmth and reduce drafts."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold air from outside is effectively blocked, preventing heat loss."
                    }}
                ],
                "and_logic_evaluation": "A heater provides heat generation, AND closed windows prevent that heat from escaping. Both actions work together to maximize warmth.",
                "therefore": "This combination is the correct choice because both actions are effective and synergistic."
            }},
            {{
                "option": "D",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The person raises body temperature",
                        "actions": [
                            {{
                                "id": "D1.1",
                                "description": "The person eats spicy food",
                                "premises": [
                                    {{
                                        "id": "D1.1.1",
                                        "text": "Spicy food causes a sensation of warmth by stimulating nerve receptors."
                                    }},
                                    {{
                                        "id": "D1.1.2",
                                        "text": "The sensation is a neural response, not an increase in core body temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "D1.2",
                                "description": "No lasting heat is produced",
                                "premises": [
                                    {{
                                        "id": "D1.2.1",
                                        "text": "Spicy food can cause sweating, which is the body's natural cooling mechanism."
                                    }},
                                    {{
                                        "id": "D1.2.2",
                                        "text": "The net result of sweating is body heat loss, not gain."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the person does not effectively raise their body temperature and may even lose heat from sweating."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold exposure is reduced",
                        "actions": [
                            {{
                                "id": "D2.1",
                                "description": "The person takes a cold shower",
                                "premises": [
                                    {{
                                        "id": "D2.1.1",
                                        "text": "Cold water draws heat away from skin and internal organs."
                                    }},
                                    {{
                                        "id": "D2.1.2",
                                        "text": "Skin temperature drops rapidly, triggering the body to preserve heat."
                                    }}
                                ]
                            }},
                            {{
                                "id": "D2.2",
                                "description": "Shower increases cold exposure",
                                "premises": [
                                    {{
                                        "id": "D2.2.1",
                                        "text": "Wet skin loses heat much faster than dry skin."
                                    }},
                                    {{
                                        "id": "D2.2.2",
                                        "text": "The cold water in a shower increases heat loss rather than reducing cold exposure."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold exposure is significantly increased, leading to rapid heat loss."
                    }}
                ],
                "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
                "therefore": "This combination is counterproductive and not the best choice."
            }}
        ],
        "final_answer": "C"
    }}
    
    Now your turn:
    Question:
    {str(row['question'])}
    
    Options:
    A. {str(row['A'])}
    B. {str(row['B'])}
    C. {str(row['C'])}
    D. {str(row['D'])}
    
    Generate the response as a JSON object, following the exact example format.
    Output: {{
      "output_breakdown": [
        {{
          "option": "A",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "A1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "A1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }},
            {{
              "id": "H2",
              "factor": "...",
              "actions": [
                {{
                  "id": "A2.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A2.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A2.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "A2.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A2.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A2.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "B",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "B1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "B1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "B1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "B1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "B1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "B1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "C",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "C1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "C1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "C1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "C1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "C1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "C1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "D",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "D1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "D1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "D1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "D1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "D1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "D1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }}
      ],
      "final_answer": ""
    }}
    """
    
    messages = [
    {"role": "system", "content": "You are a logical reasoning AI designed to evaluate complex, multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the 'AND' combination positively contribute to the overall goal of the question. Your task is to analyze each option and provide a structured, multi-step breakdown."},
    {"role": "user", "content": user_content}
    ]
    return messages


def process_single_row(qa_df, output_file_csv):
    """
    Orchestrates the single-stage pipeline and saves the final output to a CSV file.
    """
    print(f"Starting single-stage pipeline for {len(qa_df)} rows.")
    final_output_list = []
    
    required_cols = ['question', 'A', 'B', 'C', 'D', 'correct_label']
    if not all(col in qa_df.columns for col in required_cols):
        raise ValueError(f"DataFrame must contain the following columns: {required_cols}")

    valid_choices = {'A', 'B', 'C', 'D'}

    for idx, row in qa_df.iterrows():
        # This is where the model generates the question
        messages = one_shot_one_depth_reasoning_with_answer(row)
        if idx == 0:
            print(messages)
        try:
            # Call the API and get the full JSON output
            api_result_dict = call_gpt4o_mini(messages)
            
            
            # Extract the reasoning and final answer
            generated_reasoning = json.dumps(api_result_dict.get('output_breakdown', []))
            predicted_label = api_result_dict.get('final_answer')
            
            # Create the final result dictionary for this row
            result = {
                'question': row['question'],
                'options': f"A. {row['A']} B. {row['B']} C. {row['C']} D. {row['D']}",
                'reasoning_full': generated_reasoning,
                'predicted_label': predicted_label.strip().upper() if predicted_label and predicted_label.strip().upper() in valid_choices else None,
                'correct_label': row['correct_label']
            }

            final_output_list.append(result)
            print(f"Processed row {idx} successfully. Predicted: {result.get('predicted_label')}, Correct: {result.get('correct_label')}")
            
        except Exception as e:
            print(f"Failed to process row {idx}. Error: {e}. Skipping.")
            final_output_list.append({
                'question': row['question'],
                'options': f"A. {row['A']} B. {row['B']} C. {row['C']} D. {row['D']}",
                'reasoning_full': "",
                'predicted_label': None,
                'correct_label': row['correct_label']
            })

    final_df = pd.DataFrame(final_output_list)
    final_df.to_csv(output_file_csv, index=False, encoding='utf-8')
    print(f"\nProcessing complete. {len(final_output_list)} final results saved to '{output_file_csv}'.")

# --- Example of running the pipeline ---
if __name__ == '__main__':
    process_single_row(qa_df.iloc[:150], 'csqa_oneshot_1d_reasoning_with_answer.csv')
# Out:
# Starting single-stage pipeline for 150 rows.
# [{'role': 'system', 'content': 'You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions for training purposes. You will be provided with the correct answer to help you generate exemplary reasoning trees. Use this information to create particularly thorough analysis while still reasoning through all options systematically.'}, {'role': 'user', 'content': '\n        You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.\n        \n        Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:\n        \n        1. Start with a Hypothesis that reflects the overall goal of the question.\n        \n        2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) seperated by logical AND that correspond to the two factors mentioned in the question.\n        \n        3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.\n        \n        4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option\'s effectiveness.\n    \n        5. At the end, provide the right choice (just the letter and not the full sentence).\n        \n        Below is an example for your reference:\n        \n        Question: What are ways someone can get warm?\n        A. Wearing thick clothing and turning off the lights\n        B. Drinking hot tea and sitting near an open window\n        C. Turning on a heater and closing windows\n        D. Eating spicy food and taking a cold shower\n    \n        Output: {\n            "output_breakdown": [\n                {\n                    "option": "A",\n                    "hypothesis": "The person stays warm",\n                    "sub_hypotheses": [\n                        {\n                            "id": "SubH 1",\n                            "factor": "Internal heat is retained (via thick clothing)",\n                            "premise": "Thick clothing traps the body\'s natural heat by creating a layer of insulation.",\n                            "conclusion": "Wearing thick clothing effectively helps retain internal heat."\n                        },\n                        {\n                            "id": "SubH 2",\n                            "factor": "External cold is reduced (via turning off lights)",\n                            "premise": "Turning off lights does not significantly change external cold exposure.",\n                            "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."\n                        }\n                    ],\n                    "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",\n                    "therefore": "This combination is not the best choice."\n                },\n                {\n                    "option": "B",\n                    "hypothesis": "The person stays warm",\n                    "sub_hypotheses": [\n                        {\n                            "id": "SubH 1",\n                            "factor": "Internal heat is retained (via hot tea)",\n                            "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",\n                            "conclusion": "Drinking hot tea provides a temporary increase in internal heat."\n                        },\n                        {\n                            "id": "SubH 2",\n                            "factor": "External cold is reduced (via sitting near an open window)",\n                            "p ...
# Processed row 0 successfully. Predicted: A, Correct: A
# Processed row 1 successfully. Predicted: B, Correct: B
# Processed row 2 successfully. Predicted: C, Correct: C
# Processed row 3 successfully. Predicted: D, Correct: D
# Processed row 4 successfully. Predicted: A, Correct: A
# Processed row 5 successfully. Predicted: B, Correct: B
# Processed row 6 successfully. Predicted: C, Correct: C
# Processed row 7 successfully. Predicted: D, Correct: D
# Processed row 8 successfully. Predicted: A, Correct: A
# Processed row 9 successfully. Predicted: B, Correct: B
# Processed row 10 successfully. Predicted: C, Correct: C
# Processed row 11 successfully. Predicted: D, Correct: D
# Processed row 12 successfully. Predicted: A, Correct: A
# Processed row 13 successfully. Predicted: B, Correct: B
# Processed row 14 successfully. Predicted: C, Correct: C
# Processed row 15 successfully. Predicted: D, Correct: D
# Processed row 16 successfully. Predicted: A, Correct: A
# Processed row 17 successfully. Predicted: B, Correct: B
# Processed row 18 successfully. Predicted: C, Correct: C
# Processed row 19 successfully. Predicted: D, Correct: D
# Processed row 20 successfully. Predicted: A, Correct: A
# Processed row 21 successfully. Predicted: B, Correct: B
# Processed row 22 successfully. Predicted: C, Correct: C
# Processed row 23 successfully. Predicted: D, Correct: D
# Processed row 24 successfully. Predicted: A, Correct: A
# Processed row 25 successfully. Predicted: B, Correct: B
# Processed row 26 successfully. Predicted: C, Correct: C
# Processed row 27 successfully. Predicted: D, Correct: D
# Processed row 28 successfully. Predicted: A, Correct: A
# Processed row 29 successfully. Predicted: B, Correct: B
# Processed row 30 successfully. Predicted: C, Correct: C
# Processed row 31 successfully. Predicted: D, Correct: D
# Processed row 32 successfully. Predicted: A, Correct: A
# Processed row 33 successfully. Predicted: B, Correct: B
# Processed row 34 successfully. Predicted: C, Correct: C
# Processed row 35 successfully. Predicted: D, Correct: D
# Processed row 36 successfully. Predicted: A, Correct: A
# Processed row 37 successfully. Predicted: B, Correct: B
# Processed row 38 successfully. Predicted: C, Correct: C
# Processed row 39 successfully. Predicted: D, Correct: D
# Processed row 40 successfully. Predicted: A, Correct: A
# Processed row 41 successfully. Predicted: B, Correct: B
# Processed row 42 successfully. Predicted: C, Correct: C
# Processed row 43 successfully. Predicted: D, Correct: D
# Processed row 44 successfully. Predicted: A, Correct: A
# Processed row 45 successfully. Predicted: B, Correct: B
# Processed row 46 successfully. Predicted: C, Correct: C
# Processed row 47 successfully. Predicted: D, Correct: D
# Processed row 48 successfully. Predicted: A, Correct: A
# Processed row 49 successfully. Predicted: B, Correct: B
# Processed row 50 successfully. Predicted: C, Correct: C
# Processed row 51 successfully. Predicted: D, Correct: D
# Processed row 52 successfully. Predicted: A, Correct: A
# Processed row 53 successfully. Predicted: B, Correct: B
# Processed row 54 successfully. Predicted: C, Correct: C
# Processed row 55 successfully. Predicted: D, Correct: D
# Processed row 56 successfully. Predicted: A, Correct: A
# Processed row 57 successfully. Predicted: B, Correct: B
# Processed row 58 successfully. Predicted: C, Correct: C
# Processed row 59 successfully. Predicted: D, Correct: D
# Processed row 60 successfully. Predicted: A, Correct: A
# Processed row 61 successfully. Predicted: B, Correct: B
# Processed row 62 successfully. Predicted: C, Correct: C
# Processed row 63 successfully. Predicted: D, Correct: D
# Processed row 64 successfully. Predicted: A, Correct: A
# Processed row 65 successfully. Predicted: B, Correct: B
# Processed row 66 successfully. Predicted: C, Correct: C
# Processed row 67 successfully. Predicted: D, Correct: D
# Processed row 68 successfully. Predicted: A, Correct: A
# Processed row 69 successfully. Predicted: B, Correct: B
# Processed row 70 successfully. Predicted: C, Correct: C
# Processed row 71 successfully. Predicted: D, Correct: D
# Processed row 72 successfully. Predicted: A, Correct: A
# Processed row 73 successfully. Predicted: B, Correct: B
# Processed row 74 successfully. Predicted: C, Correct: C
# Processed row 75 successfully. Predicted: D, Correct: D
# Processed row 76 successfully. Predicted: A, Correct: A
# Processed row 77 successfully. Predicted: C, Correct: B
# Processed row 78 successfully. Predicted: C, Correct: C
# Processed row 79 successfully. Predicted: D, Correct: D
# Processed row 80 successfully. Predicted: A, Correct: A
# Processed row 81 successfully. Predicted: B, Correct: B
# Processed row 82 successfully. Predicted: C, Correct: C
# Processed row 83 successfully. Predicted: D, Correct: D
# Processed row 84 successfully. Predicted: A, Correct: A
# Processed row 85 successfully. Predicted: B, Correct: B
# Processed row 86 successfully. Predicted: C, Correct: C
# Processed row 87 successfully. Predicted: D, Correct: D
# Processed row 88 successfully. Predicted: A, Correct: A
# Processed row 89 successfully. Predicted: B, Correct: B
# Processed row 90 successfully. Predicted: C, Correct: C
# Processed row 91 successfully. Predicted: D, Correct: D
# Processed row 92 successfully. Predicted: A, Correct: A
# Processed row 93 successfully. Predicted: B, Correct: B
# Processed row 94 successfully. Predicted: C, Correct: C
# Processed row 95 successfully. Predicted: D, Correct: D
# Processed row 96 successfully. Predicted: A, Correct: A
# Processed row 97 successfully. Predicted: B, Correct: B
# Processed row 98 successfully. Predicted: C, Correct: C
# Processed row 99 successfully. Predicted: D, Correct: D
# Processed row 100 successfully. Predicted: A, Correct: A
# Processed row 101 successfully. Predicted: B, Correct: B
# Processed row 102 successfully. Predicted: C, Correct: C
# Processed row 103 successfully. Predicted: D, Correct: D
# Processed row 104 successfully. Predicted: A, Correct: A
# Processed row 105 successfully. Predicted: B, Correct: B
# Processed row 106 successfully. Predicted: C, Correct: C
# Processed row 107 successfully. Predicted: D, Correct: D
# Processed row 108 successfully. Predicted: A, Correct: A
# Processed row 109 successfully. Predicted: B, Correct: B
# Processed row 110 successfully. Predicted: C, Correct: C
# Processed row 111 successfully. Predicted: D, Correct: D
# Processed row 112 successfully. Predicted: A, Correct: A
# Processed row 113 successfully. Predicted: B, Correct: B
# Processed row 114 successfully. Predicted: C, Correct: C
# Processed row 115 successfully. Predicted: D, Correct: D
# Processed row 116 successfully. Predicted: A, Correct: A
# Processed row 117 successfully. Predicted: B, Correct: B
# Processed row 118 successfully. Predicted: C, Correct: C
# Processed row 119 successfully. Predicted: D, Correct: D
# Processed row 120 successfully. Predicted: A, Correct: A
# Processed row 121 successfully. Predicted: B, Correct: B
# Processed row 122 successfully. Predicted: C, Correct: C
# Processed row 123 successfully. Predicted: D, Correct: D
# Processed row 124 successfully. Predicted: A, Correct: A
# Processed row 125 successfully. Predicted: B, Correct: B
# Processed row 126 successfully. Predicted: C, Correct: C
# Processed row 127 successfully. Predicted: D, Correct: D
# Processed row 128 successfully. Predicted: A, Correct: A
# Processed row 129 successfully. Predicted: B, Correct: B
# Processed row 130 successfully. Predicted: C, Correct: C
# Processed row 131 successfully. Predicted: D, Correct: D
# Processed row 132 successfully. Predicted: A, Correct: A
# Processed row 133 successfully. Predicted: B, Correct: B
# Processed row 134 successfully. Predicted: C, Correct: C
# Processed row 135 successfully. Predicted: D, Correct: D
# Processed row 136 successfully. Predicted: A, Correct: A
# Processed row 137 successfully. Predicted: B, Correct: B
# Processed row 138 successfully. Predicted: C, Correct: C
# Processed row 139 successfully. Predicted: D, Correct: D
# Processed row 140 successfully. Predicted: A, Correct: A
# Processed row 141 successfully. Predicted: B, Correct: B
# Processed row 142 successfully. Predicted: C, Correct: C
# Processed row 143 successfully. Predicted: D, Correct: D
# Processed row 144 successfully. Predicted: A, Correct: A
# Processed row 145 successfully. Predicted: B, Correct: B
# Processed row 146 successfully. Predicted: C, Correct: C
# Processed row 147 successfully. Predicted: D, Correct: D
# Processed row 148 successfully. Predicted: A, Correct: A
# Processed row 149 successfully. Predicted: B, Correct: B
#
# Processing complete. 150 final results saved to 'csqa_oneshot_1d_reasoning_with_answer.csv'.

# %%
# import pandas as pd
# import json

# # Replace 'csqa_oneshot_1d_reasoning.csv' with the name of your output file
# output_file_csv = 'csqa_oneshot_1d_reasoning.csv'

# # Load the CSV file into a DataFrame
# try:
#     results_df = pd.read_csv(output_file_csv)
# except FileNotFoundError:
#     print(f"Error: The file '{output_file_csv}' was not found.")
#     exit()

# # Iterate through the DataFrame and print the desired columns
# print(f"Displaying results from '{output_file_csv}':\n")

# for index, row in results_df.iterrows():
#     print(f"Q: {row['question']}")
#     print(f"Options: {row['options']}")
#     print(f"Correct answer: {row['correct_label']}")
#     print(f"Predicted answer: {row['predicted_label']}")
    
#     # The reasoning column contains a JSON string, so we need to parse it
#     # to print it nicely, otherwise it will just be a long string
#     try:
#         reasoning_data = json.loads(row['reasoning_full'])
#         print(f"Reasoning:")
#         for option_breakdown in reasoning_data:
#             option = option_breakdown['option']
#             evaluation = option_breakdown['and_logic_evaluation']
#             print(f"  Option {option}: {evaluation}")
#     except json.JSONDecodeError:
#         print(f"Reasoning: (Could not parse JSON for this row)")
#         print(row['reasoning_full'])
        
#     print("-" * 20)

output_file_csv = 'csqa_oneshot_1d_reasoning_with_answer.csv'

# Load the CSV file
try:
    results_df = pd.read_csv(output_file_csv)
except FileNotFoundError:
    print(f"Error: The file '{output_file_csv}' was not found.")
    exit()

# Iterate through all rows and print the formatted JSON output for each
print(f"Displaying formatted JSON output for all rows from '{output_file_csv}':\n")

for index, row in results_df.iloc[:25].iterrows():
    # Print a header for the current question
    print(f"--- Question {index + 1} ---")
    print(f"Question: {row['question']}")
    print(f"Correct Answer: {row['correct_label']}")
    print(f"Predicted Answer: {row['predicted_label']}\n")

    # Get the JSON string and pretty-print it
    try:
        json_string = row['reasoning_full']
        reasoning_data = json.loads(json_string)
        
        # Use json.dumps with indent=2 for a clean, hierarchical output
        pretty_json = json.dumps(reasoning_data, indent=2)
        print("Reasoning Breakdown (JSON):")
        print(pretty_json)
        
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error processing JSON for this row: {e}")
        print("Raw Data:")
        print(row['reasoning_full'])
    
    print("-" * 50 + "\n")
# Out:
# Displaying formatted JSON output for all rows from 'csqa_oneshot_1d_reasoning_with_answer.csv':
#
# --- Question 1 ---
# Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The sanctions against the school undermine the efforts made to change.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions invalidate the school's efforts.",
#         "premise": "To invalidate means to render something ineffective or null, suggesting that the sanctions disregard the positive changes the school has attempted to implement.",
#         "conclusion": "The sanctions effectively dismiss the validity of the school's efforts to improve."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions negate the school's efforts.",
#         "premise": "To negate means to nullify or make ineffective, indicating that the sanctions actively counteract the school's attempts at reform.",
#         "conclusion": "The sanctions directly oppose and undermine the school's efforts to change."
#       }
#     ],
#     "and_logic_evaluation": "Both parts of this option work together to illustrate that the sanctions not only disregard the school's efforts but also actively counteract them, leading to a comprehensive understanding of their negative impact.",
#     "therefore": "This combination effectively captures the essence of how the sanctions affect the school's efforts."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The sanctions against the school promote discipline while negating efforts to change.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions negate the school's efforts.",
#         "premise": "As previously established, sanctions can nullify the school's attempts at reform.",
#         "conclusion": "The sanctions do indeed negate the school's efforts."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions promote discipline.",
#         "premise": "While sanctions may enforce discipline, they do not necessarily promote it in a constructive manner, especially if they undermine reform efforts.",
#         "conclusion": "Promoting discipline through punitive measures can be counterproductive if it disregards the context of improvement."
#       }
#     ],
#     "and_logic_evaluation": "While the first part is valid, the second part fails to align with the overall goal of the question, as promoting discipline does not effectively address the negative impact of the sanctions on the school's efforts.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The sanctions against the school enforce rules while promoting discipline.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions enforce rules.",
#         "premise": "Sanctions typically serve to enforce compliance with established rules.",
#         "conclusion": "The sanctions do enforce rules within the school context."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions promote discipline.",
#         "premise": "While enforcing rules can lead to a semblance of discipline, it does not necessarily promote a positive or constructive environment for change.",
#         "conclusion": "Enforcing rules may not effectively support the school's efforts to change."
#       }
#     ],
#     "and_logic_evaluation": "The first part is valid, but the second part does not address the negative implications of the sanctions on the school's reform efforts, making this combination incomplete.",
#     "therefore": "This combination does not fully capture the essence of the situation."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The sanctions against the school undermine efforts while enforcing rules.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions undermine the school's efforts.",
#         "premise": "Sanctions can indeed undermine the positive changes the school is trying to implement.",
#         "conclusion": "The sanctions negatively impact the school's reform efforts."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions enforce rules.",
#         "premise": "Sanctions are often a method of enforcing compliance with rules.",
#         "conclusion": "The sanctions do serve to enforce rules within the school."
#       }
#     ],
#     "and_logic_evaluation": "While both parts are valid, the term 'enforce rules' does not capture the essence of the negative impact on the school's efforts as effectively as 'invalidate' and 'negate' do.",
#     "therefore": "This combination is valid but not as precise in conveying the overall impact of the sanctions."
#   }
# ]
# --------------------------------------------------
#
# --- Question 2 ---
# Question: Sammy wanted to go to where the people were.  Where might he go?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Sammy goes to where people are present.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Social venues attract crowds.",
#         "premise": "Social venues, such as bars, clubs, and community centers, are designed to host gatherings and events, making them popular places for people to congregate.",
#         "conclusion": "Going to social venues would likely lead Sammy to where many people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Quiet retreats are typically less populated.",
#         "premise": "Quiet retreats, such as spas or nature reserves, are intended for relaxation and solitude, often attracting fewer people.",
#         "conclusion": "Quiet retreats do not align with Sammy's goal of being where people are."
#       }
#     ],
#     "and_logic_evaluation": "While social venues effectively attract crowds, quiet retreats do not contribute to the goal of being around people. Therefore, this combination is ineffective.",
#     "therefore": "This option does not fulfill the requirement."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Sammy goes to where people are present.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Local events gather large crowds.",
#         "premise": "Local events, such as fairs, concerts, and festivals, are specifically organized to attract attendees, making them ideal places for social interaction.",
#         "conclusion": "Attending local events would lead Sammy directly to where many people are gathered."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Social venues also attract crowds.",
#         "premise": "Social venues are designed for social interaction and typically host many people, especially during events or peak hours.",
#         "conclusion": "Going to social venues would also ensure Sammy is around many people."
#       }
#     ],
#     "and_logic_evaluation": "Both local events and social venues are effective in attracting crowds, working together to maximize Sammy's chances of being where people are.",
#     "therefore": "This combination is the best choice for Sammy's goal."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Sammy goes to where people are present.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Sports arenas attract large crowds.",
#         "premise": "Sports arenas are venues for sporting events that typically draw large audiences, making them popular places for social gatherings.",
#         "conclusion": "Going to a sports arena would likely lead Sammy to where many people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Quiet retreats are typically less populated.",
#         "premise": "Quiet retreats, similar to option A, are designed for relaxation and solitude, attracting fewer people.",
#         "conclusion": "Quiet retreats do not align with Sammy's goal of being where people are."
#       }
#     ],
#     "and_logic_evaluation": "While sports arenas effectively attract crowds, quiet retreats do not contribute to the goal of being around people. Therefore, this combination is ineffective.",
#     "therefore": "This option does not fulfill the requirement."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Sammy goes to where people are present.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Sports arenas attract large crowds.",
#         "premise": "Sports arenas host events that draw significant audiences, making them a good choice for social interaction.",
#         "conclusion": "Going to a sports arena would likely lead Sammy to where many people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Train platforms are transit areas with varying crowds.",
#         "premise": "Train platforms can have many people, especially during peak travel times, but they are not specifically designed for social interaction.",
#         "conclusion": "While train platforms may have people, they do not guarantee a social environment like the other options."
#       }
#     ],
#     "and_logic_evaluation": "Sports arenas effectively attract crowds, but train platforms do not provide a social atmosphere conducive to interaction. Therefore, this combination is not the best choice.",
#     "therefore": "This option does not fulfill the requirement."
#   }
# ]
# --------------------------------------------------
#
# --- Question 3 ---
# Question: To locate a choker not located in a jewelry box or boutique where would you go?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique, one can find it in a home decor store AND personal accessories.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Home decor stores may carry unique accessories.",
#         "premise": "Home decor stores often focus on items for home aesthetics and may not typically stock jewelry items like chokers.",
#         "conclusion": "Home decor stores are unlikely to have chokers available."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal accessories stores may have chokers.",
#         "premise": "Personal accessories stores specialize in various accessories, including jewelry.",
#         "conclusion": "Personal accessories stores could potentially have chokers."
#       }
#     ],
#     "and_logic_evaluation": "While personal accessories stores may have chokers, home decor stores do not typically stock them, making this combination ineffective.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique, one can find it in a fashion outlet AND personal accessories.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Fashion outlets may carry trendy jewelry.",
#         "premise": "Fashion outlets often stock a variety of clothing and accessories, including jewelry items like chokers.",
#         "conclusion": "Fashion outlets could potentially have chokers available."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal accessories stores may have chokers.",
#         "premise": "Personal accessories stores specialize in various accessories, including jewelry.",
#         "conclusion": "Personal accessories stores could potentially have chokers."
#       }
#     ],
#     "and_logic_evaluation": "Both fashion outlets and personal accessories stores may carry chokers, but they are still more traditional retail environments, which may not align with the goal of finding chokers outside of typical jewelry locations.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique, one can find it in an artisan market AND online marketplace.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Artisan markets often feature handmade jewelry.",
#         "premise": "Artisan markets are known for unique, handcrafted items, including jewelry like chokers.",
#         "conclusion": "Artisan markets are likely to have a variety of chokers available."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Online marketplaces have a wide range of products.",
#         "premise": "Online marketplaces offer a vast selection of items from various sellers, including unique and handmade jewelry.",
#         "conclusion": "Online marketplaces are very likely to have chokers available."
#       }
#     ],
#     "and_logic_evaluation": "Both artisan markets and online marketplaces are excellent sources for finding chokers, as they provide unique and diverse options outside of traditional jewelry stores.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique, one can find it in an artisan market AND home decor store.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Artisan markets often feature handmade jewelry.",
#         "premise": "Artisan markets are known for unique, handcrafted items, including jewelry like chokers.",
#         "conclusion": "Artisan markets are likely to have a variety of chokers available."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Home decor stores may carry unique accessories.",
#         "premise": "Home decor stores often focus on items for home aesthetics and may not typically stock jewelry items like chokers.",
#         "conclusion": "Home decor stores are unlikely to have chokers available."
#       }
#     ],
#     "and_logic_evaluation": "While artisan markets are a good source for chokers, home decor stores do not typically stock them, making this combination ineffective.",
#     "therefore": "This option is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 4 ---
# Question: Google Maps and other highway and street GPS services have replaced what?
# Correct Answer: D
# Predicted Answer: D
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Google Maps and other GPS services have replaced printed road maps and urban planning manuals.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer used.",
#         "premise": "Printed road maps have been largely replaced by digital navigation tools that provide real-time updates and directions.",
#         "conclusion": "This part of the hypothesis is valid as printed road maps are indeed less commonly used."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Urban planning manuals are no longer used.",
#         "premise": "Urban planning manuals serve a different purpose, focusing on city development and infrastructure rather than navigation.",
#         "conclusion": "This part of the hypothesis is invalid as urban planning manuals are still relevant and used in their specific context."
#       }
#     ],
#     "and_logic_evaluation": "While printed road maps have been replaced, urban planning manuals are still in use, making this combination incomplete.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Google Maps and other GPS services have replaced printed road maps and historical navigation logs.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer used.",
#         "premise": "Printed road maps have been largely replaced by digital navigation tools that provide real-time updates and directions.",
#         "conclusion": "This part of the hypothesis is valid as printed road maps are indeed less commonly used."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Historical navigation logs are no longer used.",
#         "premise": "Historical navigation logs are not commonly used for current navigation, but they serve as records of past navigation methods.",
#         "conclusion": "This part of the hypothesis is invalid as historical navigation logs still hold value for research and historical context."
#       }
#     ],
#     "and_logic_evaluation": "While printed road maps have been replaced, historical navigation logs are still relevant, making this combination incomplete.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Google Maps and other GPS services have replaced route planning software and urban planning manuals.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Route planning software is no longer used.",
#         "premise": "Google Maps and similar services have integrated route planning features, making standalone route planning software less necessary.",
#         "conclusion": "This part of the hypothesis is valid as many users now rely on GPS services for route planning."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Urban planning manuals are no longer used.",
#         "premise": "Urban planning manuals serve a different purpose, focusing on city development and infrastructure rather than navigation.",
#         "conclusion": "This part of the hypothesis is invalid as urban planning manuals are still relevant and used in their specific context."
#       }
#     ],
#     "and_logic_evaluation": "While route planning software may be less used due to GPS services, urban planning manuals are still in use, making this combination incomplete.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Google Maps and other GPS services have replaced printed road maps and route planning software.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer used.",
#         "premise": "Printed road maps have been largely replaced by digital navigation tools that provide real-time updates and directions.",
#         "conclusion": "This part of the hypothesis is valid as printed road maps are indeed less commonly used."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Route planning software is no longer used.",
#         "premise": "Google Maps and similar services have integrated route planning features, making standalone route planning software less necessary.",
#         "conclusion": "This part of the hypothesis is also valid as many users now rely on GPS services for route planning."
#       }
#     ],
#     "and_logic_evaluation": "Both printed road maps and route planning software have been effectively replaced by GPS services, making this combination complete and valid.",
#     "therefore": "This combination is the correct choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 5 ---
# Question: The fox walked from the city into the forest, what was it looking for?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The fox is looking for resources in the forest.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Finding suitable prey.",
#         "premise": "Foxes are carnivorous and rely on hunting small animals for food, which they can find in forested areas.",
#         "conclusion": "Finding suitable prey is essential for the fox's survival and is a primary reason for its movement into the forest."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Seeking shelter from disturbances.",
#         "premise": "Forests provide cover and protection from human activities and predators, allowing the fox to rest and raise its young safely.",
#         "conclusion": "Shelter from disturbances is crucial for the fox's well-being and safety."
#       }
#     ],
#     "and_logic_evaluation": "Both finding suitable prey and seeking shelter from disturbances are critical for the fox's survival and well-being. They complement each other, as the forest offers both food and safety.",
#     "therefore": "This combination effectively addresses the fox's needs and is the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The fox is looking for resources in the forest.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Finding an urban garden.",
#         "premise": "Urban gardens may provide some food sources, but they are not typically found in forests.",
#         "conclusion": "Finding an urban garden is irrelevant to the fox's search in the forest."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Finding farm fields.",
#         "premise": "Farm fields are usually located outside of forested areas and may not provide the cover or safety the fox seeks.",
#         "conclusion": "Farm fields do not contribute to the fox's needs in the forest."
#       }
#     ],
#     "and_logic_evaluation": "While both factors mention potential food sources, neither is relevant to the forest environment, making this combination ineffective.",
#     "therefore": "This option does not meet the fox's needs and is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The fox is looking for resources in the forest.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Finding a natural habitat.",
#         "premise": "The forest is indeed a natural habitat for foxes, providing food and shelter.",
#         "conclusion": "Finding a natural habitat is relevant to the fox's needs."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Finding farm fields.",
#         "premise": "Farm fields are not part of the forest ecosystem and do not provide the necessary resources for the fox.",
#         "conclusion": "Finding farm fields does not contribute to the fox's search in the forest."
#       }
#     ],
#     "and_logic_evaluation": "While finding a natural habitat is relevant, the inclusion of farm fields detracts from the overall effectiveness of this option, as it does not align with the forest environment.",
#     "therefore": "This combination is partially relevant but ultimately fails to fully address the fox's needs."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The fox is looking for resources in the forest.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Finding suitable prey.",
#         "premise": "As previously established, suitable prey is essential for the fox's survival and can be found in the forest.",
#         "conclusion": "Finding suitable prey is relevant to the fox's needs."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Finding neighborhood pets.",
#         "premise": "Neighborhood pets are typically found in urban areas, not in forests, and do not contribute to the fox's natural hunting behavior.",
#         "conclusion": "Finding neighborhood pets is irrelevant to the fox's search in the forest."
#       }
#     ],
#     "and_logic_evaluation": "While finding suitable prey is relevant, the mention of neighborhood pets does not align with the forest environment and detracts from the overall effectiveness of this option.",
#     "therefore": "This combination is partially relevant but ultimately fails to fully address the fox's needs."
#   }
# ]
# --------------------------------------------------
#
# --- Question 6 ---
# Question: What home entertainment equipment requires cable?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The equipment requires cable for operation.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Wireless speaker requires cable.",
#         "premise": "Wireless speakers typically operate via Bluetooth or Wi-Fi and do not require a physical cable connection for audio playback.",
#         "conclusion": "Wireless speakers do not require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Portable projector requires cable.",
#         "premise": "Portable projectors can often operate wirelessly, but they usually require a power cable to function.",
#         "conclusion": "While portable projectors may need a power cable, they do not necessarily require a cable for data input."
#       }
#     ],
#     "and_logic_evaluation": "Wireless speakers do not require cable, and while portable projectors may need a power cable, they do not require a data cable. Therefore, this combination does not meet the requirement.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The equipment requires cable for operation.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Television requires cable.",
#         "premise": "Televisions typically require a cable connection for cable TV service or to connect to other devices like a cable box or streaming device.",
#         "conclusion": "Televisions generally require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Home theater system requires cable.",
#         "premise": "Home theater systems usually require multiple cable connections for speakers, receivers, and other components to function properly.",
#         "conclusion": "Home theater systems also require cable for operation."
#       }
#     ],
#     "and_logic_evaluation": "Both the television and home theater system require cable connections for proper operation, making this combination effective.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The equipment requires cable for operation.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Wireless speaker requires cable.",
#         "premise": "Wireless speakers operate via Bluetooth or Wi-Fi and do not require a physical cable connection for audio playback.",
#         "conclusion": "Wireless speakers do not require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Gaming console requires cable.",
#         "premise": "Gaming consoles typically require a power cable and may require HDMI or other cables to connect to a display.",
#         "conclusion": "Gaming consoles do require cables for power and connection to displays."
#       }
#     ],
#     "and_logic_evaluation": "While gaming consoles require cables, wireless speakers do not, which means this combination does not fully meet the requirement.",
#     "therefore": "This option is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The equipment requires cable for operation.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Digital frame requires cable.",
#         "premise": "Digital frames typically require a power cable to operate, but they can often receive images wirelessly.",
#         "conclusion": "Digital frames do require a power cable but not necessarily a data cable."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Portable projector requires cable.",
#         "premise": "Portable projectors usually require a power cable to function and may also need a cable for data input, depending on the model.",
#         "conclusion": "Portable projectors require a power cable and may require a data cable."
#       }
#     ],
#     "and_logic_evaluation": "While both devices may require a power cable, the digital frame does not require a data cable, which means this combination does not fully meet the requirement.",
#     "therefore": "This option is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 7 ---
# Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The woman is heading to a local gathering with emergency supplies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Traveling to a local gathering.",
#         "premise": "A drawstring bag is typically used for casual outings, which aligns with attending a local gathering.",
#         "conclusion": "The drawstring bag could be suitable for a local gathering."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Carrying emergency supplies.",
#         "premise": "Emergency supplies often require more space and organization than a drawstring bag can provide.",
#         "conclusion": "Using a drawstring bag for emergency supplies is impractical."
#       }
#     ],
#     "and_logic_evaluation": "While the drawstring bag could be used for a local gathering, it is not suitable for carrying emergency supplies, which undermines the overall goal.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The woman is heading to a business engagement and a local gathering.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Traveling for a business engagement.",
#         "premise": "Business engagements typically require more formal and organized luggage than a drawstring bag.",
#         "conclusion": "A drawstring bag is not appropriate for a business engagement."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Attending a local gathering.",
#         "premise": "A drawstring bag can be suitable for casual events like local gatherings.",
#         "conclusion": "The drawstring bag could work for a local gathering."
#       }
#     ],
#     "and_logic_evaluation": "While the drawstring bag is suitable for a local gathering, it fails to meet the requirements for a business engagement, making this combination ineffective.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The woman is heading to the airport for a family gathering.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Traveling to the airport.",
#         "premise": "A drawstring bag is a practical choice for airport travel, as it is lightweight and easy to carry.",
#         "conclusion": "The drawstring bag is suitable for airport travel."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Attending a family gathering.",
#         "premise": "Family gatherings often involve casual settings where a drawstring bag is appropriate for carrying personal items.",
#         "conclusion": "The drawstring bag is also suitable for a family gathering."
#       }
#     ],
#     "and_logic_evaluation": "Both parts of this option work together effectively: the drawstring bag is suitable for both airport travel and a family gathering.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The woman is heading to a business engagement with emergency supplies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Traveling for a business engagement.",
#         "premise": "Business engagements typically require more formal and organized luggage than a drawstring bag.",
#         "conclusion": "A drawstring bag is not appropriate for a business engagement."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Carrying emergency supplies.",
#         "premise": "Emergency supplies often require more space and organization than a drawstring bag can provide.",
#         "conclusion": "Using a drawstring bag for emergency supplies is impractical."
#       }
#     ],
#     "and_logic_evaluation": "Both parts of this option are unsuitable: the drawstring bag is not appropriate for either a business engagement or carrying emergency supplies.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 8 ---
# Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
# Correct Answer: D
# Predicted Answer: D
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The forgotten leftovers are found in a suitable location.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Food is stored in a food cabinet.",
#         "premise": "A food cabinet is typically used for storing dry goods and non-perishable items.",
#         "conclusion": "While a food cabinet can store food, it is not ideal for leftovers, especially those that need refrigeration."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The dining area is a suitable place for food storage.",
#         "premise": "The dining area is primarily for eating and not for food storage, making it an inappropriate location for forgotten leftovers.",
#         "conclusion": "The dining area does not contribute positively to the storage of leftovers."
#       }
#     ],
#     "and_logic_evaluation": "A food cabinet may store food, but it is not suitable for leftovers, AND the dining area is not a proper storage location. Both factors fail to support the hypothesis.",
#     "therefore": "This combination does not effectively address the question."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The forgotten leftovers are found in a suitable location.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Food is stored in cold storage.",
#         "premise": "Cold storage is appropriate for preserving perishable items, including leftovers.",
#         "conclusion": "Cold storage is a suitable location for storing leftovers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The dining area is a suitable place for food storage.",
#         "premise": "The dining area is not designed for food storage and is primarily for consumption.",
#         "conclusion": "The dining area does not contribute positively to the storage of leftovers."
#       }
#     ],
#     "and_logic_evaluation": "Cold storage is appropriate for leftovers, BUT the dining area is not a suitable storage location. The second part undermines the effectiveness of the first.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The forgotten leftovers are found in a suitable location.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Food is stored on the kitchen counter.",
#         "premise": "The kitchen counter is a common place for food preparation and temporary storage.",
#         "conclusion": "While the kitchen counter can hold food, it is not ideal for long-term storage of leftovers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The dining area is a suitable place for food storage.",
#         "premise": "The dining area is primarily for eating and not for food storage.",
#         "conclusion": "The dining area does not contribute positively to the storage of leftovers."
#       }
#     ],
#     "and_logic_evaluation": "The kitchen counter may hold food temporarily, BUT the dining area is not a proper storage location. Both factors fail to support the hypothesis.",
#     "therefore": "This combination does not effectively address the question."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The forgotten leftovers are found in a suitable location.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Food is stored in cold storage.",
#         "premise": "Cold storage is specifically designed to preserve perishable items, including leftovers, by maintaining a low temperature.",
#         "conclusion": "Cold storage is an ideal location for storing leftovers, preventing spoilage."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Food is stored in a sealed container.",
#         "premise": "A sealed container prevents air exposure and contamination, which is essential for preserving the quality of leftovers.",
#         "conclusion": "Using a sealed container enhances the effectiveness of cold storage by preventing spoilage."
#       }
#     ],
#     "and_logic_evaluation": "Cold storage effectively preserves leftovers AND a sealed container prevents spoilage. Both factors work together to ensure the leftovers remain safe and edible.",
#     "therefore": "This combination is the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 9 ---
# Question: What do people use to absorb extra ink from a fountain pen?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Absorbent paper is used to soak up excess ink.",
#         "premise": "Absorbent paper is specifically designed to absorb liquids, including ink, making it highly effective for this purpose.",
#         "conclusion": "Using absorbent paper allows for efficient ink absorption, preventing smudging and ensuring clean writing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Ink-drying cloth aids in the drying process.",
#         "premise": "An ink-drying cloth is made from materials that help to quickly absorb moisture from the surface of the paper, facilitating faster drying of the ink.",
#         "conclusion": "The ink-drying cloth complements the absorbent paper by ensuring that any remaining moisture is quickly absorbed, further preventing smudging."
#       }
#     ],
#     "and_logic_evaluation": "Both absorbent paper and ink-drying cloth work together to effectively absorb excess ink and promote drying, making this combination ideal for the task.",
#     "therefore": "This combination is the best choice for absorbing extra ink from a fountain pen."
#   },
#   {
#     "option": "B",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in the drying process.",
#         "premise": "An ink-drying cloth is effective at absorbing moisture from the surface of the paper, which helps to dry the ink.",
#         "conclusion": "The ink-drying cloth can assist in reducing smudging by absorbing some moisture."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Notebook cover does not absorb ink.",
#         "premise": "A notebook cover is typically made from materials that are not absorbent, such as plastic or cardboard, which do not effectively soak up ink.",
#         "conclusion": "Using a notebook cover does not contribute to the absorption of excess ink."
#       }
#     ],
#     "and_logic_evaluation": "While the ink-drying cloth helps with drying, the notebook cover does not absorb ink, making this combination ineffective for the goal.",
#     "therefore": "This combination fails to meet the requirement for effective ink absorption."
#   },
#   {
#     "option": "C",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in the drying process.",
#         "premise": "An ink-drying cloth is designed to absorb moisture, which can help in drying the ink on the paper.",
#         "conclusion": "The ink-drying cloth can assist in reducing smudging by absorbing moisture."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Writing surface does not absorb ink.",
#         "premise": "A writing surface, such as a desk or table, is not designed to absorb ink and will not help in the absorption process.",
#         "conclusion": "Using a writing surface does not contribute to the absorption of excess ink."
#       }
#     ],
#     "and_logic_evaluation": "While the ink-drying cloth helps with drying, the writing surface does not absorb ink, making this combination ineffective for the goal.",
#     "therefore": "This combination fails to meet the requirement for effective ink absorption."
#   },
#   {
#     "option": "D",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in the drying process.",
#         "premise": "An ink-drying cloth is effective at absorbing moisture from the surface of the paper, which helps to dry the ink.",
#         "conclusion": "The ink-drying cloth can assist in reducing smudging by absorbing some moisture."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Fabric swatch does not effectively absorb ink.",
#         "premise": "A fabric swatch may not be designed for ink absorption and can vary in absorbency based on the material.",
#         "conclusion": "Using a fabric swatch may not provide consistent or effective ink absorption."
#       }
#     ],
#     "and_logic_evaluation": "While the ink-drying cloth helps with drying, the fabric swatch may not effectively absorb ink, making this combination less reliable.",
#     "therefore": "This combination is not the best choice for effective ink absorption."
#   }
# ]
# --------------------------------------------------
#
# --- Question 10 ---
# Question: Where is a business restaurant likely to be located?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "A business restaurant is likely to be located at university campuses AND in suburban neighborhoods.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "University campuses attract a large number of students and faculty.",
#         "premise": "University campuses have a high density of potential customers, including students and staff who may seek convenient dining options.",
#         "conclusion": "This makes university campuses a viable location for business restaurants."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Suburban neighborhoods provide a stable residential customer base.",
#         "premise": "Suburban neighborhoods often have families and professionals who may dine out regularly, providing a consistent customer base.",
#         "conclusion": "This makes suburban neighborhoods a reasonable location for business restaurants."
#       }
#     ],
#     "and_logic_evaluation": "While both university campuses and suburban neighborhoods can attract customers, they do not specifically cater to the business clientele that a business restaurant targets.",
#     "therefore": "This combination is not the best choice for a business restaurant's location."
#   },
#   {
#     "option": "B",
#     "hypothesis": "A business restaurant is likely to be located at business park entrances AND near conference venues.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Business park entrances provide direct access to corporate clients.",
#         "premise": "Business parks are often home to multiple companies, and restaurants at their entrances can attract employees looking for convenient dining options during work hours.",
#         "conclusion": "This makes business park entrances an ideal location for a business restaurant."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Conference venues attract visitors and professionals seeking dining options.",
#         "premise": "Conference venues host events that bring in large groups of professionals who may need dining options nearby, especially during breaks.",
#         "conclusion": "This makes locations near conference venues highly suitable for business restaurants."
#       }
#     ],
#     "and_logic_evaluation": "Both business park entrances and conference venues cater directly to business clientele, making this combination highly effective for a business restaurant's location.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "A business restaurant is likely to be located at corporate office clusters AND near tourist sites.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Corporate office clusters attract business professionals.",
#         "premise": "Corporate office clusters provide a concentrated area of potential customers who may seek dining options during work hours.",
#         "conclusion": "This makes corporate office clusters a good location for business restaurants."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Tourist sites attract visitors who may not be business clientele.",
#         "premise": "While tourist sites attract a large number of visitors, they are not specifically targeted towards business professionals, which is the primary clientele for business restaurants.",
#         "conclusion": "This makes locations near tourist sites less relevant for a business restaurant."
#       }
#     ],
#     "and_logic_evaluation": "Corporate office clusters provide a strong customer base, BUT tourist sites do not align with the business-focused clientele, weakening the overall effectiveness.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "A business restaurant is likely to be located at corporate office clusters AND inside shopping malls.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Corporate office clusters attract business professionals.",
#         "premise": "Corporate office clusters provide a concentrated area of potential customers who may seek dining options during work hours.",
#         "conclusion": "This makes corporate office clusters a good location for business restaurants."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Shopping malls attract a diverse range of customers.",
#         "premise": "While shopping malls attract many visitors, they cater to a broader audience, including families and casual shoppers, rather than specifically targeting business clientele.",
#         "conclusion": "This makes locations inside shopping malls less ideal for a business restaurant."
#       }
#     ],
#     "and_logic_evaluation": "Corporate office clusters provide a strong customer base, BUT shopping malls dilute the focus on business clientele, making this combination less effective.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 11 ---
# Question: Where do you put your grapes just before checking out?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Temporary cart space is used for holding grapes.",
#         "premise": "A temporary cart space is designed for holding items while shopping, making it a suitable place for grapes before checkout.",
#         "conclusion": "Using temporary cart space is appropriate for holding grapes."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Refrigerator section is used for grapes.",
#         "premise": "The refrigerator section is not a practical location for grapes just before checkout, as it is typically not accessible at that point in the shopping process.",
#         "conclusion": "Using the refrigerator section is impractical just before checkout."
#       }
#     ],
#     "and_logic_evaluation": "While temporary cart space is suitable for holding grapes, the refrigerator section is not accessible at checkout, making this combination ineffective.",
#     "therefore": "This combination does not work well."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Produce section holder is used for grapes.",
#         "premise": "The produce section holder is designed for displaying fruits and vegetables, making it a logical place for grapes.",
#         "conclusion": "Using the produce section holder is appropriate for grapes."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal bag is used for grapes.",
# ...
#         "premise": "The main entryway is designed for public access and is the primary entrance for visitors.",
#         "conclusion": "Using the main entryway allows for easy and appropriate access."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Visitor check-in is a valid entrance.",
#         "premise": "Visitor check-in is also an accessible entrance for guests, often located near the main entryway.",
#         "conclusion": "Using visitor check-in provides a welcoming and organized entry point."
#       }
#     ],
#     "and_logic_evaluation": "Both the main entryway and visitor check-in are suitable entrances for public access, working together to ensure a proper entry experience.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The person uses an entrance other than the back entrance.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Main entryway is a valid entrance.",
#         "premise": "The main entryway is designed for public access and is the primary entrance for visitors.",
#         "conclusion": "Using the main entryway allows for easy and appropriate access."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Loading dock is a valid entrance.",
#         "premise": "The loading dock is primarily used for deliveries and may not be intended for general public access.",
#         "conclusion": "Using the loading dock may not be appropriate for general visitors."
#       }
#     ],
#     "and_logic_evaluation": "The main entryway is suitable for public access, BUT the loading dock is not appropriate for general visitors.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The person uses an entrance other than the back entrance.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Loading dock is a valid entrance.",
#         "premise": "The loading dock is primarily used for deliveries and may not be intended for general public access.",
#         "conclusion": "Using the loading dock may not be appropriate for general visitors."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Maintenance route is a valid entrance.",
#         "premise": "The maintenance route is typically reserved for staff and maintenance personnel, not for public access.",
#         "conclusion": "Using the maintenance route is not suitable for general visitors."
#       }
#     ],
#     "and_logic_evaluation": "Both the loading dock and maintenance route are not appropriate for public access, making this option ineffective.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 23 ---
# Question: You can share files with someone if you have a connection to a what?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "You can share files with someone.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A data transfer service is available.",
#         "premise": "A data transfer service allows users to send files over the internet.",
#         "conclusion": "Having a data transfer service enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "An internet caf\u00e9 is accessible.",
#         "premise": "An internet caf\u00e9 provides internet access but does not inherently facilitate file sharing.",
#         "conclusion": "While an internet caf\u00e9 allows internet access, it does not guarantee a means to share files."
#       }
#     ],
#     "and_logic_evaluation": "A data transfer service allows for file sharing, BUT an internet caf\u00e9 does not contribute to the file-sharing process itself.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "You can share files with someone.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A data transfer service is available.",
#         "premise": "A data transfer service allows users to send files over the internet.",
#         "conclusion": "Having a data transfer service enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A public library is accessible.",
#         "premise": "A public library may provide internet access but does not inherently facilitate file sharing.",
#         "conclusion": "While a public library allows for internet access, it does not guarantee a means to share files."
#       }
#     ],
#     "and_logic_evaluation": "A data transfer service allows for file sharing, BUT a public library does not contribute to the file-sharing process itself.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "You can share files with someone.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A file-sharing network is available.",
#         "premise": "A file-sharing network allows users to upload and download files from other users, facilitating direct file sharing.",
#         "conclusion": "Having access to a file-sharing network is essential for sharing files."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A digital collaboration platform is available.",
#         "premise": "A digital collaboration platform provides tools for users to share files, communicate, and work together on projects.",
#         "conclusion": "Access to a digital collaboration platform enhances the ability to share files effectively."
#       }
#     ],
#     "and_logic_evaluation": "A file-sharing network allows for direct file sharing AND a digital collaboration platform provides additional tools for effective sharing. Both actions work together to maximize file-sharing capabilities.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "You can share files with someone.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A file-sharing network is available.",
#         "premise": "A file-sharing network allows users to upload and download files from other users, facilitating direct file sharing.",
#         "conclusion": "Having access to a file-sharing network is essential for sharing files."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A public library is accessible.",
#         "premise": "A public library may provide internet access but does not inherently facilitate file sharing.",
#         "conclusion": "While a public library allows for internet access, it does not guarantee a means to share files."
#       }
#     ],
#     "and_logic_evaluation": "A file-sharing network allows for direct file sharing, BUT a public library does not contribute to the file-sharing process itself.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 24 ---
# Question: The accelerator was controlled via a hand throttle, and the foot pedals controlled the steering in the small what?
# Correct Answer: D
# Predicted Answer: D
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The vehicle is controlled effectively.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in light aircraft.",
#         "premise": "In light aircraft, a hand throttle is commonly used to manage engine power and speed.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for light aircraft."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in electric scooters.",
#         "premise": "Electric scooters typically use handlebars for steering, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in electric scooters, making this part incorrect."
#       }
#     ],
#     "and_logic_evaluation": "The hand throttle is suitable for light aircraft, BUT foot pedals do not control steering in electric scooters, which undermines the overall effectiveness.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The vehicle is controlled effectively.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in personal drones.",
#         "premise": "Personal drones typically use joysticks or remote controls for acceleration, not hand throttles.",
#         "conclusion": "Using a hand throttle for acceleration is not appropriate for personal drones."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in cargo ships.",
#         "premise": "Cargo ships are steered using a wheel or rudder system, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in cargo ships, making this part incorrect."
#       }
#     ],
#     "and_logic_evaluation": "Neither the hand throttle for personal drones nor foot pedals for cargo ships are appropriate, leading to a complete failure of this option.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The vehicle is controlled effectively.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in remote vehicles.",
#         "premise": "Remote vehicles can use various control methods, including hand throttles, for acceleration.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for remote vehicles."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in sports cars.",
#         "premise": "Sports cars are typically steered using a steering wheel, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in sports cars, making this part incorrect."
#       }
#     ],
#     "and_logic_evaluation": "The hand throttle is suitable for remote vehicles, BUT foot pedals do not control steering in sports cars, which undermines the overall effectiveness.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The vehicle is controlled effectively.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in light aircraft.",
#         "premise": "In light aircraft, a hand throttle is commonly used to manage engine power and speed.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for light aircraft."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in remote vehicles.",
#         "premise": "Many remote vehicles, especially those designed for racing or maneuvering, can utilize foot pedals for steering or control.",
#         "conclusion": "Foot pedals can effectively control steering in certain types of remote vehicles."
#       }
#     ],
#     "and_logic_evaluation": "Both the hand throttle for light aircraft and foot pedals for remote vehicles are appropriate and work together to ensure effective control.",
#     "therefore": "This combination is the correct choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 25 ---
# Question: Sean was lying about the body, but he was very scared.  He constantly worried about what?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Sean is worried about the consequences of his actions.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Potential repercussions of lying.",
#         "premise": "Lying can lead to various negative outcomes, including legal consequences, damaged relationships, and loss of credibility.",
#         "conclusion": "Sean is likely worried about the potential repercussions of being discovered as a liar."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Losing friends' trust.",
#         "premise": "Trust is a fundamental component of friendships, and lying can severely damage that trust, leading to isolation and loss of social support.",
#         "conclusion": "Sean is also concerned about losing the trust of his friends, which would further exacerbate his fear."
#       }
#     ],
#     "and_logic_evaluation": "Both potential repercussions of lying and the fear of losing friends' trust are significant concerns for Sean, as they directly relate to the consequences of his dishonesty. Together, they create a comprehensive picture of his anxiety.",
#     "therefore": "This combination effectively captures Sean's worries and is the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Sean is worried about legal and interpersonal issues.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Legal advice.",
#         "premise": "Seeking legal advice indicates concern about potential legal repercussions, which is relevant to Sean's situation.",
#         "conclusion": "However, this does not encompass the full scope of Sean's worries."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Conflict resolution.",
#         "premise": "Conflict resolution is important in maintaining relationships, but it does not directly address the fear of losing trust or the repercussions of lying.",
#         "conclusion": "This option lacks a direct connection to Sean's primary fears."
#       }
#     ],
#     "and_logic_evaluation": "While both factors are relevant to Sean's situation, they do not fully capture the essence of his worries about being discovered and losing friends' trust.",
#     "therefore": "This combination is insufficient and does not effectively represent Sean's concerns."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Sean is worried about being discovered and receiving negative attention.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Being discovered.",
#         "premise": "The fear of being discovered as a liar is a valid concern for Sean, as it relates to the potential repercussions of his actions.",
#         "conclusion": "This factor is relevant to his anxiety."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Negative attention.",
#         "premise": "Negative attention can stem from being discovered, but it does not specifically address the loss of trust from friends.",
#         "conclusion": "This factor is somewhat relevant but does not encompass the full scope of Sean's worries."
#       }
#     ],
#     "and_logic_evaluation": "While being discovered is a significant concern, negative attention does not directly relate to the loss of friends' trust, which is a critical aspect of Sean's anxiety.",
#     "therefore": "This combination is partially relevant but ultimately fails to capture the complete picture of Sean's worries."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Sean is worried about losing friends' trust and legal issues.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Losing friends' trust.",
#         "premise": "This is a valid concern for Sean, as trust is essential in friendships and can be easily damaged by dishonesty.",
#         "conclusion": "This factor is relevant to his anxiety."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Legal advice.",
#         "premise": "While legal advice indicates concern about potential legal repercussions, it does not directly address the emotional impact of losing friends' trust.",
#         "conclusion": "This factor is relevant but does not fully encompass Sean's worries."
#       }
#     ],
#     "and_logic_evaluation": "Losing friends' trust is a significant concern, but the inclusion of legal advice does not directly relate to the emotional aspect of Sean's fears.",
#     "therefore": "This combination is partially relevant but ultimately does not capture the full scope of Sean's worries."
#   }
# ]
# --------------------------------------------------
