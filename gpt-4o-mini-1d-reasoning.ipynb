# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/csqa-dataset/csqa_second_stage-5000.csv
# /kaggle/input/csqa-pairs-baselines/QA_Mixed.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_NEITHER_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_NEITHER.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_OR_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_AND.csv
# /kaggle/input/csqa-pairs-baselines/__huggingface_repos__.json
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_MIXED_results.csv
# /kaggle/input/csqa-pairs-baselines/csqa_zeroshot_AND_results.csv
# /kaggle/input/csqa-pairs-baselines/QA_OR.csv
# /kaggle/input/csqa-pairs-baselines/logical_combinations_output.csv

# %%
qa_df = pd.read_csv('/kaggle/input/csqa-pairs-baselines/QA_AND.csv')

# %%
qa_df.head()
# Out:
#                                             question  \
# 0  The sanctions against the school were a punish...
# 1  Sammy wanted to go to where the people were.  ...
# 2  To locate a choker not located in a jewelry bo...
# 3  Google Maps and other highway and street GPS s...
# 4  The fox walked from the city into the forest, ...
#
#                                               A  \
# 0                         invalidate AND negate
# 1              social venues AND quiet retreats
# 2     home decor store AND personal accessories
# 3  printed road maps AND urban planning manuals
# 4   suitable prey AND shelter from disturbances
#
#                                                   B  \
# 0                     negate AND promote discipline
# 1                    local events AND social venues
# 2           fashion outlet AND personal accessories
# 3  printed road maps AND historical navigation logs
# 4                      urban garden AND farm fields
#
#                                                    C  \
# 0               enforce rules AND promote discipline
# 1                   sports arenas AND quiet retreats
# 2              artisan market AND online marketplace
# 3  route planning software AND urban planning man...
# 4                    natural habitat AND farm fields
#
#                                                D correct_label  \
# 0                    undermine AND enforce rules             A
# 1              sports arenas AND train platforms             B
# 2            artisan market AND home decor store             C
# 3  printed road maps AND route planning software             D
# 4            suitable prey AND neighborhood pets             A
#
#                              correct_answer_text qa_type
# 0                          invalidate AND negate     AND
# 1                 local events AND social venues     AND
# 2          artisan market AND online marketplace     AND
# 3  printed road maps AND route planning software     AND
# 4    suitable prey AND shelter from disturbances     AND

# %%
# !pip install -q transformers accelerate bitsandbytes peft trl datasets

# %%
import os
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

os.environ['HF_TOKEN'] = user_secrets.get_secret("hugging_face")

# %%
from huggingface_hub import login
login(new_session=False)

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# MODEL_NAME = "meta-llama/Llama-3.1-8B-Instruct"

# # Load tokenizer
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# tokenizer.pad_token = tokenizer.eos_token

# # Load model in 4-bit for QLoRA
# model = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME,
#     load_in_4bit=True,              # 4-bit quantization
#     device_map="auto",              # Automatically split layers to GPU
#     bnb_4bit_quant_type="nf4",      # NormalFloat4 (better for QLoRA)
#     bnb_4bit_use_double_quant=True, # More compression
#     torch_dtype="auto"
# )

# # Prepare for LoRA fine-tuning
# model = prepare_model_for_kbit_training(model)

# # Configure LoRA
# lora_config = LoraConfig(
#     r=8,            # Rank
#     lora_alpha=16,  # Scaling factor
#     target_modules=["q_proj", "v_proj"],  # Apply LoRA to attention layers
#     lora_dropout=0.05,
#     bias="none",
#     task_type="CAUSAL_LM"
# )

# # Wrap model with LoRA
# model = get_peft_model(model, lora_config)

# print("Model ready for QLoRA fine-tuning!")

# %%
# import random
# import ast
# import pandas as pd
# import numpy as np


# def safe_eval(val):
#     if isinstance(val, list):  # already list
#         return val
#     if pd.isna(val):  # NaN
#         return []
#     if isinstance(val, str):  # string that looks like a list
#         return ast.literal_eval(val)
#     return []  # fallback

# df['correct_combinations'] = df['correct_combinations'].apply(safe_eval)
# df['incorrect_combinations'] = df['incorrect_combinations'].apply(safe_eval)


# qa_pairs = []
# correct_label_cycle = ['A', 'B', 'C', 'D']
# label_index = 0  # To cycle through correct answer positions


# for idx, row in df.iterrows():
#     if len(row['correct_combinations']) == 0 or len(row['incorrect_combinations']) == 0:
#         continue  # skip if missing answers
    
#     question = row['question']
#     # if len(row['correct_combinations']) > 1:
#     #     correct_ans = row['correct_combinations'][1]
#     # else:
#     correct_ans = row['correct_combinations'][0]
#     /
#     incorrect_list = row['incorrect_combinations']
#     if len(incorrect_list) >= 3:
#         incorrect_ans = random.sample(incorrect_list, 3)
#     else:
#         incorrect_ans = random.choices(incorrect_list, k=3)
    
#     # We'll fix the correct answer position according to label_index
#     labels = ['A', 'B', 'C', 'D']
#     correct_label = correct_label_cycle[label_index % 4]
#     label_index += 1
    
#     # Place correct answer in the position indicated by correct_label
#     options = incorrect_ans.copy()
#     options.insert(labels.index(correct_label), correct_ans)
    
#     qa_pairs.append({
#         'question': question,
#         'A': options[0],
#         'B': options[1],
#         'C': options[2],
#         'D': options[3],
#         'correct_label': correct_label,
#         'correct_answer_text': correct_ans
#     })

# qa_df = pd.DataFrame(qa_pairs)
# print(f"Generated {len(qa_df)} QA pairs with balanced correct answer positions.")

# qa_df.to_csv('csqa_pairs.csv',index=False)

# %%
qa_df.head()
# Out:
#                                             question  \
# 0  The sanctions against the school were a punish...
# 1  Sammy wanted to go to where the people were.  ...
# 2  To locate a choker not located in a jewelry bo...
# 3  Google Maps and other highway and street GPS s...
# 4  The fox walked from the city into the forest, ...
#
#                                               A  \
# 0                         invalidate AND negate
# 1              social venues AND quiet retreats
# 2     home decor store AND personal accessories
# 3  printed road maps AND urban planning manuals
# 4   suitable prey AND shelter from disturbances
#
#                                                   B  \
# 0                     negate AND promote discipline
# 1                    local events AND social venues
# 2           fashion outlet AND personal accessories
# 3  printed road maps AND historical navigation logs
# 4                      urban garden AND farm fields
#
#                                                    C  \
# 0               enforce rules AND promote discipline
# 1                   sports arenas AND quiet retreats
# 2              artisan market AND online marketplace
# 3  route planning software AND urban planning man...
# 4                    natural habitat AND farm fields
#
#                                                D correct_label  \
# 0                    undermine AND enforce rules             A
# 1              sports arenas AND train platforms             B
# 2            artisan market AND home decor store             C
# 3  printed road maps AND route planning software             D
# 4            suitable prey AND neighborhood pets             A
#
#                              correct_answer_text qa_type
# 0                          invalidate AND negate     AND
# 1                 local events AND social venues     AND
# 2          artisan market AND online marketplace     AND
# 3  printed road maps AND route planning software     AND
# 4    suitable prey AND shelter from disturbances     AND

# %%
# import json

# def one_shot_one_depth_reasoning(model, tokenizer, qa_dataframe):
#     results = []
#     required_cols = ['question', 'A', 'B', 'C', 'D', 'correct_label']
#     if not all(col in qa_dataframe.columns for col in required_cols):
#         raise ValueError(f"DataFrame must contain the following columns: {required_cols}")

#     valid_choices = {'A', 'B', 'C', 'D'}

#     for idx, row in qa_dataframe.iterrows():
#         predicted_label = None
#         try:
#             # Construct the prompt
#             prompt = f"""
#             You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.
#             Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:
            
#             1. Start with a Hypothesis that reflects the overall goal of the question.
            
#             2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) that correspond to the two factors mentioned in the question.
            
#             3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.
            
#             4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option's effectiveness.

#             5. At the end, provide the right choice (just the letter and not the full sentence).
            
#             Below is an example for your reference:
            
#             Question: What are ways someone can get warm?
#             A. Wearing thick clothing and turning off the lights
#             B. Drinking hot tea and sitting near an open window
#             C. Turning on a heater and closing windows
#             D. Eating spicy food and taking a cold shower

#             Output: {{
#                 "output_breakdown": [
#                     {{
#                         "option": "A",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via thick clothing)",
#                                 "premise": "Thick clothing traps the body's natural heat by creating a layer of insulation.",
#                                 "conclusion": "Wearing thick clothing effectively helps retain internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via turning off lights)",
#                                 "premise": "Turning off lights does not significantly change external cold exposure.",
#                                 "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",
#                         "therefore": "This combination is not the best choice."
#                     }},
#                     {{
#                         "option": "B",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via hot tea)",
#                                 "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",
#                                 "conclusion": "Drinking hot tea provides a temporary increase in internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via sitting near an open window)",
#                                 "premise": "Sitting near an open window allows cold air to enter and increases the body's exposure to cold, causing rapid heat loss.",
#                                 "conclusion": "Sitting near an open window increases heat loss and contradicts the goal of reducing cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss.",
#                         "therefore": "This combination is contradictory and not the best choice."
#                     }},
#                     {{
#                         "option": "C",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via heater)",
#                                 "premise": "A heater generates and adds heat to the indoor environment.",
#                                 "conclusion": "Turning on a heater increases heat retention."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via closed windows)",
#                                 "premise": "Closing windows prevents cold air from entering and warm air from escaping.",
#                                 "conclusion": "Closing windows effectively reduces external cold exposure."
#                             }}
#                         ],
#                         "and_logic_evaluation": "A heater provides heat generation AND closed windows prevent heat from escaping. Both actions work together to maximize warmth.",
#                         "therefore": "This combination is the correct choice."
#                     }},
#                     {{
#                         "option": "D",
#                         "hypothesis": "The person stays warm",
#                         "sub_hypotheses": [
#                             {{
#                                 "id": "SubH 1",
#                                 "factor": "Internal heat is retained (via spicy food)",
#                                 "premise": "Eating spicy food induces a warmth sensation but provides no real thermal gain to the body.",
#                                 "conclusion": "Eating spicy food does not effectively help retain internal heat."
#                             }},
#                             {{
#                                 "id": "SubH 2",
#                                 "factor": "External cold is reduced (via a cold shower)",
#                                 "premise": "Taking a cold shower involves direct contact with cold water, which rapidly draws heat away from the body.",
#                                 "conclusion": "Taking a cold shower significantly increases external cold exposure and causes major heat loss."
#                             }}
#                         ],
#                         "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
#                         "therefore": "This combination is counterproductive and not the best choice."
#                     }}
#                 ],
#                 "final_answer": "C"
#             }}

#             Now your turn:
#             Question:
#             {str(row['question'])}
            
#             Options:
#             A. {str(row['A'])}
#             B. {str(row['B'])}
#             C. {str(row['C'])}
#             D. {str(row['D'])}
            
#             Output: {{
#               "output_breakdown": [
#                 {{
#                   "option": "A",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "B",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "C",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }},
#                 {{
#                   "option": "D",
#                   "hypothesis": "...",
#                   "sub_hypotheses": [
#                     {{
#                       "id": "SubH 1",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }},
#                     {{
#                       "id": "SubH 2",
#                       "factor": "...",
#                       "premise": "...",
#                       "conclusion": "..."
#                     }}
#                   ],
#                   "and_logic_evaluation": "...",
#                   "therefore": "..."
#                 }}
#               ],
#               "final_answer": ""
#             }}
#             """
            
#             inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True)
#             inputs = {key: value.to(model.device) for key, value in inputs.items()}

#             output_tokens = model.generate(
#                 input_ids=inputs['input_ids'],
#                 attention_mask=inputs['attention_mask'],
#                 max_new_tokens=1024,
#                 do_sample=False
#             )

#             generated_token_ids = output_tokens[0][inputs['input_ids'].shape[1]:]
#             generated_text = tokenizer.decode(generated_token_ids, skip_special_tokens=True)

#             # --- REVISED POST-PROCESSING STEPS ---
#             # 1. Add a placeholder to make the JSON valid if the model's output is incomplete
#             closing_brace_index = generated_text.rfind("}}")
#             if closing_brace_index != -1:
#                 json_string = generated_text[:closing_brace_index+2]
#             else:
#                 json_string = generated_text + "}}" # In case the model's output is completely missing the end

#             # 2. Attempt to parse the JSON output
#             try:
#                 data = json.loads(json_string)
#                 extracted_label = data.get('final_answer')
#                 if extracted_label and extracted_label in valid_choices:
#                     predicted_label = extracted_label
#                 else:
#                     predicted_label = None # Fallback if final_answer is missing or invalid
#             except json.JSONDecodeError:
#                 # Fallback to a less-structured approach if JSON parsing fails
#                 # This could happen if the model's output is malformed
#                 pass
            
#             # The rest of your logging logic remains the same
#             results.append({
#                 'question': str(row['question']),
#                 'options': f"A. {str(row['A'])} B. {str(row['B'])} C. {str(row['C'])} D. {str(row['D'])}",
#                 'reasoning': generated_text,
#                 'generated_label': predicted_label,
#                 'correct_label': str(row['correct_label']).strip().upper()
#             })
            
#         except Exception as e:
#             print(f"Error processing row {idx}: {e}")
#             results.append({
#                 'question': str(row['question']),
#                 'options': f"A. {str(row['A'])} B. {str(row['B'])} C. {str(row['C'])} D. {str(row['D'])}",
#                 'reasoning': "",
#                 'generated_label': None,
#                 'correct_label': str(row['correct_label']).strip().upper()
#             })

#     return results

    

# # Usage example
# results = one_shot_one_depth_reasoning(model,tokenizer, qa_df.iloc[:20])
# my_results = pd.DataFrame(results)
# my_results.to_csv('csqa_oneshot_1d_reasoning.csv',index=False)

# for res in results[:20]:
#     print(f"Q: {res['question']}")
#     print(f"Options: {res['options']}")
#     print(f"Correct answer: {res['correct_label']}")
#     print(f"Reasoning: {res['reasoning']}")
#     print(f"Predicted answer: {res['generated_label']}")
#     print("-----")

# %%
import os
import json
import time
import pandas as pd
import random
from openai import OpenAI, RateLimitError
from tenacity import retry, wait_random_exponential, stop_after_attempt
from datasets import load_dataset
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

# --- 1. Setup and API Call Functions ---

openai_key = user_secrets.get_secret("openai")
if not openai_key:
    raise ValueError("OPENAI_API_KEY environment variable not set.")
client = OpenAI(api_key=openai_key)


def call_gpt4o_mini(messages):
    """Sends a prompt to the GPT-4o-mini API with robustness for errors."""
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            response_format={"type": "json_object"},
            temperature=0,
            n=1
        )
        content = response.choices[0].message.content
        return json.loads(content)
    except RateLimitError as e:
        print(f"Rate limit error: {e}. Retrying...")
        raise
    except json.JSONDecodeError as e:
        print(f"Received invalid JSON from API: {e}. Retrying...")
        raise e
    except Exception as e:
        print(f"An unexpected error occurred during the API call: {e}")
        raise e


def one_shot_one_depth_reasoning(row):
    """
    Creates multi-step reasoning questions where each option is a compound-compound statement:
    - The entire option is joined by AND/OR
    - Each side of the AND/OR is itself a multi-step fused fact
    """
    
        # Construct the prompt
    user_content = f"""
        You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal of the question.
        Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:
        
        1. Start with a Hypothesis that reflects the overall goal of the question.
        
        2. Break down the hypothesis into two sub-hypotheses (SubH 1 and SubH 2) seperated by logical AND that correspond to the two factors mentioned in the question.
        
        3. For each sub-hypothesis, provide a Premise and a Conclusion that fully and accurately explains the reasoning.
        
        4. Finally, provide an AND Logic Evaluation that summarizes how the two parts of the option work together, and a concluding Therefore statement that definitively judges the option's effectiveness.
    
        5. At the end, provide the right choice (just the letter and not the full sentence).
        
        Below is an example for your reference:
        
        Question: What are ways someone can get warm?
        A. Wearing thick clothing and turning off the lights
        B. Drinking hot tea and sitting near an open window
        C. Turning on a heater and closing windows
        D. Eating spicy food and taking a cold shower
    
        Output: {{
            "output_breakdown": [
                {{
                    "option": "A",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via thick clothing)",
                            "premise": "Thick clothing traps the body's natural heat by creating a layer of insulation.",
                            "conclusion": "Wearing thick clothing effectively helps retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via turning off lights)",
                            "premise": "Turning off lights does not significantly change external cold exposure.",
                            "conclusion": "Turning off lights is an irrelevant action for reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to the overall goal.",
                    "therefore": "This combination is not the best choice."
                }},
                {{
                    "option": "B",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via hot tea)",
                            "premise": "Drinking a warm liquid like hot tea provides a temporary, slight increase in core body temperature.",
                            "conclusion": "Drinking hot tea provides a temporary increase in internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via sitting near an open window)",
                            "premise": "Sitting near an open window allows cold air to enter and increases the body's exposure to cold, causing rapid heat loss.",
                            "conclusion": "Sitting near an open window increases heat loss and contradicts the goal of reducing cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss.",
                    "therefore": "This combination is contradictory and not the best choice."
                }},
                {{
                    "option": "C",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via heater)",
                            "premise": "A heater generates and adds heat to the indoor environment.",
                            "conclusion": "Turning on a heater increases heat retention."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via closed windows)",
                            "premise": "Closing windows prevents cold air from entering and warm air from escaping.",
                            "conclusion": "Closing windows effectively reduces external cold exposure."
                        }}
                    ],
                    "and_logic_evaluation": "A heater provides heat generation AND closed windows prevent heat from escaping. Both actions work together to maximize warmth.",
                    "therefore": "This combination is the correct choice."
                }},
                {{
                    "option": "D",
                    "hypothesis": "The person stays warm",
                    "sub_hypotheses": [
                        {{
                            "id": "SubH 1",
                            "factor": "Internal heat is retained (via spicy food)",
                            "premise": "Eating spicy food induces a warmth sensation but provides no real thermal gain to the body.",
                            "conclusion": "Eating spicy food does not effectively help retain internal heat."
                        }},
                        {{
                            "id": "SubH 2",
                            "factor": "External cold is reduced (via a cold shower)",
                            "premise": "Taking a cold shower involves direct contact with cold water, which rapidly draws heat away from the body.",
                            "conclusion": "Taking a cold shower significantly increases external cold exposure and causes major heat loss."
                        }}
                    ],
                    "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
                    "therefore": "This combination is counterproductive and not the best choice."
                }}
            ],
            "final_answer": "C"
        }}
    
        Now your turn:
        Question:
        {str(row['question'])}
        
        Options:
        A. {str(row['A'])}
        B. {str(row['B'])}
        C. {str(row['C'])}
        D. {str(row['D'])}
        Generate the response as a JSON object, following the example format.
        Output: {{
          "output_breakdown": [
            {{
              "option": "A",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "B",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "C",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }},
            {{
              "option": "D",
              "hypothesis": "...",
              "sub_hypotheses": [
                {{
                  "id": "SubH 1",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }},
                {{
                  "id": "SubH 2",
                  "factor": "...",
                  "premise": "...",
                  "conclusion": "..."
                }}
              ],
              "and_logic_evaluation": "...",
              "therefore": "..."
            }}
          ],
          "final_answer": ""
        }}
        """
    
    messages = [
    {"role": "system", "content": "You are a logical reasoning AI designed to evaluate multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the 'AND' combination positively contribute to the overall goal of the question. Your task is to analyze each option and provide a structured, multi-step breakdown."},
    {"role": "user", "content": user_content}
    ]
    return messages



def one_shot_three_depth_reasoning(row):
    """
    Creates a prompt for a three-depth reasoning task with nested premises.
    
    The prompt instructs the model to analyze each option by:
    1.  Starting with a top-level Hypothesis (H).
    2.  Breaking it down into two Sub-Hypotheses (H1 and H2).
    3.  For each Sub-Hypothesis, analyzing two specific actions (e.g., A1.1 and A1.2).
    4.  Providing a two-premise breakdown for each action.
    5.  The conclusion for each Sub-Hypothesis is explicitly stated as being entailed by the premises.
    6.  Finally, evaluating the AND logic and providing a definitive 'Therefore' statement.
    """
    user_content = f"""
    You are a logical reasoning AI designed to evaluate complex, multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the "AND" combination positively contribute to the overall goal.

    Your task is to analyze each option and provide a structured, multi-step breakdown. For each option, you will:

    1.  Start with a top-level Hypothesis (H) that reflects the overall goal of the question.
    
    2.  Break down the hypothesis into two Sub-Hypotheses (H1 and H2) that correspond to the two factors mentioned in the question.
    
    3.  For each Sub-Hypothesis, analyze the specific Actions (A1.1, A1.2, etc.) taken in the option.
    
    4.  Provide a two-premise breakdown for each action, detailing the logical steps.
    
    5.  The conclusion for each Sub-Hypothesis is explicitly stated as being entailed by the premises.
    
    6.  Provide an AND Logic Evaluation that summarizes how the two top-level actions work together.
    
    7.  Finally, provide a concluding Therefore statement that definitively judges the option's effectiveness.

    8.  At the end, provide the right choice (just the letter, e.g., 'A', and not the full sentence).
    
    Below is an example for your reference. Note the three-depth logical breakdown for each action and the new conclusion field that represents the entailment.
    
    Question: What are ways someone can get warm?
    A. Wearing thick clothing and turning off the lights
    B. Drinking hot tea and sitting near an open window
    C. Turning on a heater and closing windows
    D. Eating spicy food and taking a cold shower
    
    Output: {{
        "output_breakdown": [
            {{
                "option": "A",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The body retains heat",
                        "actions": [
                            {{
                                "id": "A1.1",
                                "description": "The person wears thick clothing",
                                "premises": [
                                    {{
                                        "id": "A1.1.1",
                                        "text": "Thick clothes act as insulation by trapping air."
                                    }},
                                    {{
                                        "id": "A1.1.2",
                                        "text": "Insulation slows heat loss from the body."
                                    }}
                                ]
                            }},
                            {{
                                "id": "A1.2",
                                "description": "Heat stays close to the body",
                                "premises": [
                                    {{
                                        "id": "A1.2.1",
                                        "text": "Insulated air layers reduce heat transfer from the body to the environment."
                                    }},
                                    {{
                                        "id": "A1.2.2",
                                        "text": "Reduced heat transfer helps maintain body temperature."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the body effectively retains heat due to the insulating properties of thick clothing."
                    }},
                    {{
                        "id": "H2",
                        "factor": "External cold is blocked",
                        "actions": [
                            {{
                                "id": "A2.1",
                                "description": "The person turns off the lights",
                                "premises": [
                                    {{
                                        "id": "A2.1.1",
                                        "text": "Lights produce a negligible amount of heat."
                                    }},
                                    {{
                                        "id": "A2.1.2",
                                        "text": "Turning them off has no significant effect on room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "A2.2",
                                "description": "No cold air is blocked",
                                "premises": [
                                    {{
                                        "id": "A2.2.1",
                                        "text": "Cold drafts and heat loss still occur without a physical barrier."
                                    }},
                                    {{
                                        "id": "A2.2.2",
                                        "text": "Heat is lost even when lights are off."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, external cold is not blocked because turning off the lights is irrelevant to thermal insulation or blocking drafts."
                    }}
                ],
                "and_logic_evaluation": "Wearing thick clothing helps retain warmth, BUT turning off the lights is irrelevant to blocking external cold.",
                "therefore": "This combination is not the best choice because one of the actions is ineffective."
            }},
            {{
                "option": "B",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The person increases internal warmth",
                        "actions": [
                            {{
                                "id": "B1.1",
                                "description": "The person drinks hot tea",
                                "premises": [
                                    {{
                                        "id": "B1.1.1",
                                        "text": "Hot tea briefly warms internal body temperature."
                                    }},
                                    {{
                                        "id": "B1.1.2",
                                        "text": "Warm liquids promote circulation, which can help distribute warmth."
                                    }}
                                ]
                            }},
                            {{
                                "id": "B1.2",
                                "description": "Internal warmth can reduce cold impact",
                                "premises": [
                                    {{
                                        "id": "B1.2.1",
                                        "text": "A higher internal temperature delays the onset of shivering."
                                    }},
                                    {{
                                        "id": "B1.2.2",
                                        "text": "Better circulation helps distribute warmth throughout the body."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, drinking hot tea provides a temporary increase in internal warmth, which helps reduce the impact of the cold."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold exposure is avoided",
                        "actions": [
                            {{
                                "id": "B2.1",
                                "description": "The person sits near an open window",
                                "premises": [
                                    {{
                                        "id": "B2.1.1",
                                        "text": "Cold air enters through the open window."
                                    }},
                                    {{
                                        "id": "B2.1.2",
                                        "text": "Cold drafts lower the ambient room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "B2.2",
                                "description": "Cold air exposure causes heat loss",
                                "premises": [
                                    {{
                                        "id": "B2.2.1",
                                        "text": "Drafts cool the body directly, causing discomfort."
                                    }},
                                    {{
                                        "id": "B2.2.2",
                                        "text": "Body heat escapes faster in cold, moving air."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold exposure is not avoided, and the person's body will lose heat faster."
                    }}
                ],
                "and_logic_evaluation": "Drinking hot tea provides temporary warmth, BUT sitting near an open window causes significant heat loss, directly contradicting the goal.",
                "therefore": "This combination is counterproductive and not the best choice."
            }},
            {{
                "option": "C",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The room is kept warm",
                        "actions": [
                            {{
                                "id": "C1.1",
                                "description": "The person turns on a heater",
                                "premises": [
                                    {{
                                        "id": "C1.1.1",
                                        "text": "Heaters convert electrical energy into thermal energy."
                                    }},
                                    {{
                                        "id": "C1.1.2",
                                        "text": "The warmer air increases the room’s temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "C1.2",
                                "description": "The warm room helps maintain body heat",
                                "premises": [
                                    {{
                                        "id": "C1.2.1",
                                        "text": "A warm environment reduces body heat loss to the surrounding air."
                                    }},
                                    {{
                                        "id": "C1.2.2",
                                        "text": "Less heat loss helps the person stay warm and comfortable."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the room is effectively kept warm, which helps the body retain heat."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold air from outside is blocked",
                        "actions": [
                            {{
                                "id": "C2.1",
                                "description": "The person closes the windows",
                                "premises": [
                                    {{
                                        "id": "C2.1.1",
                                        "text": "Open windows allow cold drafts to enter the room."
                                    }},
                                    {{
                                        "id": "C2.1.2",
                                        "text": "Cold drafts lower the room temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "C2.2",
                                "description": "No drafts means indoor heat is retained",
                                "premises": [
                                    {{
                                        "id": "C2.2.1",
                                        "text": "Closing windows stops cold air inflow."
                                    }},
                                    {{
                                        "id": "C2.2.2",
                                        "text": "A stable room temperature helps maintain warmth and reduce drafts."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold air from outside is effectively blocked, preventing heat loss."
                    }}
                ],
                "and_logic_evaluation": "A heater provides heat generation, AND closed windows prevent that heat from escaping. Both actions work together to maximize warmth.",
                "therefore": "This combination is the correct choice because both actions are effective and synergistic."
            }},
            {{
                "option": "D",
                "hypothesis": "The person stays warm in extremely cold weather",
                "sub_hypotheses": [
                    {{
                        "id": "H1",
                        "factor": "The person raises body temperature",
                        "actions": [
                            {{
                                "id": "D1.1",
                                "description": "The person eats spicy food",
                                "premises": [
                                    {{
                                        "id": "D1.1.1",
                                        "text": "Spicy food causes a sensation of warmth by stimulating nerve receptors."
                                    }},
                                    {{
                                        "id": "D1.1.2",
                                        "text": "The sensation is a neural response, not an increase in core body temperature."
                                    }}
                                ]
                            }},
                            {{
                                "id": "D1.2",
                                "description": "No lasting heat is produced",
                                "premises": [
                                    {{
                                        "id": "D1.2.1",
                                        "text": "Spicy food can cause sweating, which is the body's natural cooling mechanism."
                                    }},
                                    {{
                                        "id": "D1.2.2",
                                        "text": "The net result of sweating is body heat loss, not gain."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, the person does not effectively raise their body temperature and may even lose heat from sweating."
                    }},
                    {{
                        "id": "H2",
                        "factor": "Cold exposure is reduced",
                        "actions": [
                            {{
                                "id": "D2.1",
                                "description": "The person takes a cold shower",
                                "premises": [
                                    {{
                                        "id": "D2.1.1",
                                        "text": "Cold water draws heat away from skin and internal organs."
                                    }},
                                    {{
                                        "id": "D2.1.2",
                                        "text": "Skin temperature drops rapidly, triggering the body to preserve heat."
                                    }}
                                ]
                            }},
                            {{
                                "id": "D2.2",
                                "description": "Shower increases cold exposure",
                                "premises": [
                                    {{
                                        "id": "D2.2.1",
                                        "text": "Wet skin loses heat much faster than dry skin."
                                    }},
                                    {{
                                        "id": "D2.2.2",
                                        "text": "The cold water in a shower increases heat loss rather than reducing cold exposure."
                                    }}
                                ]
                            }}
                        ],
                        "conclusion": "Therefore, cold exposure is significantly increased, leading to rapid heat loss."
                    }}
                ],
                "and_logic_evaluation": "Eating spicy food provides a minimal, psychological sense of warmth, BUT a cold shower causes significant heat loss.",
                "therefore": "This combination is counterproductive and not the best choice."
            }}
        ],
        "final_answer": "C"
    }}
    
    Now your turn:
    Question:
    {str(row['question'])}
    
    Options:
    A. {str(row['A'])}
    B. {str(row['B'])}
    C. {str(row['C'])}
    D. {str(row['D'])}
    
    Generate the response as a JSON object, following the exact example format.
    Output: {{
      "output_breakdown": [
        {{
          "option": "A",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "A1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "A1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }},
            {{
              "id": "H2",
              "factor": "...",
              "actions": [
                {{
                  "id": "A2.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A2.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A2.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "A2.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "A2.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "A2.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "B",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "B1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "B1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "B1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "B1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "B1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "B1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "C",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "C1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "C1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "C1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "C1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "C1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "C1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }},
        {{
          "option": "D",
          "hypothesis": "...",
          "sub_hypotheses": [
            {{
              "id": "H1",
              "factor": "...",
              "actions": [
                {{
                  "id": "D1.1",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "D1.1.1",
                      "text": "..."
                    }},
                    {{
                      "id": "D1.1.2",
                      "text": "..."
                    }}
                  ]
                }},
                {{
                  "id": "D1.2",
                  "description": "...",
                  "premises": [
                    {{
                      "id": "D1.2.1",
                      "text": "..."
                    }},
                    {{
                      "id": "D1.2.2",
                      "text": "..."
                    }}
                  ]
                }}
              ],
              "conclusion": "..."
            }}
          ],
          "and_logic_evaluation": "...",
          "therefore": "..."
        }}
      ],
      "final_answer": ""
    }}
    """
    
    messages = [
    {"role": "system", "content": "You are a logical reasoning AI designed to evaluate complex, multi-factor, multiple-choice questions. To find the correct answer, you must analyze each option and determine if both parts of the 'AND' combination positively contribute to the overall goal of the question. Your task is to analyze each option and provide a structured, multi-step breakdown."},
    {"role": "user", "content": user_content}
    ]
    return messages


def process_single_row(qa_df, output_file_csv):
    """
    Orchestrates the single-stage pipeline and saves the final output to a CSV file.
    """
    print(f"Starting single-stage pipeline for {len(qa_df)} rows.")
    final_output_list = []
    
    required_cols = ['question', 'A', 'B', 'C', 'D', 'correct_label']
    if not all(col in qa_df.columns for col in required_cols):
        raise ValueError(f"DataFrame must contain the following columns: {required_cols}")

    valid_choices = {'A', 'B', 'C', 'D'}

    for idx, row in qa_df.iterrows():
        # This is where the model generates the question
        messages = one_shot_one_depth_reasoning(row)
        try:
            # Call the API and get the full JSON output
            api_result_dict = call_gpt4o_mini(messages)
            
            
            # Extract the reasoning and final answer
            generated_reasoning = json.dumps(api_result_dict.get('output_breakdown', []))
            predicted_label = api_result_dict.get('final_answer')
            
            # Create the final result dictionary for this row
            result = {
                'question': row['question'],
                'options': f"A. {row['A']} B. {row['B']} C. {row['C']} D. {row['D']}",
                'reasoning_full': generated_reasoning,
                'predicted_label': predicted_label.strip().upper() if predicted_label and predicted_label.strip().upper() in valid_choices else None,
                'correct_label': row['correct_label']
            }

            final_output_list.append(result)
            print(f"Processed row {idx} successfully. Predicted: {result.get('predicted_label')}, Correct: {result.get('correct_label')}")
            
        except Exception as e:
            print(f"Failed to process row {idx}. Error: {e}. Skipping.")
            final_output_list.append({
                'question': row['question'],
                'options': f"A. {row['A']} B. {row['B']} C. {row['C']} D. {row['D']}",
                'reasoning_full': "",
                'predicted_label': None,
                'correct_label': row['correct_label']
            })

    final_df = pd.DataFrame(final_output_list)
    final_df.to_csv(output_file_csv, index=False, encoding='utf-8')
    print(f"\nProcessing complete. {len(final_output_list)} final results saved to '{output_file_csv}'.")

# --- Example of running the pipeline ---
if __name__ == '__main__':
    process_single_row(qa_df.iloc[:100], 'csqa_oneshot_1d_reasoning.csv')
# Out:
# Starting single-stage pipeline for 100 rows.
# Processed row 0 successfully. Predicted: A, Correct: A
# Processed row 1 successfully. Predicted: B, Correct: B
# Processed row 2 successfully. Predicted: C, Correct: C
# Processed row 3 successfully. Predicted: None, Correct: D
# Processed row 4 successfully. Predicted: A, Correct: A
# Processed row 5 successfully. Predicted: B, Correct: B
# Processed row 6 successfully. Predicted: C, Correct: C
# Processed row 7 successfully. Predicted: D, Correct: D
# Processed row 8 successfully. Predicted: A, Correct: A
# Processed row 9 successfully. Predicted: B, Correct: B
# Processed row 10 successfully. Predicted: B, Correct: C
# Processed row 11 successfully. Predicted: C, Correct: D
# Processed row 12 successfully. Predicted: A, Correct: A
# Processed row 13 successfully. Predicted: B, Correct: B
# Processed row 14 successfully. Predicted: C, Correct: C
# Processed row 15 successfully. Predicted: D, Correct: D
# Processed row 16 successfully. Predicted: A, Correct: A
# Processed row 17 successfully. Predicted: B, Correct: B
# Processed row 18 successfully. Predicted: C, Correct: C
# Processed row 19 successfully. Predicted: D, Correct: D
# Processed row 20 successfully. Predicted: A, Correct: A
# Processed row 21 successfully. Predicted: B, Correct: B
# Processed row 22 successfully. Predicted: C, Correct: C
# Processed row 23 successfully. Predicted: D, Correct: D
# Processed row 24 successfully. Predicted: C, Correct: A
# Processed row 25 successfully. Predicted: B, Correct: B
# Processed row 26 successfully. Predicted: C, Correct: C
# Processed row 27 successfully. Predicted: D, Correct: D
# Processed row 28 successfully. Predicted: B, Correct: A
# Processed row 29 successfully. Predicted: B, Correct: B
# Processed row 30 successfully. Predicted: A, Correct: C
# Processed row 31 successfully. Predicted: D, Correct: D
# Processed row 32 successfully. Predicted: A, Correct: A
# Processed row 33 successfully. Predicted: B, Correct: B
# Processed row 34 successfully. Predicted: C, Correct: C
# Processed row 35 successfully. Predicted: None, Correct: D
# Processed row 36 successfully. Predicted: A, Correct: A
# Processed row 37 successfully. Predicted: B, Correct: B
# Processed row 38 successfully. Predicted: C, Correct: C
# Processed row 39 successfully. Predicted: B, Correct: D
# Processed row 40 successfully. Predicted: A, Correct: A
# Processed row 41 successfully. Predicted: B, Correct: B
# Processed row 42 successfully. Predicted: C, Correct: C
# Processed row 43 successfully. Predicted: B, Correct: D
# Processed row 44 successfully. Predicted: A, Correct: A
# Processed row 45 successfully. Predicted: B, Correct: B
# Processed row 46 successfully. Predicted: D, Correct: C
# Processed row 47 successfully. Predicted: C, Correct: D
# Processed row 48 successfully. Predicted: B, Correct: A
# Processed row 49 successfully. Predicted: B, Correct: B
# Processed row 50 successfully. Predicted: C, Correct: C
# Processed row 51 successfully. Predicted: B, Correct: D
# Processed row 52 successfully. Predicted: A, Correct: A
# Processed row 53 successfully. Predicted: B, Correct: B
# Processed row 54 successfully. Predicted: C, Correct: C
# Processed row 55 successfully. Predicted: D, Correct: D
# Processed row 56 successfully. Predicted: A, Correct: A
# Processed row 57 successfully. Predicted: B, Correct: B
# Processed row 58 successfully. Predicted: C, Correct: C
# Processed row 59 successfully. Predicted: D, Correct: D
# Processed row 60 successfully. Predicted: C, Correct: A
# Processed row 61 successfully. Predicted: B, Correct: B
# Processed row 62 successfully. Predicted: C, Correct: C
# Processed row 63 successfully. Predicted: A, Correct: D
# Processed row 64 successfully. Predicted: A, Correct: A
# Processed row 65 successfully. Predicted: B, Correct: B
# Processed row 66 successfully. Predicted: B, Correct: C
# Processed row 67 successfully. Predicted: C, Correct: D
# Processed row 68 successfully. Predicted: A, Correct: A
# Processed row 69 successfully. Predicted: B, Correct: B
# Processed row 70 successfully. Predicted: C, Correct: C
# Processed row 71 successfully. Predicted: D, Correct: D
# Processed row 72 successfully. Predicted: A, Correct: A
# Processed row 73 successfully. Predicted: B, Correct: B
# Processed row 74 successfully. Predicted: C, Correct: C
# Processed row 75 successfully. Predicted: D, Correct: D
# Processed row 76 successfully. Predicted: D, Correct: A
# Processed row 77 successfully. Predicted: C, Correct: B
# Processed row 78 successfully. Predicted: C, Correct: C
# Processed row 79 successfully. Predicted: D, Correct: D
# Processed row 80 successfully. Predicted: C, Correct: A
# Processed row 81 successfully. Predicted: B, Correct: B
# Processed row 82 successfully. Predicted: C, Correct: C
# Processed row 83 successfully. Predicted: D, Correct: D
# Processed row 84 successfully. Predicted: A, Correct: A
# Processed row 85 successfully. Predicted: B, Correct: B
# Processed row 86 successfully. Predicted: C, Correct: C
# Processed row 87 successfully. Predicted: C, Correct: D
# Processed row 88 successfully. Predicted: A, Correct: A
# Processed row 89 successfully. Predicted: D, Correct: B
# Processed row 90 successfully. Predicted: C, Correct: C
# Processed row 91 successfully. Predicted: D, Correct: D
# Processed row 92 successfully. Predicted: A, Correct: A
# Processed row 93 successfully. Predicted: B, Correct: B
# Processed row 94 successfully. Predicted: C, Correct: C
# Processed row 95 successfully. Predicted: D, Correct: D
# Processed row 96 successfully. Predicted: A, Correct: A
# Processed row 97 successfully. Predicted: B, Correct: B
# Processed row 98 successfully. Predicted: C, Correct: C
# Processed row 99 successfully. Predicted: C, Correct: D
#
# Processing complete. 100 final results saved to 'csqa_oneshot_1d_reasoning.csv'.

# %%
# import pandas as pd
# import json

# # Replace 'csqa_oneshot_1d_reasoning.csv' with the name of your output file
# output_file_csv = 'csqa_oneshot_1d_reasoning.csv'

# # Load the CSV file into a DataFrame
# try:
#     results_df = pd.read_csv(output_file_csv)
# except FileNotFoundError:
#     print(f"Error: The file '{output_file_csv}' was not found.")
#     exit()

# # Iterate through the DataFrame and print the desired columns
# print(f"Displaying results from '{output_file_csv}':\n")

# for index, row in results_df.iterrows():
#     print(f"Q: {row['question']}")
#     print(f"Options: {row['options']}")
#     print(f"Correct answer: {row['correct_label']}")
#     print(f"Predicted answer: {row['predicted_label']}")
    
#     # The reasoning column contains a JSON string, so we need to parse it
#     # to print it nicely, otherwise it will just be a long string
#     try:
#         reasoning_data = json.loads(row['reasoning_full'])
#         print(f"Reasoning:")
#         for option_breakdown in reasoning_data:
#             option = option_breakdown['option']
#             evaluation = option_breakdown['and_logic_evaluation']
#             print(f"  Option {option}: {evaluation}")
#     except json.JSONDecodeError:
#         print(f"Reasoning: (Could not parse JSON for this row)")
#         print(row['reasoning_full'])
        
#     print("-" * 20)

output_file_csv = 'csqa_oneshot_1d_reasoning.csv'

# Load the CSV file
try:
    results_df = pd.read_csv(output_file_csv)
except FileNotFoundError:
    print(f"Error: The file '{output_file_csv}' was not found.")
    exit()

# Iterate through all rows and print the formatted JSON output for each
print(f"Displaying formatted JSON output for all rows from '{output_file_csv}':\n")

for index, row in results_df.iloc[:25].iterrows():
    # Print a header for the current question
    print(f"--- Question {index + 1} ---")
    print(f"Question: {row['question']}")
    print(f"Correct Answer: {row['correct_label']}")
    print(f"Predicted Answer: {row['predicted_label']}\n")

    # Get the JSON string and pretty-print it
    try:
        json_string = row['reasoning_full']
        reasoning_data = json.loads(json_string)
        
        # Use json.dumps with indent=2 for a clean, hierarchical output
        pretty_json = json.dumps(reasoning_data, indent=2)
        print("Reasoning Breakdown (JSON):")
        print(pretty_json)
        
    except (json.JSONDecodeError, KeyError) as e:
        print(f"Error processing JSON for this row: {e}")
        print("Raw Data:")
        print(row['reasoning_full'])
    
    print("-" * 50 + "\n")
# Out:
# Displaying formatted JSON output for all rows from 'csqa_oneshot_1d_reasoning.csv':
#
# --- Question 1 ---
# Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The sanctions against the school invalidate the efforts made to change.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions invalidate the school's efforts.",
#         "premise": "To invalidate means to declare something as having no legal force or effect, which would suggest that the school's efforts are rendered meaningless.",
#         "conclusion": "The sanctions would indeed undermine the legitimacy of the school's efforts."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions negate the school's efforts.",
#         "premise": "To negate means to nullify or make ineffective, which implies that the school's efforts are completely countered by the sanctions.",
#         "conclusion": "The sanctions would also completely counteract the school's efforts."
#       }
#     ],
#     "and_logic_evaluation": "Both parts suggest that the sanctions completely undermine and render ineffective the school's efforts to change, which aligns with the context of the question.",
#     "therefore": "This combination effectively captures the impact of the sanctions."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The sanctions against the school negate the efforts made to change.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions negate the school's efforts.",
#         "premise": "Negating means to nullify or make ineffective, indicating that the school's efforts are countered.",
#         "conclusion": "The sanctions would nullify the school's efforts."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions promote discipline.",
#         "premise": "Promoting discipline suggests that the sanctions are intended to encourage better behavior or adherence to rules.",
#         "conclusion": "While promoting discipline may be a goal, it does not directly relate to the negation of the school's efforts."
#       }
#     ],
#     "and_logic_evaluation": "Negating the school's efforts aligns with the context, but promoting discipline does not directly contribute to the negation of efforts.",
#     "therefore": "This combination is partially effective but lacks coherence."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The sanctions against the school enforce rules and promote discipline.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions enforce rules.",
#         "premise": "Enforcing rules means ensuring compliance with established guidelines, which the sanctions aim to achieve.",
#         "conclusion": "The sanctions do indeed enforce rules."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions promote discipline.",
#         "premise": "Promoting discipline suggests that the sanctions are intended to encourage better behavior.",
#         "conclusion": "The sanctions can promote discipline as a result of enforcing rules."
#       }
#     ],
#     "and_logic_evaluation": "While both parts are true, they do not address the question of how the sanctions relate to the school's efforts to change.",
#     "therefore": "This combination does not effectively address the question."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The sanctions against the school undermine the efforts made to change.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The sanctions undermine the school's efforts.",
#         "premise": "To undermine means to weaken or damage something, which suggests that the sanctions negatively impact the school's efforts.",
#         "conclusion": "The sanctions would indeed weaken the school's efforts."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The sanctions enforce rules.",
#         "premise": "Enforcing rules means ensuring compliance, which is a goal of the sanctions.",
#         "conclusion": "While the sanctions enforce rules, this does not directly relate to the undermining of the school's efforts."
#       }
#     ],
#     "and_logic_evaluation": "Undermining the school's efforts aligns with the context, but enforcing rules does not directly contribute to this undermining.",
#     "therefore": "This combination is partially effective but lacks coherence."
#   }
# ]
# --------------------------------------------------
#
# --- Question 2 ---
# Question: Sammy wanted to go to where the people were.  Where might he go?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Sammy goes to where the people are",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Social venues attract people",
#         "premise": "Social venues, such as bars, clubs, and community centers, are designed for social interaction and typically have many people.",
#         "conclusion": "Going to social venues effectively leads Sammy to where people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Quiet retreats do not attract people",
#         "premise": "Quiet retreats, such as spas or nature reserves, are intended for solitude and relaxation, often having fewer people.",
#         "conclusion": "Going to quiet retreats does not lead Sammy to where people are."
#       }
#     ],
#     "and_logic_evaluation": "While social venues attract people, quiet retreats do not, making this combination ineffective.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Sammy goes to where the people are",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Local events attract people",
#         "premise": "Local events, such as fairs, concerts, and festivals, are designed to gather crowds and encourage social interaction.",
#         "conclusion": "Going to local events effectively leads Sammy to where people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Social venues attract people",
#         "premise": "Social venues are also designed for social interaction and typically have many people.",
#         "conclusion": "Going to social venues effectively leads Sammy to where people are."
#       }
#     ],
#     "and_logic_evaluation": "Both local events and social venues attract people, making this combination effective.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Sammy goes to where the people are",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Sports arenas attract people",
#         "premise": "Sports arenas host events that draw large crowds, making them popular places for social gatherings.",
#         "conclusion": "Going to sports arenas effectively leads Sammy to where people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Quiet retreats do not attract people",
#         "premise": "Quiet retreats are intended for solitude and relaxation, often having fewer people.",
#         "conclusion": "Going to quiet retreats does not lead Sammy to where people are."
#       }
#     ],
#     "and_logic_evaluation": "While sports arenas attract people, quiet retreats do not, making this combination ineffective.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Sammy goes to where the people are",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Sports arenas attract people",
#         "premise": "Sports arenas host events that draw large crowds, making them popular places for social gatherings.",
#         "conclusion": "Going to sports arenas effectively leads Sammy to where people are."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Train platforms attract people",
#         "premise": "Train platforms are often busy with commuters and travelers, making them places where many people gather.",
#         "conclusion": "Going to train platforms effectively leads Sammy to where people are."
#       }
#     ],
#     "and_logic_evaluation": "Both sports arenas and train platforms attract people, making this combination effective.",
#     "therefore": "This combination is a strong choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 3 ---
# Question: To locate a choker not located in a jewelry box or boutique where would you go?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Home decor store may have personal accessories.",
#         "premise": "Home decor stores often carry a variety of items, including some personal accessories.",
#         "conclusion": "While a home decor store may have personal accessories, it is not a primary location for chokers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal accessories are available.",
#         "premise": "Personal accessories can include items like chokers, but they are typically found in dedicated accessory stores or boutiques.",
#         "conclusion": "Personal accessories may be available, but the likelihood of finding a choker is low in a home decor store."
#       }
#     ],
#     "and_logic_evaluation": "A home decor store may have some personal accessories, but it is not a reliable source for chokers.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Fashion outlet may have personal accessories.",
#         "premise": "Fashion outlets often carry a range of clothing and accessories, including jewelry items like chokers.",
#         "conclusion": "A fashion outlet is a more likely place to find a choker compared to a home decor store."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal accessories are available.",
#         "premise": "Fashion outlets typically have a section for personal accessories, which can include chokers.",
#         "conclusion": "This option is promising as it combines a fashion outlet with personal accessories."
#       }
#     ],
#     "and_logic_evaluation": "A fashion outlet is likely to have personal accessories, including chokers, making this a strong option.",
#     "therefore": "This combination is a good choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Artisan market may have unique chokers.",
#         "premise": "Artisan markets often feature handmade and unique jewelry items, including chokers.",
#         "conclusion": "An artisan market is a strong candidate for finding a choker."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Online marketplace has a wide variety of accessories.",
#         "premise": "Online marketplaces offer a vast selection of items, including many types of chokers from various sellers.",
#         "conclusion": "An online marketplace is a reliable source for finding a choker."
#       }
#     ],
#     "and_logic_evaluation": "Both an artisan market and an online marketplace are excellent sources for finding chokers, making this a very strong option.",
#     "therefore": "This combination is the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "To locate a choker not located in a jewelry box or boutique.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Artisan market may have unique chokers.",
#         "premise": "Artisan markets often feature handmade and unique jewelry items, including chokers.",
#         "conclusion": "An artisan market is a strong candidate for finding a choker."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Home decor store may have personal accessories.",
#         "premise": "Home decor stores may carry some personal accessories, but they are not primarily focused on jewelry.",
#         "conclusion": "A home decor store is not a reliable source for finding chokers."
#       }
#     ],
#     "and_logic_evaluation": "While an artisan market is a good source for chokers, a home decor store is not, making this combination less effective.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 4 ---
# Question: Google Maps and other highway and street GPS services have replaced what?
# Correct Answer: D
# Predicted Answer: nan
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Google Maps and other GPS services have replaced traditional navigation tools.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer widely used.",
#         "premise": "Printed road maps were the primary navigation tool before the advent of GPS technology.",
#         "conclusion": "Google Maps effectively replaces the need for printed road maps."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Urban planning manuals are not directly replaced by GPS services.",
#         "premise": "Urban planning manuals serve a different purpose, focusing on city development rather than navigation.",
#         "conclusion": "Urban planning manuals are not replaced by GPS services."
#       }
#     ],
#     "and_logic_evaluation": "Printed road maps are effectively replaced by GPS services, BUT urban planning manuals are not relevant to navigation and are not replaced.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Google Maps and other GPS services have replaced traditional navigation tools.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer widely used.",
#         "premise": "Printed road maps were the primary navigation tool before the advent of GPS technology.",
#         "conclusion": "Google Maps effectively replaces the need for printed road maps."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Historical navigation logs are not a direct replacement.",
#         "premise": "Historical navigation logs document past routes and methods but do not serve as practical navigation tools.",
#         "conclusion": "Historical navigation logs are not replaced by GPS services."
#       }
#     ],
#     "and_logic_evaluation": "Printed road maps are effectively replaced by GPS services, BUT historical navigation logs do not serve the same purpose and are not replaced.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Google Maps and other GPS services have replaced traditional navigation tools.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Route planning software is not replaced by GPS services.",
#         "premise": "Route planning software is often integrated with GPS services to enhance navigation.",
#         "conclusion": "Route planning software is not replaced; rather, it complements GPS services."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Urban planning manuals are not directly replaced by GPS services.",
#         "premise": "Urban planning manuals serve a different purpose, focusing on city development rather than navigation.",
#         "conclusion": "Urban planning manuals are not replaced by GPS services."
#       }
#     ],
#     "and_logic_evaluation": "Route planning software is not replaced by GPS services, AND urban planning manuals are not relevant to navigation and are not replaced.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Google Maps and other GPS services have replaced traditional navigation tools.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Printed road maps are no longer widely used.",
#         "premise": "Printed road maps were the primary navigation tool before the advent of GPS technology.",
#         "conclusion": "Google Maps effectively replaces the need for printed road maps."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Route planning software is not replaced by GPS services.",
#         "premise": "Route planning software is often integrated with GPS services to enhance navigation.",
#         "conclusion": "Route planning software is not replaced; rather, it complements GPS services."
#       }
#     ],
#     "and_logic_evaluation": "Printed road maps are effectively replaced by GPS services, BUT route planning software is not replaced and is instead integrated.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 5 ---
# Question: The fox walked from the city into the forest, what was it looking for?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The fox is looking for food and safety.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Suitable prey is available in the forest.",
#         "premise": "Forests typically provide a habitat for various small animals that serve as prey for foxes.",
#         "conclusion": "The forest is a suitable environment for the fox to find food."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Shelter from disturbances is found in the forest.",
#         "premise": "Forests offer cover and protection from human activities and predators, allowing the fox to feel safe.",
#         "conclusion": "The forest provides a safe shelter for the fox."
#       }
#     ],
#     "and_logic_evaluation": "The forest offers both suitable prey for food AND shelter from disturbances, making it an ideal location for the fox.",
#     "therefore": "This combination effectively meets the fox's needs."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The fox is looking for food and agricultural resources.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Urban gardens may provide food sources.",
#         "premise": "Urban gardens can have fruits and vegetables, but they are not a primary food source for foxes.",
#         "conclusion": "Urban gardens are not a reliable source of suitable prey for the fox."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Farm fields may provide food sources.",
#         "premise": "Farm fields can attract small animals, but they are not as safe as forests for a fox.",
#         "conclusion": "Farm fields may provide some food, but they do not offer adequate shelter."
#       }
#     ],
#     "and_logic_evaluation": "Urban gardens provide minimal food AND farm fields may provide some food but lack safety, making this combination ineffective.",
#     "therefore": "This combination does not effectively meet the fox's needs."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The fox is looking for food and a natural environment.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Natural habitat provides suitable prey.",
#         "premise": "Natural habitats like forests are rich in biodiversity, offering various prey for foxes.",
#         "conclusion": "The natural habitat is a suitable environment for the fox to find food."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Farm fields do not provide adequate shelter.",
#         "premise": "Farm fields are often open and exposed, lacking the cover that forests provide.",
#         "conclusion": "Farm fields do not offer the necessary shelter for the fox."
#       }
#     ],
#     "and_logic_evaluation": "Natural habitat provides food, BUT farm fields do not provide adequate shelter, making this combination incomplete.",
#     "therefore": "This combination does not fully meet the fox's needs."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The fox is looking for food and companionship.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Suitable prey includes neighborhood pets.",
#         "premise": "Neighborhood pets are not a natural prey for foxes and are often protected by humans.",
#         "conclusion": "Neighborhood pets do not constitute suitable prey for the fox."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Neighborhood pets are not a source of shelter.",
#         "premise": "Neighborhood pets do not provide shelter; they are often kept indoors or in yards.",
#         "conclusion": "Neighborhood pets do not offer any shelter for the fox."
#       }
#     ],
#     "and_logic_evaluation": "Neighborhood pets do not provide suitable prey AND do not offer shelter, making this combination ineffective.",
#     "therefore": "This combination does not meet the fox's needs."
#   }
# ]
# --------------------------------------------------
#
# --- Question 6 ---
# Question: What home entertainment equipment requires cable?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The equipment requires cable for operation",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Wireless speaker requires cable",
#         "premise": "Wireless speakers typically operate via Bluetooth or Wi-Fi and do not require a physical cable connection for audio playback.",
#         "conclusion": "Wireless speakers do not require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Portable projector requires cable",
#         "premise": "Portable projectors often require a power cable and may need HDMI or other cables for video input.",
#         "conclusion": "Portable projectors do require cable for operation."
#       }
#     ],
#     "and_logic_evaluation": "Wireless speaker does not require cable, BUT portable projector does require cable. One part fails the requirement.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The equipment requires cable for operation",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Television requires cable",
#         "premise": "Televisions typically require a power cable and may also need HDMI or coaxial cables for signal input.",
#         "conclusion": "Televisions do require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Home theater system requires cable",
#         "premise": "Home theater systems usually require multiple cables for speakers, power, and connections to other devices.",
#         "conclusion": "Home theater systems do require cable for operation."
#       }
#     ],
#     "and_logic_evaluation": "Both television and home theater system require cable for operation. Both parts contribute positively to the goal.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The equipment requires cable for operation",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Wireless speaker requires cable",
#         "premise": "Wireless speakers typically operate via Bluetooth or Wi-Fi and do not require a physical cable connection for audio playback.",
#         "conclusion": "Wireless speakers do not require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Gaming console requires cable",
#         "premise": "Gaming consoles require a power cable and often need HDMI or other cables for video output.",
#         "conclusion": "Gaming consoles do require cable for operation."
#       }
#     ],
#     "and_logic_evaluation": "Wireless speaker does not require cable, BUT gaming console does require cable. One part fails the requirement.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The equipment requires cable for operation",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Digital frame requires cable",
#         "premise": "Digital frames typically require a power cable and may need USB or other cables for data transfer.",
#         "conclusion": "Digital frames do require cable for operation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Portable projector requires cable",
#         "premise": "Portable projectors often require a power cable and may need HDMI or other cables for video input.",
#         "conclusion": "Portable projectors do require cable for operation."
#       }
#     ],
#     "and_logic_evaluation": "Both digital frame and portable projector require cable for operation. Both parts contribute positively to the goal.",
#     "therefore": "This combination is the correct choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 7 ---
# Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The woman is heading to a local gathering with emergency supplies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The drawstring bag is suitable for a local gathering.",
#         "premise": "A drawstring bag is typically used for casual outings and can carry personal items.",
#         "conclusion": "The drawstring bag is appropriate for a local gathering."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Emergency supplies are needed for the local gathering.",
#         "premise": "Emergency supplies are usually not required for a casual local gathering.",
#         "conclusion": "The need for emergency supplies does not align with the context of a local gathering."
#       }
#     ],
#     "and_logic_evaluation": "The drawstring bag is suitable for a local gathering, BUT emergency supplies are not typically needed for such an event.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The woman is heading to a business engagement and a local gathering.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The drawstring bag is suitable for a business engagement.",
#         "premise": "A drawstring bag may not be considered professional for a business engagement.",
#         "conclusion": "The drawstring bag is not appropriate for a business engagement."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The drawstring bag is suitable for a local gathering.",
#         "premise": "A drawstring bag is typically used for casual outings and can carry personal items.",
#         "conclusion": "The drawstring bag is appropriate for a local gathering."
#       }
#     ],
#     "and_logic_evaluation": "The drawstring bag is not suitable for a business engagement, BUT it is suitable for a local gathering. The first part fails.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The woman is heading to the airport for a family gathering.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The drawstring bag is suitable for airport travel.",
#         "premise": "A drawstring bag can be used for carrying essentials during travel, making it suitable for the airport.",
#         "conclusion": "The drawstring bag is appropriate for airport travel."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The drawstring bag is suitable for a family gathering.",
#         "premise": "A drawstring bag can carry personal items needed for a family gathering.",
#         "conclusion": "The drawstring bag is appropriate for a family gathering."
#       }
#     ],
#     "and_logic_evaluation": "The drawstring bag is suitable for both airport travel AND a family gathering. Both actions work together to support the hypothesis.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The woman is heading to a business engagement with emergency supplies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The drawstring bag is suitable for a business engagement.",
#         "premise": "A drawstring bag may not be considered professional for a business engagement.",
#         "conclusion": "The drawstring bag is not appropriate for a business engagement."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Emergency supplies are needed for a business engagement.",
#         "premise": "Emergency supplies are typically not required for a business engagement.",
#         "conclusion": "The need for emergency supplies does not align with the context of a business engagement."
#       }
#     ],
#     "and_logic_evaluation": "The drawstring bag is not suitable for a business engagement, AND emergency supplies are not typically needed for such an event. Both parts fail.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 8 ---
# Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
# Correct Answer: D
# Predicted Answer: D
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The leftovers were found in a place where they could spoil.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Food is stored in a food cabinet.",
#         "premise": "A food cabinet is typically used for storing non-perishable items and may not be suitable for leftovers.",
#         "conclusion": "Finding moldy leftovers in a food cabinet is unlikely, as it is not a common storage place for perishable food."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The dining area is a place where food is consumed.",
#         "premise": "The dining area is not a storage area for leftovers, but rather a place for eating.",
#         "conclusion": "Finding moldy leftovers in the dining area is also unlikely, as it is not a storage location."
#       }
#     ],
#     "and_logic_evaluation": "Both the food cabinet and dining area are not appropriate places for storing leftovers, making this option ineffective.",
#     "therefore": "This combination does not support the hypothesis."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The leftovers were found in a place where they could spoil.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Cold storage is suitable for perishable food.",
#         "premise": "Cold storage, such as a refrigerator, is designed to keep food fresh and prevent spoilage.",
#         "conclusion": "Finding moldy leftovers in cold storage indicates they were forgotten and spoiled despite being in a suitable place."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The dining area is a place where food is consumed.",
#         "premise": "The dining area is not a storage area for leftovers, but rather a place for eating.",
#         "conclusion": "Finding moldy leftovers in the dining area is unlikely, as it is not a storage location."
#       }
#     ],
#     "and_logic_evaluation": "Cold storage is appropriate for storing leftovers, but the dining area is not, making this combination partially effective but not ideal.",
#     "therefore": "This combination does not fully support the hypothesis."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The leftovers were found in a place where they could spoil.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "The dining area is a place where food is consumed.",
#         "premise": "The dining area is not a storage area for leftovers, but rather a place for eating.",
#         "conclusion": "Finding moldy leftovers in the dining area is unlikely, as it is not a storage location."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "The kitchen counter is a common place for food preparation.",
#         "premise": "The kitchen counter can be a place where leftovers are temporarily placed but is not ideal for long-term storage.",
#         "conclusion": "Finding moldy leftovers on the kitchen counter suggests they were left out and spoiled."
#       }
#     ],
#     "and_logic_evaluation": "The dining area is not suitable for storing leftovers, while the kitchen counter can lead to spoilage, making this combination ineffective.",
#     "therefore": "This combination does not support the hypothesis."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The leftovers were found in a place where they could spoil.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Cold storage is suitable for perishable food.",
#         "premise": "Cold storage, such as a refrigerator, is designed to keep food fresh and prevent spoilage.",
#         "conclusion": "Finding moldy leftovers in cold storage indicates they were forgotten and spoiled despite being in a suitable place."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A sealed container is ideal for storing leftovers.",
#         "premise": "A sealed container helps to keep food fresh and prevents exposure to air and bacteria.",
#         "conclusion": "Finding moldy leftovers in a sealed container suggests they were improperly stored or left too long."
#       }
#     ],
#     "and_logic_evaluation": "Both cold storage and a sealed container are appropriate for storing leftovers, but finding moldy food indicates a failure in storage practices.",
#     "therefore": "This combination supports the hypothesis effectively."
#   }
# ]
# --------------------------------------------------
#
# --- Question 9 ---
# Question: What do people use to absorb extra ink from a fountain pen?
# Correct Answer: A
# Predicted Answer: A
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Absorbent paper is effective for ink absorption.",
#         "premise": "Absorbent paper is designed to soak up excess ink due to its porous structure.",
#         "conclusion": "Using absorbent paper effectively helps in absorbing extra ink."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Ink-drying cloth aids in drying the ink.",
#         "premise": "An ink-drying cloth is specifically made to absorb moisture and can help in drying excess ink quickly.",
#         "conclusion": "Using an ink-drying cloth effectively aids in drying and absorbing extra ink."
#       }
#     ],
#     "and_logic_evaluation": "Both absorbent paper and ink-drying cloth are effective in absorbing and drying excess ink, working together to achieve the goal.",
#     "therefore": "This combination is a strong choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in drying the ink.",
#         "premise": "An ink-drying cloth is designed to absorb moisture and can help in drying excess ink quickly.",
#         "conclusion": "Using an ink-drying cloth effectively aids in drying and absorbing extra ink."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Notebook cover does not absorb ink effectively.",
#         "premise": "A notebook cover is typically made of materials that are not designed for ink absorption.",
#         "conclusion": "Using a notebook cover does not effectively contribute to absorbing extra ink."
#       }
#     ],
#     "and_logic_evaluation": "While the ink-drying cloth is effective, the notebook cover does not contribute to the goal of absorbing ink.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in drying the ink.",
#         "premise": "An ink-drying cloth is designed to absorb moisture and can help in drying excess ink quickly.",
#         "conclusion": "Using an ink-drying cloth effectively aids in drying and absorbing extra ink."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Writing surface does not absorb ink effectively.",
#         "premise": "A writing surface, such as a desk or table, is not designed to absorb ink and may lead to ink spreading rather than absorption.",
#         "conclusion": "Using a writing surface does not effectively contribute to absorbing extra ink."
#       }
#     ],
#     "and_logic_evaluation": "While the ink-drying cloth is effective, the writing surface does not contribute to the goal of absorbing ink.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "People effectively absorb extra ink from a fountain pen.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Ink-drying cloth aids in drying the ink.",
#         "premise": "An ink-drying cloth is designed to absorb moisture and can help in drying excess ink quickly.",
#         "conclusion": "Using an ink-drying cloth effectively aids in drying and absorbing extra ink."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Fabric swatch may absorb ink but is not optimal.",
#         "premise": "A fabric swatch can absorb some ink, but it may not be as effective as specialized absorbent materials.",
#         "conclusion": "Using a fabric swatch may help but is not the most effective method for absorbing extra ink."
#       }
#     ],
#     "and_logic_evaluation": "The ink-drying cloth is effective, but the fabric swatch is not the optimal choice for ink absorption.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 10 ---
# Question: Where is a business restaurant likely to be located?
# Correct Answer: B
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "A business restaurant is likely to be located in areas with high foot traffic.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "University campuses attract students and faculty who need dining options.",
#         "premise": "University campuses have a large population of students and staff who require convenient dining options.",
#         "conclusion": "A business restaurant at a university campus would likely have a steady stream of customers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Suburban neighborhoods may not have the same density of potential customers.",
#         "premise": "Suburban neighborhoods often have lower population density and may not provide enough foot traffic for a business restaurant.",
#         "conclusion": "While suburban neighborhoods can have restaurants, they may not be ideal for a business-focused restaurant."
#       }
#     ],
#     "and_logic_evaluation": "A university campus provides a strong customer base, BUT suburban neighborhoods may not offer sufficient foot traffic.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "A business restaurant is likely to be located in areas with high foot traffic.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Business park entrances are frequented by employees looking for lunch options.",
#         "premise": "Employees in business parks often seek nearby dining options during work hours.",
#         "conclusion": "A restaurant at a business park entrance would likely attract a consistent customer base."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Conference venues attract visitors who may need dining options.",
#         "premise": "Conference venues host events that bring in attendees who often look for nearby restaurants.",
#         "conclusion": "A restaurant near a conference venue would likely benefit from increased foot traffic during events."
#       }
#     ],
#     "and_logic_evaluation": "Both business park entrances and conference venues provide high foot traffic and potential customers, making this a strong combination.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "A business restaurant is likely to be located in areas with high foot traffic.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Corporate office clusters have a high concentration of employees needing lunch options.",
#         "premise": "Employees in corporate office clusters often seek convenient dining options during work hours.",
#         "conclusion": "A restaurant in a corporate office cluster would likely attract a steady stream of customers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Tourist sites attract visitors who may also seek dining options.",
#         "premise": "Tourist sites bring in a diverse crowd looking for meals, especially during peak visiting hours.",
#         "conclusion": "A restaurant near tourist sites would benefit from increased foot traffic from visitors."
#       }
#     ],
#     "and_logic_evaluation": "Both corporate office clusters and tourist sites provide high foot traffic and potential customers, making this a strong combination.",
#     "therefore": "This combination is also a strong choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "A business restaurant is likely to be located in areas with high foot traffic.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Corporate office clusters have a high concentration of employees needing lunch options.",
#         "premise": "Employees in corporate office clusters often seek convenient dining options during work hours.",
#         "conclusion": "A restaurant in a corporate office cluster would likely attract a steady stream of customers."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Shopping malls attract a diverse crowd looking for dining options.",
#         "premise": "Shopping malls have a high volume of visitors who often look for places to eat while shopping.",
#         "conclusion": "A restaurant inside a shopping mall would likely benefit from high foot traffic."
#       }
#     ],
#     "and_logic_evaluation": "Both corporate office clusters and shopping malls provide high foot traffic and potential customers, making this a strong combination.",
#     "therefore": "This combination is also a strong choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 11 ---
# Question: Where do you put your grapes just before checking out?
# Correct Answer: C
# Predicted Answer: B
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Temporary cart space is used for holding items.",
#         "premise": "A temporary cart space is designed for holding items while shopping.",
#         "conclusion": "Using temporary cart space is appropriate for holding grapes before checkout."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Refrigerator section is suitable for grapes.",
#         "premise": "The refrigerator section is meant for perishable items that need to be kept cool.",
#         "conclusion": "Placing grapes in the refrigerator section is suitable for their preservation."
#       }
#     ],
#     "and_logic_evaluation": "Using temporary cart space is appropriate for holding grapes, AND the refrigerator section is suitable for their preservation. However, placing grapes in the refrigerator section is not practical just before checkout.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Produce section holder is designed for fruits.",
#         "premise": "The produce section holder is specifically designed to hold fresh fruits like grapes.",
#         "conclusion": "Using the produce section holder is appropriate for storing grapes."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal bag is used for carrying items.",
#         "premise": "A personal bag is typically used to carry purchased items, including grapes.",
#         "conclusion": "Placing grapes in a personal bag is suitable for carrying them to checkout."
#       }
#     ],
#     "and_logic_evaluation": "Using the produce section holder is appropriate for grapes, AND placing them in a personal bag is suitable for carrying them to checkout. Both actions work together effectively.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Checkout conveyor is for finalizing purchases.",
#         "premise": "The checkout conveyor is where items are placed for scanning and payment.",
#         "conclusion": "Placing grapes on the checkout conveyor is appropriate just before checkout."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Produce section holder is designed for fruits.",
#         "premise": "The produce section holder is specifically designed to hold fresh fruits like grapes.",
#         "conclusion": "Using the produce section holder is appropriate for storing grapes."
#       }
#     ],
#     "and_logic_evaluation": "Placing grapes on the checkout conveyor is appropriate for finalizing purchases, BUT using the produce section holder is not relevant just before checkout.",
#     "therefore": "This combination is contradictory and not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Grapes are stored appropriately before checkout.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Refrigerator section is suitable for grapes.",
#         "premise": "The refrigerator section is meant for perishable items that need to be kept cool.",
#         "conclusion": "Placing grapes in the refrigerator section is suitable for their preservation."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Personal bag is used for carrying items.",
#         "premise": "A personal bag is typically used to carry purchased items, including grapes.",
#         "conclusion": "Placing grapes in a personal bag is suitable for carrying them to checkout."
#       }
#     ],
#     "and_logic_evaluation": "Placing grapes in the refrigerator section is suitable for their preservation, BUT using a personal bag is more appropriate for carrying them to checkout. However, the refrigerator section is not practical just before checkout.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 12 ---
# Question: Before getting a divorce, what did the wife feel who was doing all the work?
# Correct Answer: D
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The wife feels conflicted emotions before divorce.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Frustration from doing all the work.",
#         "premise": "The wife feels overwhelmed and unappreciated due to carrying the majority of the responsibilities in the relationship.",
#         "conclusion": "Frustration is a valid emotion stemming from the imbalance in workload."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Hope for change in the relationship.",
#         "premise": "Despite her frustration, the wife may still believe that her partner can change and that the relationship can improve.",
# ...
#       }
#     ],
#     "and_logic_evaluation": "Visitor check-in is a valid entrance, BUT the loading dock is not suitable for general access. This combination does not fully satisfy the goal.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The person uses an entrance other than the back entrance.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Main entryway is a valid entrance.",
#         "premise": "The main entryway is typically the primary entrance for visitors and does not involve using the back entrance.",
#         "conclusion": "Using the main entryway satisfies the requirement of not using the back entrance."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Visitor check-in is also a valid entrance.",
#         "premise": "Visitor check-in is accessible for guests and does not involve using the back entrance.",
#         "conclusion": "Using visitor check-in also satisfies the requirement of not using the back entrance."
#       }
#     ],
#     "and_logic_evaluation": "Both the main entryway and visitor check-in are valid entrances that do not involve using the back entrance. This combination fully satisfies the goal.",
#     "therefore": "This combination is the correct choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The person uses an entrance other than the back entrance.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Main entryway is a valid entrance.",
#         "premise": "The main entryway is typically the primary entrance for visitors and does not involve using the back entrance.",
#         "conclusion": "Using the main entryway satisfies the requirement of not using the back entrance."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Loading dock is not a valid entrance for general access.",
#         "premise": "The loading dock is primarily used for deliveries and service access, not for general public entry.",
#         "conclusion": "Using the loading dock does not meet the requirement for a valid entrance for visitors."
#       }
#     ],
#     "and_logic_evaluation": "Main entryway is a valid entrance, BUT the loading dock is not suitable for general access. This combination does not fully satisfy the goal.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The person uses an entrance other than the back entrance.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Loading dock is not a valid entrance for general access.",
#         "premise": "The loading dock is primarily used for deliveries and service access, not for general public entry.",
#         "conclusion": "Using the loading dock does not meet the requirement for a valid entrance for visitors."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Maintenance route is not a valid entrance for general access.",
#         "premise": "The maintenance route is typically restricted to staff and not intended for visitor access.",
#         "conclusion": "Using the maintenance route does not meet the requirement for a valid entrance for visitors."
#       }
#     ],
#     "and_logic_evaluation": "Both the loading dock and maintenance route are not suitable for general access. This combination fails to provide a valid entrance.",
#     "therefore": "This combination is not the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 23 ---
# Question: You can share files with someone if you have a connection to a what?
# Correct Answer: C
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "You can share files with someone",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A data transfer service is available",
#         "premise": "A data transfer service allows users to send and receive files over the internet.",
#         "conclusion": "Having a data transfer service enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "An internet caf\u00e9 provides access to computers and the internet",
#         "premise": "An internet caf\u00e9 offers public access to computers and internet services, facilitating file sharing.",
#         "conclusion": "An internet caf\u00e9 can support file sharing by providing necessary technology."
#       }
#     ],
#     "and_logic_evaluation": "A data transfer service allows for file sharing AND an internet caf\u00e9 provides the necessary access to do so. Both factors work together to enable file sharing.",
#     "therefore": "This combination is a valid choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "You can share files with someone",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A data transfer service is available",
#         "premise": "A data transfer service allows users to send and receive files over the internet.",
#         "conclusion": "Having a data transfer service enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A public library provides access to computers and the internet",
#         "premise": "A public library offers public access to computers and internet services, facilitating file sharing.",
#         "conclusion": "A public library can support file sharing by providing necessary technology."
#       }
#     ],
#     "and_logic_evaluation": "A data transfer service allows for file sharing AND a public library provides the necessary access to do so. Both factors work together to enable file sharing.",
#     "therefore": "This combination is a valid choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "You can share files with someone",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A file-sharing network is available",
#         "premise": "A file-sharing network allows users to share files directly with each other over the internet.",
#         "conclusion": "Having a file-sharing network enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A digital collaboration platform facilitates file sharing",
#         "premise": "A digital collaboration platform provides tools for users to share files and work together online.",
#         "conclusion": "A digital collaboration platform enhances the ability to share files."
#       }
#     ],
#     "and_logic_evaluation": "A file-sharing network allows for direct file sharing AND a digital collaboration platform enhances this capability. Both factors work together to enable file sharing.",
#     "therefore": "This combination is a valid choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "You can share files with someone",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "A file-sharing network is available",
#         "premise": "A file-sharing network allows users to share files directly with each other over the internet.",
#         "conclusion": "Having a file-sharing network enables file sharing."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "A public library provides access to computers and the internet",
#         "premise": "A public library offers public access to computers and internet services, facilitating file sharing.",
#         "conclusion": "A public library can support file sharing by providing necessary technology."
#       }
#     ],
#     "and_logic_evaluation": "A file-sharing network allows for direct file sharing AND a public library provides the necessary access to do so. Both factors work together to enable file sharing.",
#     "therefore": "This combination is a valid choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 24 ---
# Question: The accelerator was controlled via a hand throttle, and the foot pedals controlled the steering in the small what?
# Correct Answer: D
# Predicted Answer: D
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "The vehicle is controlled effectively with the specified mechanisms.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in a light aircraft.",
#         "premise": "Light aircraft typically use hand throttles for controlling engine power and speed.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for a light aircraft."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in an electric scooter.",
#         "premise": "Electric scooters generally use handlebars for steering, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in an electric scooter."
#       }
#     ],
#     "and_logic_evaluation": "The hand throttle is suitable for a light aircraft, BUT foot pedals do not control steering in an electric scooter.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "B",
#     "hypothesis": "The vehicle is controlled effectively with the specified mechanisms.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in a personal drone.",
#         "premise": "Personal drones typically use joysticks or remote controls, not hand throttles.",
#         "conclusion": "Using a hand throttle for acceleration is not appropriate for a personal drone."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in a cargo ship.",
#         "premise": "Cargo ships are steered using a wheel or joystick, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in a cargo ship."
#       }
#     ],
#     "and_logic_evaluation": "Neither the hand throttle for a personal drone nor foot pedals for a cargo ship are appropriate, making this combination ineffective.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "C",
#     "hypothesis": "The vehicle is controlled effectively with the specified mechanisms.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in a remote vehicle.",
#         "premise": "Remote vehicles can use hand throttles for acceleration, depending on the design.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for a remote vehicle."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in a sports car.",
#         "premise": "Sports cars typically use a steering wheel for direction control, not foot pedals.",
#         "conclusion": "Foot pedals do not control steering in a sports car."
#       }
#     ],
#     "and_logic_evaluation": "The hand throttle can be suitable for a remote vehicle, BUT foot pedals do not control steering in a sports car.",
#     "therefore": "This combination is not the best choice."
#   },
#   {
#     "option": "D",
#     "hypothesis": "The vehicle is controlled effectively with the specified mechanisms.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Hand throttle controls acceleration in a light aircraft.",
#         "premise": "Light aircraft typically use hand throttles for controlling engine power and speed.",
#         "conclusion": "Using a hand throttle for acceleration is appropriate for a light aircraft."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Foot pedals control steering in a remote vehicle.",
#         "premise": "Some remote vehicles can be designed to use foot pedals for steering, depending on the model.",
#         "conclusion": "Foot pedals can control steering in certain types of remote vehicles."
#       }
#     ],
#     "and_logic_evaluation": "Both the hand throttle for a light aircraft and foot pedals for a remote vehicle can be appropriate, making this combination effective.",
#     "therefore": "This combination is the best choice."
#   }
# ]
# --------------------------------------------------
#
# --- Question 25 ---
# Question: Sean was lying about the body, but he was very scared.  He constantly worried about what?
# Correct Answer: A
# Predicted Answer: C
#
# Reasoning Breakdown (JSON):
# [
#   {
#     "option": "A",
#     "hypothesis": "Sean is worried about the consequences of his lies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Potential repercussions of lying.",
#         "premise": "Lying can lead to various negative outcomes, including legal issues or personal consequences.",
#         "conclusion": "Sean is likely worried about the potential repercussions of his lies."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Losing friends' trust.",
#         "premise": "Lying can damage relationships, leading to a loss of trust among friends.",
#         "conclusion": "Sean is also likely worried about losing the trust of his friends due to his dishonesty."
#       }
#     ],
#     "and_logic_evaluation": "Both potential repercussions and losing friends' trust are valid concerns for someone who is lying and scared.",
#     "therefore": "This combination effectively captures Sean's worries."
#   },
#   {
#     "option": "B",
#     "hypothesis": "Sean is worried about managing the situation.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Legal advice.",
#         "premise": "Seeking legal advice indicates concern about potential legal consequences of his actions.",
#         "conclusion": "Sean may be worried about needing legal advice due to his lies."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Conflict resolution.",
#         "premise": "Conflict resolution suggests that Sean is trying to manage interpersonal issues arising from his lies.",
#         "conclusion": "Sean is also concerned about resolving conflicts that may arise from his dishonesty."
#       }
#     ],
#     "and_logic_evaluation": "While both legal advice and conflict resolution are relevant, they do not directly reflect the emotional aspect of Sean's fear regarding his lies.",
#     "therefore": "This combination does not fully capture Sean's emotional worries."
#   },
#   {
#     "option": "C",
#     "hypothesis": "Sean is worried about being exposed.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Being discovered.",
#         "premise": "Fear of being discovered indicates a concern about the consequences of his lies being revealed.",
#         "conclusion": "Sean is likely worried about being found out for his dishonesty."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Negative attention.",
#         "premise": "Negative attention can arise from being discovered, leading to social or personal repercussions.",
#         "conclusion": "Sean is also worried about the negative attention that could come from being exposed."
#       }
#     ],
#     "and_logic_evaluation": "Both being discovered and negative attention are directly related to Sean's fear of the consequences of his lies.",
#     "therefore": "This combination effectively captures Sean's worries."
#   },
#   {
#     "option": "D",
#     "hypothesis": "Sean is worried about the fallout from his lies.",
#     "sub_hypotheses": [
#       {
#         "id": "SubH 1",
#         "factor": "Losing friends' trust.",
#         "premise": "Losing friends' trust is a significant concern for someone who has lied.",
#         "conclusion": "Sean is likely worried about the impact of his lies on his friendships."
#       },
#       {
#         "id": "SubH 2",
#         "factor": "Legal advice.",
#         "premise": "Seeking legal advice indicates concern about potential legal consequences of his actions.",
#         "conclusion": "Sean may also be worried about needing legal advice due to his lies."
#       }
#     ],
#     "and_logic_evaluation": "While losing friends' trust is a valid concern, legal advice does not directly relate to the emotional aspect of Sean's fear regarding his lies.",
#     "therefore": "This combination does not fully capture Sean's emotional worries."
#   }
# ]
# --------------------------------------------------
