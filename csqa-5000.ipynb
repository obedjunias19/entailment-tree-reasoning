# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# import os
# import json
# import time
# import pandas as pd
# import random
# from openai import OpenAI, RateLimitError
# from tenacity import retry, wait_random_exponential, stop_after_attempt
# from datasets import load_dataset
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()

# # --- 1. Setup and API Call Functions ---

# openai_key = user_secrets.get_secret("openai")
# if not openai_key:
#     raise ValueError("OPENAI_API_KEY environment variable not set.")
# client = OpenAI(api_key=openai_key)


# def call_gpt4o_mini(messages):
#     """Sends a prompt to the GPT-4o-mini API with robustness for errors."""
#     try:
#         response = client.chat.completions.create(
#             model="gpt-4o-mini",
#             messages=messages,
#             response_format={"type": "json_object"},
#             temperature=0.7,
#             n=1
#         )
#         content = response.choices[0].message.content
#         return json.loads(content)
#     except RateLimitError as e:
#         print(f"Rate limit error: {e}. Retrying...")
#         raise
#     except json.JSONDecodeError as e:
#         print(f"Received invalid JSON from API: {e}. Retrying...")
#         raise e
#     except Exception as e:
#         print(f"An unexpected error occurred during the API call: {e}")
#         raise e

# # --- 2. Data Loading and Filtering ---

# def load_and_filter_scienceqa_data(subset_name="natural science"):
#     """
#     Loads the ScienceQA dataset, filters for a specific subset, and then
#     further filters for text-only questions with a valid lecture/solution context.
#     """
#     print("Loading ScienceQA dataset...")
#     ds = load_dataset("derek-thomas/ScienceQA")
#     df = ds['train'].to_pandas()
#     df = df[df['subject'] == subset_name].iloc[:50]

#     text_only_df = df[df['image'].isnull()].copy()

#     def build_context(row):
#         context_parts = []
#         if pd.notna(row['lecture']) and len(str(row['lecture'])) > 0:
#             context_parts.append(str(row['lecture']))
#         if pd.notna(row['solution']) and len(str(row['solution'])) > 0:
#             context_parts.append(str(row['solution']))
#         if pd.notna(row['hint']) and len(str(row['hint'])) > 0:
#             # Use 'Required Context:' to explicitly tell the model this is important
#             context_parts.append('Required Context: ' + str(row['hint']))
#         return ' '.join(context_parts)

#     text_only_df['text_context'] = text_only_df.apply(build_context, axis=1)

#     # Filter out rows where the combined context is empty
#     text_only_df = text_only_df[text_only_df['text_context'].str.len() > 0]

#     print(f"Loaded and filtered {len(text_only_df)} text-only questions.")
#     return text_only_df

# # --- 3. Revised Single-Prompt Function with Constraints ---

# def construct_single_stage_prompt(context):
#     """
#     Constructs a single prompt to generate a question, options, and distractors
#     with strong constraints for thematic coherence and grounding.
#     """
#     user_content = f"""
#     You are an expert at creating high-quality, complex multiple-choice questions.

#     Your task is to generate one question based on the provided context. The correct answer must be a single option that combines two or more facts using a logical operator ("and" or "or"). The distractors must be plausible but factually incorrect.

#     Let's think step by step:
#     1.  Read the context carefully and identify a specific thematic category (e.g., "states of matter," "living organisms").
#     2.  If the context contains "**Required Context:**", this information is critical.
#     3.  From the context, extract a set of independent, atomic facts. Categorize these as either "Correct Facts" or "Incorrect Facts" (plausible but wrong claims).
#     4.  Select a subset of the "Correct Facts" and combine them into a single, compound correct option using "and" or "or."
#     5.  Formulate a concise question that relies on this combined logic.
#     6.  Create 4-6 options in total. The correct option will be one of these. The distractors can be either "Incorrect Facts" or compound statements made from mixing correct and incorrect facts.
#     7.  Randomly assign a letter (A, B, C, D, E, F) to the correct option. 
#     8.  Format the final output as a single JSON object.

#     Strict Constraints:
#     -   **Fact-Grounded:** The entire question, all facts, and all options must be strictly derived from the context.
#     -   **No Pronouns:** All options must use proper subject names or descriptive phrases (e.g., "solids" instead of "they").
#     -   **No Repetition:** The correct option MUST be a novel combination of facts. It must NOT be a direct copy of a compound statement from the context.
#     -   **Randomized Correct Answer:** The `correct_answer_label` must be randomly assigned and not always 'A'.
#     -   **Multiple Options:** Generate 4-6 options.
#     -   **JSON Format:** The final output must be a single JSON object with the following keys: `correct_facts`, `incorrect_facts`, `question`, `choices`, `correct_answer_label`, and `logical_structure`.

#     Context:
#     {context}

#     Output JSON Example:
#     {{
#       "correct_facts": [
#         "Solids have a definite shape.",
#         "Solids have a definite volume.",
#         "Liquids take the shape of their container."
#       ],
#       "incorrect_facts": [
#         "Solids can be bent easily.",
#         "Liquids have a definite shape."
#       ],
#       "question": "Which of the following describes the key characteristics of solids and liquids?",
#       "choices": [
#         "A. Solids have a definite shape and liquids have a definite volume.",
#         "B. Liquids have a definite shape and Liquids have a definite volume.",
#         "C. Solids take the shape of their container or solida hhave a definite volume.",
#         "D. Solids have no definite shape."
#       ],
#       "correct_answer_label": "A",
#       "logical_structure": "AND"
#     }}
    
#     {{
#   "correct_facts": [
#     "Solar energy is a renewable resource.",
#     "Wind energy is a renewable resource.",
#     "Solar panels convert sunlight into electricity.",
#     "Wind turbines convert wind into electricity."
#   ],
#   "incorrect_facts": [
#     "Solar energy is a nonrenewable resource.",
#     "Wind turbines convert coal into electricity.",
#     "Solar panels generate energy at night."
#   ],
#   "question": "Which of the following describes a true statement about renewable energy generation?",
#   "choices": [
#     "A. Wind energy is a nonrenewable resource or wind turbines convert coal into electricity.",
#     "B. Solar energy is a nonrenewable resource and solar panels convert sunlight into electricity.",
#     "C. Solar panels convert sunlight into electricity or wind turbines convert wind into electricity.",
#     "D. Solar panels generate energy at night."
#   ],
#   "correct_answer_label": "C",
#   "logical_structure": "OR"
# }}
#     """
#     messages = [
#         {"role": "system", "content": "You are a QA system that strictly follows instructions."},
#         {"role": "user", "content": user_content}
#     ]
#     return messages

# # --- 4. Main Execution Block ---
# def process_single_stage_pipeline(df, output_file_csv):
#     """
#     Orchestrates the single-stage pipeline and saves the final output to a CSV file.
#     """
#     print(f"Starting single-stage pipeline for {len(df)} rows.")
#     final_output_list = []
    
#     for i in range(len(df)):
#         row = df.iloc[i]
        
#         # This is where the model generates the question
#         messages = construct_single_stage_prompt(row['text_context'])
#         try:
#             result = call_gpt4o_mini(messages)
            
#             # This is where we add the metadata to the final output
#             result['original_context'] = row['text_context']
            
#             # Add the hint to the final output if it exists in the original row
#             if pd.notna(row['hint']) and len(str(row['hint'])) > 0:
#                 result['original_hint'] = str(row['hint'])

#             final_output_list.append(result)
#             print(f"  Processed row {i} successfully.")
#         except Exception as e:
#             print(f"  Failed to process row {i}. Skipping.")
#         time.sleep(0.01)

#     final_df = pd.DataFrame(final_output_list)
#     final_df.to_csv(output_file_csv, index=False, encoding='utf-8')
#     print(f"\nProcessing complete. {len(final_output_list)} final results saved to '{output_file_csv}'.")

# if __name__ == '__main__':
#     filtered_df = load_and_filter_scienceqa_data()
#     if not filtered_df.empty:
#         output_csv_file = 'scienceqa_single_stage_generated.csv'
#         process_single_stage_pipeline(filtered_df, output_csv_file)

# %%
# results = pd.read_csv('scienceqa_single_stage_generated.csv')

# %%
# results

# %%
# def print_final_outputs(df):
#     """Prints the final generated questions in a clean, readable format."""
#     print("\n" + "="*50)
#     print("      SAMPLE GENERATED QUESTIONS")
#     print("="*50 + "\n")
    
#     for idx, row in df.iterrows():
#         print(f"--- Question {idx+1} ---")
#         print(f"  Logical Structure: {row.get('logical_structure')}")
#         print(f"  Question: {row.get('question')}")

#         print()
#         print(f"Correct Facts: ",{row['correct_facts']})
#         print(f"Incorrect Facts: ",{row['incorrect_facts']})   
#         print()
#         # Print choices
#         choices = row.get('choices')
#         if isinstance(choices, str):
#             print("  Choices:")
#             print(choices)
        
#         print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
        
#         # Conditionally print the original hint if it exists
#         if 'original_hint' in row and pd.notna(row['original_hint']):
#             print(f"  Original Hint: {row['original_hint']}")

#         print("\n" + "-"*40 + "\n")

# %%
# print_final_outputs(results)

# %%
import os
import json
import time
import pandas as pd
import random
from openai import OpenAI, RateLimitError
from tenacity import retry, wait_random_exponential, stop_after_attempt
from datasets import load_dataset
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

# --- 1. Setup and API Call Functions ---

openai_key = user_secrets.get_secret("openai")
if not openai_key:
    raise ValueError("OPENAI_API_KEY environment variable not set.")
client = OpenAI(api_key=openai_key)


def call_gpt4o_mini(messages):
    """Sends a prompt to the GPT-4o-mini API with robustness for errors."""
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            response_format={"type": "json_object"},
            temperature=0.5,
            n=1
        )
        content = response.choices[0].message.content
        return json.loads(content)
    except RateLimitError as e:
        print(f"Rate limit error: {e}. Retrying...")
        raise
    except json.JSONDecodeError as e:
        print(f"Received invalid JSON from API: {e}. Retrying...")
        raise e
    except Exception as e:
        print(f"An unexpected error occurred during the API call: {e}")
        raise e

# --- 2. Data Loading and Filtering ---

def load_and_filter_scienceqa_data(subset_name="natural science"):
    """
    Loads the ScienceQA dataset, filters for a specific subset, and then
    further filters for text-only questions with a valid lecture/solution context.
    """
    print("Loading ScienceQA dataset...")
    ds = load_dataset("tau/commonsense_qa")
    train_df = ds['train'].to_pandas()
    valid_df  = ds['validation'].to_pandas()
    test_df = ds['test'].to_pandas()
    df = pd.concat([train_df, valid_df, test_df], ignore_index=True)
    print(df.shape)
    
    print(f"Loaded and filtered {len(df)} text-only questions.")
    return df.iloc[:20]

# --- 3. Revised Single-Prompt Function with Constraints ---
def construct_single_stage_options_prompt(question, correct_answers, incorrect_answers, context=""):
    """
    Single-stage fallback: directly produce AND/OR options with multi-level subclaims.
    Less controllable than two-stage, but convenient.
    """
    user_content = f"""
You will produce multi-step AND/OR options for a multiple-choice item.

INPUT
- Question: {question}
- Correct Atomic Facts: {correct_answers}
- Incorrect Atomic Facts: {incorrect_answers}
- Optional background (do NOT reference explicitly): {context}

REQUIREMENTS
- Produce >=2 correct and 3–4 incorrect options.
- Each option must be exactly: <Subclaim A> AND/OR <Subclaim B>.
- Each Subclaim (A, B) must itself be multi-level by merging ≥2 correct atomic facts (for correct options).
- Remember each subclain have to be multi-step and multi-level where one has to reason over the question and the answer to get to the correct answer.
- Incorrect options must integrate at least one incorrect atomic fact (or misuse AND/OR) to create a plausible but false composite.
- No “based on the context” phrasing. No copy/paste of facts.

OUTPUT (JSON only):
{{
  "question": "<repeat question>",
  "correct_combinations": ["...", "..."],
  "incorrect_combinations": ["...", "...", "..."],
  "notes_private": "Very brief note on how each subclaim merged multiple facts and where a flaw was introduced."
}}
Return JSON only.
"""
    messages = [
        {"role": "system", "content": "You are a QA system that composes multi-step options and returns strict JSON only."},
        {"role": "user", "content": user_content}
    ]
    return messages

def generate_robust_logical_options(question, context=""):
    user_content = f"""
Generate individual options for a question that will later be combined using logical operators.

QUESTION: {question}
CONTEXT: {context}

TASK: Create two separate pools of individual statements/actions.

CORRECT OPTIONS (Generate 6):
- Use 3-5 word action phrases or method descriptions
- Each must require multi-step reasoning to evaluate  
- NO explanations of why they work - force model to reason
- Test genuine understanding, not keyword matching
- Examples: "wearing insulating layers", "generating external heat", "reducing air circulation"

INCORRECT OPTIONS (Generate 8):
- Include deceptive/plausible wrong answers
- 30% should be contextually wrong (works in different situation)
- 30% should be mechanism failures (sounds right but doesn't work)
- 40% should be obvious contradictions (for reliability check)
- NO obviously silly answers - maintain plausibility

QUALITY REQUIREMENTS:
- Each option must force: Action → Physical Effect → Goal Achievement reasoning
- Include edge cases that test deep vs surface understanding
- Require distinguishing "feels right" from "actually works"
- Test causal mechanism understanding, not just correlation

OUTPUT (JSON):
{{
  "question": "{question}",
  "correct_individual_options": [
    "action/method 1",
    "action/method 2", 
    "action/method 3",
    "action/method 4",
    "action/method 5",
    "action/method 6"
  ],
  "incorrect_individual_options": [
    "plausible wrong 1",
    "contextual wrong 1", 
    "mechanism failure 1",
    "obvious wrong 1",
    "plausible wrong 2",
    "contextual wrong 2",
    "mechanism failure 2", 
    "obvious wrong 3"
  ]
}}

Generate individual statements only - combinations will be created separately.
"""
    
    messages = [
        {
            "role": "system", 
            "content": "You generate individual options for logical reasoning tests. Each option must be evaluable independently. Return only valid JSON."
        },
        {
            "role": "user", 
            "content": user_content
        }
    ]
    return messages

def generate_robust_logical_options(question, existing_correct, existing_incorrect, context=""):
    user_content = f"""
You are an expert test designer who creates challenging logical reasoning assessments. Your specialty is crafting challenging options for high school students with deep understanding from those using shallow heuristics.

QUESTION: {question}
EXISTING CORRECT: {existing_correct}
EXISTING INCORRECT: {existing_incorrect}

TASK: Expand and improve the existing option pools using the following instructions, making the selection challenging even for high school students.

ADDITIONAL CORRECT OPTIONS Rubric (Generate 3-5 more):
- Use word action phrases or method descriptions
- Should complement existing correct options (different approaches/mechanisms)
- Each must require multi-step causal reasoning to evaluate
- NO explanations of why they work 
- Test genuine understanding, not keyword matching

ADDITIONAL INCORRECT OPTIONS Rubric (Generate 3-5 more):
- Include deceptive and plausible wrong answers
- Should complement existing incorrect options
- Mix of: contextually wrong, mechanism failures, obvious contradictions

DISTRACTOR DIFFICULTY LEVELS:
- 50% Near-miss options: Work in similar contexts but fail due to subtle mechanism differences
- 30% Partial truth options: Contain correct elements but missing critical components  
- 20% Edge case failures: Seem reasonable but fail under specific constraints

DECEPTIVE QUALITY PATTERNS:
- Use domain-appropriate terminology that sounds expert-level
- Include options that work for related but different goals
- Create options where timing/context makes them invalid
- Generate options that have worked historically but don't work now
- Include options where the mechanism is partially correct but incomplete
- You may include options that fail at a later step of reasoning. (Recommended)

AVOID OBVIOUS GIVEAWAYS:
- No clearly wrong domains ("gym" for "finding people outdoors")
- No obviously impossible actions ("flying" for human travel)
- No silly/joke options that immediately stand out
- No options that contradict basic science or common sense
- Avoid shallow wrong answers that can be rejected with a keyword check.

QUALITY REQUIREMENTS:
- Each option must force: Multi Action → Multi Effect → Goal Achievement reasoning
- Include edge cases that test deep vs surface understanding.
- Test causal mechanism understanding, not just correlation.
- Each option must require connecting more than 2 distinct concepts to evaluate.
- You can include constraints that make plausible options actually invalid.
- You may include options requiring understanding real-world context and underlying implicit goals.
- Options in the same bin shouldn't mean the same.
- The answers should be directly factual, instead force the reader to think and reason deeply. (Most IMPORTANT)
- WORD LIMIT: Keep all new options the same length or shorter than your longest existing correct or incorrect option. Try to maintain the same word length for both correct and incorrect new options.

FORBIDDEN PATTERNS:
- Contains explanatory phrases
- Includes location descriptions ("park with scenic view" → just "park")
- Uses conjunctions within options ("and", "but", "or" within single option)
- Provides reasoning ("because", "since", "due to")

OUTPUT (JSON):
{{
  "question": "{question}",
  "expanded_correct_options": [
    "existing correct option 1",
    "existing correct option 2", 
    "new correct option 1",
    "new correct option 2",
    "new correct option 3"
  ],
  "expanded_incorrect_options": [
    "existing wrong option",
    "existing wrong option",
    "plausible wrong option",
    "contextual wrong option", 
    "mechanism failure option",
    "obvious wrong option",
    "plausible wrong option",
    "contextual wrong option",
    "mechanism failure option", 
    "obvious wrong option"
  ]
}}

Build upon existing options to create a more comprehensive and challenging set.
"""
    messages = [
        {
            "role": "system", 
            "content": "You are an expert test designer who creates challenging logical reasoning assessments. Each option must be evaluable independently. Return only valid JSON."
        },
        {
            "role": "user", 
            "content": user_content
        }
    ]
    return messages


# --- 4. Main Execution Block ---
def process_single_stage_pipeline(df, output_file_csv):
    """
    Orchestrates the single-stage pipeline and saves the final output to a CSV file.
    """
    print(f"Starting single-stage pipeline for {len(df)} rows.")
    final_output_list = []
    
    for i in range(len(df)):
        row = df.iloc[i]
        question = row['question']
        labels = row['choices']['label']
        texts = row['choices']['text']
        
        correct_label = row['answerKey']  # Assuming this exists
        correct_answer = texts[labels == correct_label][0]
        
        # Get incorrect answers
        incorrect_answers = texts[labels != correct_label]
        
        # This is where the model generates the question
        messages = generate_robust_logical_options(question, correct_answer, incorrect_answers)
        try:
            result = call_gpt4o_mini(messages)
            
            # This is where we add the metadata to the final output
            # result['original_context'] = row['text_context']
            
            # Add the hint to the final output if it exists in the original row
            # if pd.notna(row['hint']) and len(str(row['hint'])) > 0:
                # result['original_hint'] = str(row['hint'])

            final_output_list.append(result)
            print(f"  Processed row {i} successfully.")
        except Exception as e:
            print(f"  Failed to process row {i}. Skipping.")
        time.sleep(0.01)

    final_df = pd.DataFrame(final_output_list)
    final_df.to_csv(output_file_csv, index=False, encoding='utf-8')
    print(f"\nProcessing complete. {len(final_output_list)} final results saved to '{output_file_csv}'.")

if __name__ == '__main__':
    filtered_df = load_and_filter_scienceqa_data()
    if not filtered_df.empty:
        output_csv_file = 'csqa_single_stage_generated.csv'
        process_single_stage_pipeline(filtered_df, output_csv_file)
# Out:
# Loading ScienceQA dataset...
# (12102, 5)
# Loaded and filtered 12102 text-only questions.
# Starting single-stage pipeline for 20 rows.
#   Processed row 0 successfully.
#   Processed row 1 successfully.
#   Processed row 2 successfully.
#   Processed row 3 successfully.
#   Processed row 4 successfully.
#   Processed row 5 successfully.
#   Processed row 6 successfully.
#   Processed row 7 successfully.
#   Processed row 8 successfully.
#   Processed row 9 successfully.
#   Processed row 10 successfully.
#   Processed row 11 successfully.
#   Processed row 12 successfully.
#   Processed row 13 successfully.
#   Processed row 14 successfully.
#   Processed row 15 successfully.
#   Processed row 16 successfully.
#   Processed row 17 successfully.
#   Processed row 18 successfully.
#   Processed row 19 successfully.
#
# Processing complete. 20 final results saved to 'csqa_single_stage_generated.csv'.

# %%
df = pd.read_csv('/kaggle/working/csqa_single_stage_generated.csv')
df.head()
# Out:
#                                             question  \
# 0  The sanctions against the school were a punish...
# 1  Sammy wanted to go to where the people were.  ...
# 2  To locate a choker not located in a jewelry bo...
# 3  Google Maps and other highway and street GPS s...
# 4  The fox walked from the city into the forest, ...
#
#                             expanded_correct_options  \
# 0  ['ignore', 'overlook', 'diminish', 'undermine'...
# 1  ['populated areas', 'gathering events', 'socia...
# 2  ['jewelry store', 'artisan market', 'custom ac...
# 3  ['atlas', 'manual navigation techniques', 'rou...
# 4  ['natural habitat', 'hunting grounds', 'shelte...
#
#                           expanded_incorrect_options
# 0  ['enforce', 'authoritarian', 'yell at', 'avoid...
# 1  ['race track', 'the desert', 'apartment', 'roa...
# 2  ['neck', 'jewelry box', 'jewelry box', 'boutiq...
# 3  ['united states', 'mexico', 'countryside', 'oc...
# 4  ['pretty flowers.', 'hen house', 'storybook', ...

# %%
print("\n" + "="*50)
print("      SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#       SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'overlook', 'undermine the progress', 'stifle the improvements', 'thwart the initiatives', 'diminish the reforms']"}
# Incorrect Facts:  {"['enforce', 'authoritarian', 'yell at', 'avoid', 'boost the morale', 'support the transformation', 'accelerate the changes', 'validate the efforts', 'encourage the development', 'facilitate the growth']"}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'public events or gatherings', 'community centers or clubs', 'concerts or festivals', 'shopping malls or markets']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'abandoned buildings or ruins', 'isolated beaches or coves', 'remote mountain trails', 'private property without access', 'empty parking lots', 'derelict neighborhoods']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'online marketplace', 'local artisan fair', 'antique shop', 'craft supply store']"}
# Incorrect Facts:  {'[\'neck\', \'jewelry box\', \'jewelry box\', \'boutique\', \'department store accessory aisle\', \'clothing store clearance rack\', \'gift shop near the beach\', "friend\'s jewelry collection", \'supermarket checkout line\', \'thrift store without jewelry section\']'}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'detailed road maps', 'printed navigation guides', 'local knowledge of routes', 'manual route planning']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'static road signs', 'personal diaries of travel', 'travel brochures from the 1990s', 'hand-drawn maps', 'GPS satellites', 'road construction barriers']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'food sources hidden among the trees', 'shelter from urban predators', 'a place to raise its young', 'water sources for hydration']"}
# Incorrect Facts:  {"['pretty flowers.', 'hen house', 'storybook', 'dense forest', 'a cozy home in the city', 'to escape the rain in a cave', 'to find a lost friend', 'to gather materials for a nest', 'to attend a gathering of other animals', 'to chase after a car']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'streaming device connected via HDMI', 'cable box for satellite service', 'home theater system with wired speakers', 'gaming console using wired internet connection']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'wireless speaker system relying on Bluetooth', 'portable media player without network access', 'digital photo frame displaying local images', 'smartphone using cellular data only', 'laptop running offline media player', 'projector using battery power']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'traveling for a vacation', 'attending a business conference', 'heading to a family reunion', 'going on a hiking trip']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'heading to a local coffee shop', 'going to a car repair shop', 'visiting a museum exhibition', 'attending a wedding in the same city', 'going to a grocery store', 'heading to a nearby park']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'cold storage unit', 'sealed container in the pantry', 'vacuum-sealed bag in the freezer', 'insulated lunchbox left in the car']"}
# Incorrect Facts:  {"['carpet', 'breadbox', 'fridge', 'coach', 'oven that was turned off', 'countertop that was cleaned yesterday', 'storage shed outside', 'dishwasher that was recently used', 'cabinet above the sink', 'backseat of a taxi']"}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'paper towel', 'absorbent cloth', 'specialized ink sponge', 'absorbent notebook page']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'plastic wrap\', \'ceramic dish\', \'wooden desk surface\', \'metal pen holder\', \'cotton ball\', \'pencil eraser\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'near corporate offices', 'within conference centers', 'adjacent to financial districts', 'close to transportation hubs']"}
# Incorrect Facts:  {"['town', 'at hotel', 'mall', 'yellow pages', 'in residential neighborhoods', 'inside amusement parks', 'on remote islands', 'in rural farmlands', 'within shopping districts', 'at tourist attractions']"}
#
#
# ----------------------------------------
#
# --- Question 11 ---
#   Question: Where do you put your grapes just before checking out?
#
# Correct Facts:  {"['grocery cart', 'basket on the checkout counter', 'reusable shopping bag at the register', 'self-checkout machine area', 'near the cashier for easy access']"}
# Incorrect Facts:  {"['mouth', 'super market', 'fruit basket', 'fruit market', 'on the ground next to the cart', 'in a bag left in the car', 'in a different aisle', 'on the conveyor belt before scanning', 'underneath other groceries in the cart', 'in a separate cart for non-food items']"}
#
#
# ----------------------------------------
#
# --- Question 12 ---
#   Question: Before getting a divorce, what did the wife feel who was doing all the work?
#
# Correct Facts:  {"['bitterness', 'overwhelming exhaustion', 'unrecognized sacrifice', 'frustration from imbalance', 'resentment towards neglect']"}
# Incorrect Facts:  {"['harder', 'anguish', 'tears', 'sadness', 'contentment from routine', 'apathy towards responsibilities', 'joy from selflessness', 'indifference to partnership', 'relief from decision-making', 'optimism about the future']"}
#
#
# ----------------------------------------
#
# --- Question 13 ---
#   Question: Johnny sat on a bench and relaxed after doing a lot of work on his hobby.  Where is he?
#
# Correct Facts:  {"['garden', 'park with a lake', 'quiet nature trail', 'community garden area', 'backyard patio']"}
# Incorrect Facts:  {"['state park', 'bus depot', 'gym', 'rest area', 'busy shopping mall', 'crowded city square', 'noisy construction site', 'overpopulated beach', 'isolated mountain peak', 'loud concert venue']"}
#
#
# ----------------------------------------
#
# --- Question 14 ---
#   Question: James was cooling off too quickly. He would die if he didn't find some way to stop what?
#
# Correct Facts:  {"['loss of heat', 'increase body temperature gradually', 'insulate body to retain warmth', 'consume warm fluids to raise core temperature', 'find shelter to reduce exposure to cold', 'engage in physical activity to generate heat']"}
# Incorrect Facts:  {"['revenge', 'expansion', 'relaxation', 'calm down', 'apply ice to body to cool down further', 'take a cold shower to refresh', 'sit in a drafty area to feel better', 'reduce metabolism to conserve energy', 'wear loose clothing to avoid overheating', 'breathe deeply to calm the body']"}
#
#
# ----------------------------------------
#
# --- Question 15 ---
#   Question: Of all the rooms in a house it was his favorite, the aromas always drew him to the what?
#
# Correct Facts:  {"['kitchen', 'the oven baking bread', 'the pot simmering stew', 'the grill cooking burgers', 'the pantry filled with spices']"}
# Incorrect Facts:  {"['yard', 'basement', 'living room', 'garden', 'the bathroom with scented candles', 'the hallway with fresh paint', 'the attic storing old furniture', 'the laundry room with detergent', 'the garage with car oil', 'the bedroom with air fresheners']"}
#
#
# ----------------------------------------
#
# --- Question 16 ---
#   Question: Bill is stuck in marsh when a man comes up to him peaking Cajun, where is he?
#
# Correct Facts:  {"['louisiana', 'swampy bayou region of southern Louisiana', 'navigating through wetlands in the Gulf Coast', 'experiencing a humid marshland typical of Cajun territory', 'trapped in a coastal marsh ecosystem of the southern United States']"}
# Incorrect Facts:  {"['low lands', 'new york', 'forest', 'everglades', 'stuck in a desert area with no water sources', 'lost in a mountainous region far from wetlands', 'caught in an urban park with no marshland nearby', 'trapped in a tundra region with permafrost', 'stranded in a dry savanna with sparse vegetation', 'stuck in a coastal city with no natural marshes']"}
#
#
# ----------------------------------------
#
# --- Question 17 ---
#   Question: What is it called when you slowly cook using a grill?
#
# Correct Facts:  {"['barbeque', 'smoking meat over low heat', 'indirect heat grilling technique', 'slow-roasting on a grill', 'cooking with wood chips for flavor']"}
# Incorrect Facts:  {'[\'backyard\', \'restaurant\', \'crockpot\', "neighbor\'s house", \'grilling on high heat for quick sear\', \'boiling food in a pot\', \'using a microwave for reheating\', \'stir-frying in a pan\', \'baking in an oven\', \'frying in hot oil\']'}
#
#
# ----------------------------------------
#
# --- Question 18 ---
#   Question: What type of person typically contracts illness?
#
# Correct Facts:  {"['elderly person', 'sick person', 'individual with a weakened immune system', 'person with chronic health conditions', 'individual exposed to infectious environments', 'person undergoing chemotherapy']"}
# Incorrect Facts:  {'[\'hospital\', \'head\', "doctor\'s office", \'healthy young adult in a sterile environment\', \'athlete with optimal nutrition\', \'person practicing strict hygiene measures\', \'individual living in a remote area with no exposure\', \'person with high levels of physical fitness\', \'individual who avoids social interactions\', \'person who regularly gets vaccinated\']'}
#
#
# ----------------------------------------
#
# --- Question 19 ---
#   Question: Where would you expect to find a pizzeria while shopping?
#
# Correct Facts:  {"['food court', 'mall dining area', 'near the grocery store', 'within a shopping plaza', 'adjacent to a movie theater']"}
# Incorrect Facts:  {"['chicago', 'street', 'little italy', 'capital cities', 'inside a bookstore', 'at a hardware store', 'next to the electronics section', 'in a parking garage', 'within a clothing outlet', 'above a bank']"}
#
#
# ----------------------------------------
#
# --- Question 20 ---
#   Question: When eating everything on the tasting menu, what does one tend to feel?
#
# Correct Facts:  {"['getting full', 'experiencing flavor overload', 'savoring diverse textures', 'noticing palate fatigue', 'appreciating culinary artistry']"}
# Incorrect Facts:  {"['full stomach', 'gaining weight', 'sick', 'satisfaction', 'feeling light and energetic', 'having an empty plate', 'being unaffected by portion sizes', 'experiencing a sudden craving for more', 'feeling indifferent to the meal', 'losing interest in food']"}
#
#
# ----------------------------------------
#
# --- Question 21 ---
#   Question: What does playing soccer for a long time lead to?
#
# Correct Facts:  {"['getting tired', 'increased muscle soreness', 'enhanced teamwork skills', 'improved cardiovascular endurance', 'heightened strategic thinking']"}
# Incorrect Facts:  {"['excitement', 'fatigue', 'anger', 'hurting', 'immediate weight gain', 'decreased coordination', 'increased likelihood of boredom', 'permanent muscle growth', 'instant energy boost', 'immediate skill mastery']"}
#
#
# ----------------------------------------
#
# --- Question 22 ---
#   Question: Which entrance would you use if you do not want to use the back entrance?
#
# Correct Facts:  {"['main', 'use the side entrance for easier access', 'enter through the front doors to reach the lobby', 'approach the building from the main parking lot entrance', 'utilize the service entrance for direct entry']"}
# Incorrect Facts:  {"['side', 'anterior', 'current', 'front', 'attempt to enter through the basement exit despite it being locked', 'choose the emergency exit which is meant for evacuation only', 'use the exit sign to find an entrance, which leads outside', 'try accessing the roof entrance, which is not meant for public use', 'navigate through the maintenance area, which is restricted', 'enter through the windows, which are sealed shut']"}
#
#
# ----------------------------------------
#
# --- Question 23 ---
#   Question: You can share files with someone if you have a connection to a what?
#
# Correct Facts:  {"['computer network', 'internet service provider', 'peer-to-peer connection', 'cloud storage platform', 'virtual private network']"}
# Incorrect Facts:  {"['freeway', 'radio', 'wires', 'electrical circuit', 'telephone line without internet', 'satellite dish without service', 'local coffee shop without Wi-Fi', 'USB drive left at home', 'public library without a computer', 'walkie-talkie system']"}
#
#
# ----------------------------------------
#
# --- Question 24 ---
#   Question: The accelerator was controller via a hand throttle, and the foot pedals controlled the steering in the small what?
#
# Correct Facts:  {"['airplane', 'helicopter', 'glider', 'drone', 'ultralight aircraft']"}
# Incorrect Facts:  {"['car', 'fuel system', 'accelerate', 'boat', 'bicycle with no gears', 'hovercraft with fixed controls', 'motorcycle with foot throttle', 'submarine with manual steering', 'train with standard controls', 'electric scooter with hand brake']"}
#
#
# ----------------------------------------
#
# --- Question 25 ---
#   Question: Sean was lying about the body, but he was very scared.  He constantly worried about what?
#
# Correct Facts:  {"['being found out', 'the consequences of his lie', 'how to cover his tracks', 'the reactions of those involved', 'the possibility of being accused']"}
# Incorrect Facts:  {"['the reward money', 'hurt feelings', 'problems', 'trouble', 'being praised for his bravery', 'the weather conditions', 'the time of day', 'his favorite TV show', 'a misunderstanding with friends', 'the opinions of strangers']"}
#
#
# ----------------------------------------

# %%
print("\n" + "="*50)
print("    Cog Sci Researcher  SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#     Cog Sci Researcher  SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'dismiss', 'overlook the improvements', 'undermine the progress made', 'negate the positive changes']"}
# Incorrect Facts:  {'[\'enforce\', \'authoritarian\', \'yell at\', \'avoid\', \'validate the efforts\', \'support the initiatives\', \'encourage further changes\', \'strengthen community ties\', \'promote educational success\', "reward the school\'s dedication"]'}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'city parks during events', 'concerts or festivals nearby', 'community centers hosting gatherings', 'busy shopping districts']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'remote cabins in the woods', 'abandoned warehouses', 'isolated beaches', 'empty parking lots', 'closed amusement parks', 'quiet suburban streets']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'craft fair vendor booth', 'online marketplace search', 'local artisan workshop visit', 'thrift store exploration']"}
# Incorrect Facts:  {"['neck', 'jewelry box', 'jewelry box', 'boutique', 'shopping mall food court', 'clothing store clearance rack', 'gift shop near the beach', 'hardware store aisle', 'supermarket checkout line', 'library book section']"}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'roadside assistance services', 'printed navigation guides', 'physical paper maps', 'traditional route planning methods']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'compass usage in navigation', 'traffic light systems', 'weather forecasting tools', 'public transportation schedules', 'local diner recommendations', 'vehicle maintenance manuals']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'food sources like small mammals', 'shelter from urban noise', 'a safe place to raise its young', 'new territory for hunting']"}
# Incorrect Facts:  {"['pretty flowers.', 'hen house', 'storybook', 'dense forest', 'a place to find lost items', 'an escape route from the city', 'a gathering of other animals', 'a scenic viewpoint', 'a place to play', 'a location for a picnic']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'cable box for signal processing', 'satellite receiver for channel access', 'internet modem for streaming services', 'audio receiver for surround sound systems']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'wireless speaker for Bluetooth connectivity', 'streaming device requiring Wi-Fi only', 'computer monitor without cable input', 'projector using only battery power', 'portable media player with no cable connection', 'smartphone for mobile viewing']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'train station', 'bus terminal', 'cruise ship port', 'traveling to a conference', 'attending a music festival']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'going to a local grocery store', 'heading to a construction site', 'visiting a friend in a different city', 'attending a wedding in the park', 'going to a library for research', 'participating in a charity event in the neighborhood']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'fridge', 'cooler', 'pantry', 'storage container']"}
# Incorrect Facts:  {"['carpet', 'breadbox', 'coach', 'garden shed', 'oven', 'under the bed', 'kitchen table', 'dishwasher', 'car trunk', 'attic']"}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'ink absorbent paper', 'pressing a clean cloth against the nib', 'using a paper towel to dab the nib', 'applying a thin layer of tissue to soak up excess ink']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'using a sponge to wipe the nib\', \'placing the pen in a sealed bag\', \'applying pressure with a rubber band\', \'rubbing the nib on a rough surface\', \'holding the pen upside down\', \'submerging the pen in water\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'corporate office area', 'near conference centers', 'within business parks', 'adjacent to trade show venues']"}
# Incorrect Facts:  {"['town', 'at hotel', 'mall', 'yellow pages', 'in residential neighborhoods', 'inside amusement parks', 'along tourist attractions', 'within university campuses', 'in isolated rural areas', 'next to gas stations']"}
#
#
# ----------------------------------------
#
# --- Question 11 ---
#   Question: Where do you put your grapes just before checking out?
#
# Correct Facts:  {"['grocery cart', 'shopping basket', 'place in the checkout lane', 'load into a reusable bag', 'set on the conveyor belt']"}
# Incorrect Facts:  {"['mouth', 'super market', 'fruit basket', 'fruit market', 'put in the refrigerator', 'leave in the produce section', 'drop on the floor', 'carry in your hands', 'put in a random aisle', 'set on a shelf']"}
#
#
# ----------------------------------------
#
# --- Question 12 ---
#   Question: Before getting a divorce, what did the wife feel who was doing all the work?
#
# Correct Facts:  {"['bitterness', 'overwhelmed by responsibility', 'resentment towards her partner', 'exhaustion from constant effort', 'disappointment in the relationship']"}
# Incorrect Facts:  {"['harder', 'anguish', 'tears', 'sadness', 'contentment from sacrifice', 'indifference to the situation', 'joy from fulfilling duties', 'relief from decision-making', 'satisfaction in partnership', 'optimism about the future']"}
#
#
# ----------------------------------------
#
# --- Question 13 ---
#   Question: Johnny sat on a bench and relaxed after doing a lot of work on his hobby.  Where is he?
#
# Correct Facts:  {"['garden', 'park with a pond', 'quiet lakeside retreat', 'community garden area', 'scenic overlook with a view']"}
# Incorrect Facts:  {"['state park', 'bus depot', 'gym', 'rest area', 'busy shopping mall', 'construction site nearby', 'crowded city square', 'noisy roadside diner', 'abandoned warehouse', 'interior of a moving vehicle']"}
#
#
# ----------------------------------------
#
# --- Question 14 ---
#   Question: James was cooling off too quickly. He would die if he didn't find some way to stop what?
#
# Correct Facts:  {'[\'loss of heat\', \'preventing rapid temperature drop\', \'increasing ambient temperature around him\', "regulating his body\'s heat retention", \'using insulation to conserve warmth\']'}
# Incorrect Facts:  {"['revenge', 'expansion', 'relaxation', 'calm down', 'increasing his body weight', 'drinking cold water to feel better', 'standing in the shade to cool off', 'wearing heavy clothing to warm up', 'taking deep breaths to stabilize', 'focusing on his mental state']"}
#
#
# ----------------------------------------
#
# --- Question 15 ---
#   Question: Of all the rooms in a house it was his favorite, the aromas always drew him to the what?
#
# Correct Facts:  {"['kitchen', 'pantry filled with spices', 'dining room after a feast', 'baking area with fresh bread', 'grill station during summer cookouts']"}
# Incorrect Facts:  {"['yard', 'basement', 'living room', 'garden', 'bathroom with scented candles', 'bedroom with fresh linens', 'garage with paint fumes', 'hallway with air fresheners', 'office with coffee machine', 'attic with musty boxes']"}
#
#
# ----------------------------------------
#
# --- Question 16 ---
#   Question: Bill is stuck in marsh when a man comes up to him peaking Cajun, where is he?
#
# Correct Facts:  {"['louisiana', 'swamp area known for Cajun culture', 'region with high humidity and wetlands', 'location with diverse wildlife and marshlands', 'area famous for Cajun cuisine and dialect']"}
# Incorrect Facts:  {"['low lands', 'new york', 'forest', 'everglades', 'coastal region with dry terrain', 'urban city with no marshes', 'desert area with scarce vegetation', 'mountainous region far from wetlands', 'tropical island with no swamp', 'artificial lake surrounded by buildings']"}
#
#
# ----------------------------------------
#
# --- Question 17 ---
#   Question: What is it called when you slowly cook using a grill?
#
# Correct Facts:  {"['barbeque', 'smoke the meat over low heat', 'indirect grilling with wood chips', 'slow-cook with charcoal and sauce', 'marinate and grill slowly for tenderness']"}
# Incorrect Facts:  {"['backyard', 'restaurant', 'crockpot', 'grilling on high heat for a quick sear', 'cooking in an oven at high temperature', 'using a microwave to heat leftovers', 'boiling meat in water', 'frying in oil for a crispy finish', 'searing meat on a stovetop', 'using a pressure cooker for rapid cooking']"}
#
#
# ----------------------------------------
#
# --- Question 18 ---
#   Question: What type of person typically contracts illness?
#
# Correct Facts:  {"['elderly person', 'individual with weakened immune system', 'person living in unsanitary conditions', 'frequent traveler exposed to pathogens', 'individual with chronic health conditions']"}
# Incorrect Facts:  {'[\'hospital\', \'head\', \'sick person\', "doctor\'s office", \'young athlete with strong immunity\', \'person with a balanced diet and exercise routine\', \'individual living in a remote, clean environment\', \'person who avoids social interactions\', \'healthy person with regular check-ups\', \'individual who follows strict hygiene practices\']'}
#
#
# ----------------------------------------
#
# --- Question 19 ---
#   Question: Where would you expect to find a pizzeria while shopping?
#
# Correct Facts:  {"['food court', 'shopping plaza with dining options', 'near a supermarket with prepared meals', 'in a mall with family-friendly restaurants', 'adjacent to a movie theater']"}
# Incorrect Facts:  {"['chicago', 'street', 'little italy', 'capital cities', 'inside a bookstore with no food services', 'in a parking lot without any food vendors', 'on a residential street with no commercial activity', 'next to a clothing store with no dining establishments', 'in a warehouse district with only industrial buildings', 'within a gym that only serves health snacks']"}
#
#
# ----------------------------------------
#
# --- Question 20 ---
#   Question: When eating everything on the tasting menu, what does one tend to feel?
#
# Correct Facts:  {"['getting full', 'feeling overwhelmed by flavors', 'experiencing a culinary journey', 'noticing a gradual increase in fullness', 'savoring diverse textures and tastes']"}
# Incorrect Facts:  {"['full stomach', 'gaining weight', 'sick', 'satisfaction', 'feeling energized from variety', 'having an empty plate', 'feeling indifferent to food', 'experiencing instant gratification', 'feeling light after eating', 'noticing no change in appetite']"}
#
#
# ----------------------------------------
#
# --- Question 21 ---
#   Question: What does playing soccer for a long time lead to?
#
# Correct Facts:  {"['getting tired', 'increased muscle soreness', 'enhanced teamwork skills', 'improved cardiovascular endurance', 'developing strategic thinking']"}
# Incorrect Facts:  {"['excitement', 'fatigue', 'anger', 'hurting', 'immediate weight gain', 'decreased coordination', 'increased likelihood of boredom', 'immediate muscle growth', 'reduced overall stamina', 'permanent injury']"}
#
#
# ----------------------------------------
#
# --- Question 22 ---
#   Question: Which entrance would you use if you do not want to use the back entrance?
#
# Correct Facts:  {"['main', 'front', 'use the main door to enter the building', 'approach the front entrance for access', 'enter through the primary lobby entrance']"}
# Incorrect Facts:  {"['side', 'anterior', 'current', 'use the back entrance but only for deliveries', 'enter through a window to avoid the back entrance', 'take the service entrance for quicker access', 'use the basement entrance as a substitute', 'approach the side door as a shortcut', 'enter through the emergency exit for convenience']"}
#
#
# ----------------------------------------
#
# --- Question 23 ---
#   Question: You can share files with someone if you have a connection to a what?
#
# Correct Facts:  {"['computer network', 'internet connection', 'file-sharing protocol', 'peer-to-peer network', 'cloud storage service']"}
# Incorrect Facts:  {"['freeway', 'radio', 'wires', 'electrical circuit', 'telephone line without internet', 'USB drive without a computer', 'satellite dish without a receiver', 'printer connection without a network', 'television broadcast signal', 'power outlet']"}
#
#
# ----------------------------------------
#
# --- Question 24 ---
#   Question: The accelerator was controlled via a hand throttle, and the foot pedals controlled the steering in the small what?
#
# Correct Facts:  {"['airplane', 'glider', 'helicopter with foot-controlled cyclic', 'small drone with manual throttle', 'ultralight aircraft with hand controls']"}
# Incorrect Facts:  {"['car', 'fuel system', 'accelerate', 'boat', 'bicycle with hand brakes', 'motorcycle with foot pegs', 'hovercraft with joystick control', 'train with throttle and directional levers', 'scooter with handlebar acceleration', 'submarine with manual steering']"}
#
#
# ----------------------------------------
#
# --- Question 25 ---
#   Question: Sean was lying about the body, but he was very scared.  He constantly worried about what?
#
# Correct Facts:  {"['being found out', 'being exposed to the police', 'losing the trust of his friends', 'the consequences of his lies', 'the potential for blackmail']"}
# Incorrect Facts:  {"['the reward money', 'hurt feelings', 'problems', 'trouble', 'being late for work', 'missing a family event', 'the weather ruining his plans', 'not getting enough sleep']"}
#
#
# ----------------------------------------

# %%
print("\n" + "="*50)
print("    Test Designer Researcher  SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#     Test Designer Researcher  SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'diminish the impact of', 'undermine the credibility of', 'negate the progress achieved by', 'obscure the positive changes initiated by']"}
# Incorrect Facts:  {"['enforce', 'authoritarian', 'yell at', 'avoid', 'validate the changes made by', 'accelerate the transformation of', 'support the initiatives undertaken by', 'promote the reforms established by', 'encourage the new policies implemented by', 'enhance the reputation of']"}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'social events in the city', 'community gatherings at parks', 'festivals in urban centers', 'public transit hubs during rush hour']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'abandoned buildings on the outskirts', 'a remote cabin in the woods', 'a quiet library on a weekday', 'a private beach with no access', 'a closed amusement park', 'a secluded hiking trail']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'thrift shop for vintage finds', 'local artisan market for handmade accessories', 'online marketplace for secondhand jewelry', 'craft fair specializing in unique jewelry pieces']"}
# Incorrect Facts:  {'[\'neck\', \'jewelry box\', \'jewelry box\', \'boutique\', \'discount store with a jewelry section\', \'gift shop with a limited jewelry selection\', \'clothing store with an accessory aisle\', "friend\'s house who doesn\'t wear chokers", \'supermarket jewelry aisle\', \'flea market with no jewelry vendors\']'}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'road map', 'navigational charts', 'printed travel guides', 'manual route planning']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'digital photo albums', 'weather forecasting tools', 'satellite imagery', 'social media platforms', 'public transportation schedules', 'local business directories']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'food sources in the wild', 'shelter from urban predators', 'a mate for breeding', 'safe nesting grounds']"}
# Incorrect Facts:  {"['pretty flowers.', 'hen house', 'storybook', 'dense forest', 'a place to play fetch', 'a human companion', 'an open field for running', 'a picnic area', 'a tree for climbing', 'a spot for sunbathing']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'cable box for signal processing', 'streaming device with internet connection', 'satellite receiver for signal acquisition', 'video game console with online capabilities']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'wireless speaker system without a wired connection', 'smartphone using mobile data for streaming', 'bluetooth headphones for audio playback', 'digital photo frame displaying images from a USB drive', 'projector powered by battery without external inputs', 'desktop computer relying solely on Wi-Fi']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'traveling for a weekend getaway', 'attending a festival with supplies', 'heading to a sports event with gear', 'participating in a workshop with materials']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'heading to a business meeting without essentials', 'going to a concert but only carrying valuables', 'traveling to a remote area without necessary provisions', 'planning a picnic without food or blankets', 'visiting a museum without any personal items', 'attending a seminar without required documents']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'fridge', 'cooler with unsealed lid', 'pantry with improper ventilation', 'storage container left unopened', 'kitchen cabinet with no airflow']"}
# Incorrect Facts:  {'[\'carpet\', \'breadbox\', \'coach\', "oven that wasn\'t used", \'garage with no temperature control\', \'dining table left uncleaned\', \'bedroom closet with no food\', \'bathroom cabinet with no perishables\', \'living room shelf with decorative items\', \'laundry basket with clean clothes\']'}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'paper towel', 'absorbent cloth', 'sponge pad', 'tissue paper']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'ballpoint pen cap\', \'plastic bag\', \'sticky note\', \'water cup\', \'pencil eraser\', \'scotch tape\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'near corporate offices', 'within conference centers', 'adjacent to business hotels', 'in urban financial districts']"}
# Incorrect Facts:  {"['at a residential neighborhood', 'in a tourist attraction area', 'inside a shopping center', 'at a beach resort', 'in a rural farming community', 'within a university campus', 'in a local park', 'in an industrial area', 'at a gas station', 'in a remote mountain village']"}
#
#
# ----------------------------------------
#
# --- Question 11 ---
#   Question: Where do you put your grapes just before checking out?
#
# Correct Facts:  {"['grocery cart', 'shopping basket on the checkout counter', 'transfer grapes to a reusable bag for convenience', 'place grapes on the conveyor belt for scanning', 'set grapes aside in a designated area for checkout']"}
# Incorrect Facts:  {"['mouth', 'super market', 'fruit basket', 'fruit market', 'put grapes in the refrigerator to keep them fresh', 'leave grapes in the produce section to grab later', 'store grapes in a shopping bag on the floor', 'carry grapes in your hands while checking out', 'put grapes in a bag intended for non-perishables', 'drop grapes on the ground to make space in the cart']"}
#
#
# ----------------------------------------
#
# --- Question 12 ---
#   Question: Before getting a divorce, what did the wife feel who was doing all the work?
#
# Correct Facts:  {'[\'bitterness\', "resentment towards her partner\'s inaction", \'disappointment in unreciprocated efforts\', \'frustration from lack of appreciation\', \'exhaustion from carrying the emotional load\']'}
# Incorrect Facts:  {"['harder', 'anguish', 'tears', 'sadness', 'contentment from fulfilling her duties', 'satisfaction from being the responsible one', 'indifference due to acceptance of the situation', 'joy from the anticipation of freedom', 'relief from finally making a decision', 'confusion about her feelings towards her partner']"}
#
#
# ----------------------------------------
#
# --- Question 13 ---
#   Question: Johnny sat on a bench and relaxed after doing a lot of work on his hobby.  Where is he?
#
# Correct Facts:  {"['garden', 'park with a scenic view', 'near a pond watching ducks swim', 'under a tree enjoying the shade', 'by a flowerbed appreciating the blooms']"}
# Incorrect Facts:  {"['state park', 'bus depot', 'gym', 'rest area', 'inside a crowded mall with no benches', 'on a busy street waiting for a bus', 'in a workshop surrounded by tools', 'at a concert venue with loud music', 'in a library where silence is required', 'in a parking lot with no seating']"}
#
#
# ----------------------------------------
#
# --- Question 14 ---
#   Question: James was cooling off too quickly. He would die if he didn't find some way to stop what?
#
# Correct Facts:  {"['loss of heat', 'prevent further heat loss', 'insulate himself from cold air', 'increase ambient temperature around him', 'apply a controlled heat source']"}
# Incorrect Facts:  {"['revenge', 'expansion', 'relaxation', 'calm down', 'drink cold water to feel better', 'wear heavy clothing to trap heat', 'engage in vigorous exercise to warm up', 'sit in a cold room to acclimate', 'take a hot shower to reverse cooling', 'use ice packs to manage body temperature']"}
#
#
# ----------------------------------------
#
# --- Question 15 ---
#   Question: Of all the rooms in a house it was his favorite, the aromas always drew him to the what?
#
# Correct Facts:  {"['kitchen', 'the place where spices are blended', 'the area where meals are prepared with care', 'the room where baking fills the air with sweetness', 'the space where family recipes are lovingly cooked']"}
# Incorrect Facts:  {"['yard', 'basement', 'living room', 'garden', 'the room where laundry is done', 'the space filled with unused furniture', 'the area where tools are stored', 'the room where no cooking occurs', 'the space that smells of dust and neglect', 'the area where cleaning supplies are kept']"}
#
#
# ----------------------------------------
#
# --- Question 16 ---
#   Question: Bill is stuck in marsh when a man comes up to him peaking Cajun, where is he?
#
# Correct Facts:  {"['louisiana', 'swamp region of southern USA', 'engaged in fishing for local delicacies', 'searching for alligator habitats', 'exploring wetlands for wildlife']"}
# Incorrect Facts:  {"['low lands', 'new york', 'forest', 'everglades', 'trapped in a desert ecosystem', 'hiking through a mountainous terrain', 'lost in an urban park', 'wandering a snowy tundra', 'camping near a coastal beach', 'exploring a rocky cliffside']"}
#
#
# ----------------------------------------
#
# --- Question 17 ---
#   Question: What is it called when you slowly cook using a grill?
#
# Correct Facts:  {"['barbeque', 'smoke the meat over low heat', 'indirect grilling with wood chips', 'slow-cook using a smoking box', 'marinate and cook at a low temperature']"}
# Incorrect Facts:  {"['backyard', 'restaurant', 'crockpot', 'grilling at high temperatures', 'using a microwave for quick cooking', 'roasting in an oven', 'searing on a stovetop', 'boiling in water', 'frying in oil', 'using an air fryer']"}
#
#
# ----------------------------------------
#
# --- Question 18 ---
#   Question: What type of person typically contracts illness?
#
# Correct Facts:  {"['elderly person', 'immunocompromised individual', 'person with poor nutrition habits', 'individual exposed to high-stress environments', 'frequent traveler to regions with endemic diseases']"}
# Incorrect Facts:  {'[\'hospital\', \'head\', \'sick person\', "doctor\'s office", \'athlete with a strong immune system\', \'young adult with a balanced diet\', \'person practicing rigorous hygiene\', \'individual living in a low-stress environment\', \'healthy individual with regular exercise\', \'person who avoids crowded places\']'}
#
#
# ----------------------------------------
#
# --- Question 19 ---
#   Question: Where would you expect to find a pizzeria while shopping?
#
# Correct Facts:  {"['food court', 'shopping mall dining area', 'restaurant section of a plaza', 'near the entrance of a grocery store', 'within a large retail complex']"}
# Incorrect Facts:  {"['chicago', 'street', 'little italy', 'capital cities', 'inside a clothing store', 'at a gas station', 'on a rooftop terrace', 'in a residential neighborhood', 'next to a hardware store', 'at a public library']"}
#
#
# ----------------------------------------
#
# --- Question 20 ---
#   Question: When eating everything on the tasting menu, what does one tend to feel?
#
# Correct Facts:  {"['getting full', 'feeling satisfied after indulging', 'experiencing a sense of culinary adventure', 'noticing a gradual increase in fullness', 'recognizing a blend of flavors in each dish']"}
# Incorrect Facts:  {"['full stomach', 'gaining weight', 'sick', 'satisfaction', 'feeling energized from diverse nutrients', 'experiencing immediate regret from overeating', 'having a craving for more food afterward', 'feeling bloated despite enjoying the meal', 'believing one has overeaten but not feeling full', 'thinking about the next meal instead of enjoying the current one']"}
#
#
# ----------------------------------------
#
# --- Question 21 ---
#   Question: What does playing soccer for a long time lead to?
#
# Correct Facts:  {"['getting tired', 'experiencing muscle soreness', 'developing strategic awareness', 'enhancing teamwork skills', 'improving cardiovascular endurance']"}
# Incorrect Facts:  {"['excitement', 'fatigue', 'anger', 'hurting', 'gaining weight due to inactivity', 'immediately scoring more goals', 'having an increased attention span', 'sudden bursts of energy', 'improving memory retention', 'becoming overly competitive']"}
#
#
# ----------------------------------------
#
# --- Question 22 ---
#   Question: Which entrance would you use if you do not want to use the back entrance?
#
# Correct Facts:  {"['main', 'front', 'enter through the main lobby to access the primary hallway', 'take the side path leading to the main entrance for direct access', 'use the front door after navigating the main courtyard']"}
# Incorrect Facts:  {"['side', 'anterior', 'current', 'front', 'use the back entrance but claim to use the front', 'choose the side entrance despite its limited access', 'enter through the service door, which leads to restricted areas', 'attempt to enter through a window, which is not feasible', 'use the emergency exit, which is not designed for regular entry', 'try to access the building through the basement, which is locked']"}
#
#
# ----------------------------------------
#
# --- Question 23 ---
#   Question: You can share files with someone if you have a connection to a what?
#
# Correct Facts:  {"['computer network', 'internet service provider', 'secure file transfer protocol', 'peer-to-peer sharing application', 'cloud storage service']"}
# Incorrect Facts:  {"['freeway', 'radio', 'wires', 'electrical circuit', 'television broadcast signal', 'phone line without internet access', 'satellite dish without connection', 'USB drive without a compatible device', 'local power grid connection', 'public library without internet']"}
#
#
# ----------------------------------------
#
# --- Question 24 ---
#   Question: The accelerator was controlled via a hand throttle, and the foot pedals controlled the steering in the small what?
#
# Correct Facts:  {"['airplane', 'helicopter', 'glider', 'drone', 'ultralight aircraft']"}
# Incorrect Facts:  {"['car', 'fuel system', 'accelerate', 'boat', 'motorcycle with handlebars', 'train with fixed tracks', 'hovercraft with jet propulsion', 'bicycle with hand brakes', 'segway with balance controls', 'skateboard with foot steering']"}
#
#
# ----------------------------------------
#
# --- Question 25 ---
#   Question: Sean was lying about the body, but he was very scared.  He constantly worried about what?
#
# Correct Facts:  {"['being found out', 'the consequences of his lies', 'how to cover his tracks effectively', 'the potential for someone to discover evidence', 'the impact of his actions on his future']"}
# Incorrect Facts:  {"['the reward money', 'hurt feelings', 'problems', 'trouble', 'being blamed for unrelated incidents', 'the weather affecting his plans', 'people not believing his story', 'missing out on social events', 'the cost of legal fees', 'being judged for poor decisions']"}
#
#
# ----------------------------------------

# %%
print("\n" + "="*50)
print("    Test Designer Researcher (Word Limit|)  SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#     Test Designer Researcher (Word Limit|)  SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'dismiss', 'negate past progress', 'undermine future initiatives', 'overlook positive changes']"}
# Incorrect Facts:  {"['enforce', 'authoritarian', 'yell at', 'avoid', 'validate the efforts', 'support the changes', 'encourage further reform', 'acknowledge the improvements', 'promote the new policies', 'reward the school']"}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'crowded events', 'public transportation hubs', 'social gatherings', 'busy marketplaces']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'abandoned warehouse', 'isolated beach', 'quiet library', 'empty parking lot', 'remote cabin', 'desolate highway']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'craft fair vendor booth', 'online marketplace search', 'artisan jewelry exhibition', 'local thrift shop browsing']"}
# Incorrect Facts:  {"['neck', 'jewelry box', 'jewelry box', 'boutique', 'clothing store accessory section', 'gift shop random selection', 'home decor store', 'department store clearance rack', 'fashion magazine advertisement', 'gift registry listing']"}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'route planning software', 'real-time traffic analysis', 'turn-by-turn navigation systems', 'digital map applications']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'paperweight for desk', 'outdated road signs', 'travel brochures for hotels', 'historical geography texts', 'printed city directories', 'physical travel guides']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'food sources', 'shelter from predators', 'safe nesting area', 'water supply']"}
# Incorrect Facts:  {"['pretty flowers', 'hen house', 'storybook', 'dense forest', 'crowded picnic area', 'loud music', 'busy highway', 'brightly lit sign', 'open field', 'human company']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'streaming device connection', 'cable box installation', 'satellite receiver setup', 'home theater system wiring']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'wireless speaker pairing', 'battery-operated projector', 'digital photo frame usage', 'bluetooth soundbar connection', 'smartphone app control', 'gaming console without internet']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'train station', 'bus terminal', 'traveling to a conference', 'boarding a cruise ship', 'attending a music festival']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'going to a wedding', 'visiting a museum', 'heading to a gym', 'attending a cooking class', 'participating in a charity event', 'going to a theme park']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'fridge', 'cooler filled with ice', 'pantry with sealed containers', 'kitchen cabinet with expired items']"}
# Incorrect Facts:  {"['carpet', 'breadbox', 'coach', 'garage storage bin', 'dining table under a cloth', 'kitchen counter near the sink', 'closet with old clothes', 'bathroom cabinet', 'living room shelf', 'office drawer']"}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'paper towel', 'absorbent cloth', 'specialized ink sponge', 'absorbent pad']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'tissue paper\', \'plastic wrap\', \'notebook page\', \'sticky note\', \'dry erase board\', \'sandpaper\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'near corporate offices', 'adjacent to conference centers', 'within financial districts', 'close to transportation hubs']"}
# Incorrect Facts:  {"['town', 'at hotel', 'mall', 'yellow pages', 'in residential neighborhoods', 'within tourist attractions', 'inside amusement parks', 'near schools', 'on quiet streets', 'in remote areas']"}
#
#
# ----------------------------------------

# %%
print("\n" + "="*50)
print("    Test Designer Researcher (Word Limit|) + Strict Incorrect  SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#     Test Designer Researcher (Word Limit|) + Strict Incorrect  SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'overlook', 'diminish the value of', 'undermine the progress of', 'negate the benefits of']"}
# Incorrect Facts:  {"['enforce', 'authoritarian', 'yell at', 'avoid', 'validate past mistakes', 'accelerate future improvements', 'reinforce positive behavior', 'support ongoing initiatives', 'encourage community involvement', 'facilitate constructive dialogue']"}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'crowded events', 'social gatherings nearby', 'public transport hubs', 'community festivals']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'abandoned warehouse', 'isolated beach', 'quiet library', 'remote cabin', 'empty parking lot', 'deserted amusement park']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'online marketplace', 'custom jewelry designer', 'local artisan fair', 'vintage clothing shop']"}
# Incorrect Facts:  {"['neck', 'jewelry box', 'jewelry box', 'boutique', 'thrift store with limited selection', 'costume jewelry aisle', 'department store accessories section', 'chain retail outlet', 'general gift shop', 'online auction for unrelated items']"}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'printed road maps', 'route planning software', 'navigation chart systems', 'physical travel guides']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'interactive travel forums', 'satellite imagery services', 'local business directories', 'historical map collections', 'vehicle maintenance manuals', 'public transportation schedules']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'shelter from predators', 'food sources in the wild', 'a safe den for resting', 'territory to mark and claim']"}
# Incorrect Facts:  {"['pretty flowers.', 'hen house', 'storybook', 'dense forest', 'lively marketplace', 'sunbathing spot', 'urban garden', 'gathering of animals', 'abandoned building', 'busy highway']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'cable box', 'satellite receiver', 'streaming device with cable connectivity', 'home theater system needing wired connections']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'wireless speaker requiring no cables', 'portable gaming console without cable needs', 'smartphone streaming without external connections', 'projector using only wireless signals', 'digital photo frame needing no cable', 'Bluetooth headphones operating independently']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'traveling for a business meeting', 'attending a music festival', 'going to a family reunion', 'boarding a train for a vacation']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'attending a corporate workshop', 'visiting a museum exhibit', 'participating in a sports event', 'heading to a remote cabin', 'delivering supplies to a charity', 'checking into a hotel for a weekend']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'fridge', 'forgotten pantry shelf', 'sealed storage container', 'overstuffed cooler']"}
# Incorrect Facts:  {"['carpet', 'breadbox', 'coach', 'unsealed lunch bag', 'kitchen drawer', 'open cupboard', 'dining table', 'office desk', 'cluttered countertop', 'unused oven']"}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'sponge material', 'absorbent paper sheets', 'tissue for ink absorption', 'specialized ink-absorbing cloth']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'paper towel for ink spills\', \'canvas for painting\', \'napkin for quick clean-up\', \'fountain pen cap for storage\', \'plastic wrap for ink sealing\', \'pencil eraser for ink removal\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'near corporate offices', 'within financial districts', 'adjacent to conference centers', 'close to major transportation hubs']"}
# Incorrect Facts:  {"['town', 'at hotel', 'mall', 'yellow pages', 'in residential neighborhoods', 'on tourist beaches', 'within college campuses', 'in suburban areas', 'inside shopping centers', 'near entertainment venues']"}
#
#
# ----------------------------------------

# %%
print("\n" + "="*50)
print("    Test Designer Researcher (Word Limit|) + Strict Incorrect  SAMPLE GENERATED QUESTIONS")
print("="*50 + "\n")

for idx, row in df.iloc[:50].iterrows():
    print(f"--- Question {idx+1} ---")
    # print(f"  Logical Structure: {row.get('logical_structure')}")
    print(f"  Question: {row.get('question')}")

    print()
    print(f"Correct Facts: ",{row['expanded_correct_options']})
    print(f"Incorrect Facts: ",{row['expanded_incorrect_options']})   
    print()
    # # Print choices
    # choices = row.get('choices')
    # if isinstance(choices, str):
    #     print("  Choices:")
    #     print(choices)
    
    # print(f"  Correct Answer Label: {row.get('correct_answer_label')}")
    
    # Conditionally print the original hint if it exists
    if 'original_hint' in row and pd.notna(row['original_hint']):
        print(f"  Original Hint: {row['original_hint']}")

    print("\n" + "-"*40 + "\n")
# Out:
# ==================================================
#     Test Designer Researcher (Word Limit|) + Strict Incorrect  SAMPLE GENERATED QUESTIONS
# ==================================================
#
# --- Question 1 ---
#   Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#
# Correct Facts:  {"['ignore', 'overlook', 'diminish', 'undermine', 'negate']"}
# Incorrect Facts:  {"['enforce', 'authoritarian', 'yell at', 'avoid', 'validate', 'accelerate', 'support', 'reinforce', 'comply', 'motivate']"}
#
#
# ----------------------------------------
#
# --- Question 2 ---
#   Question: Sammy wanted to go to where the people were.  Where might he go?
#
# Correct Facts:  {"['populated areas', 'gathering events', 'social hubs', 'public transit stations', 'community festivals']"}
# Incorrect Facts:  {"['race track', 'the desert', 'apartment', 'roadblock', 'abandoned buildings', 'isolated beaches', 'remote cabins', 'quiet libraries', 'empty parking lots', 'uninhabited islands']"}
#
#
# ----------------------------------------
#
# --- Question 3 ---
#   Question: To locate a choker not located in a jewelry box or boutique where would you go?
#
# Correct Facts:  {"['jewelry store', 'artisan market', 'custom accessory workshop', 'vintage clothing shop', 'online auction platform']"}
# Incorrect Facts:  {"['neck', 'jewelry box', 'jewelry box', 'boutique', 'general department store', 'discount retailer', 'craft fair', 'online shopping site', 'gift shop', 'fashion warehouse']"}
#
#
# ----------------------------------------
#
# --- Question 4 ---
#   Question: Google Maps and other highway and street GPS services have replaced what?
#
# Correct Facts:  {"['atlas', 'manual navigation techniques', 'route planning software', 'printed travel guides', 'landmark-based navigation']"}
# Incorrect Facts:  {"['united states', 'mexico', 'countryside', 'oceans', 'historical maps', 'compass usage', 'roadside assistance services', 'physical road signs', 'public transport schedules', 'local knowledge databases']"}
#
#
# ----------------------------------------
#
# --- Question 5 ---
#   Question: The fox walked from the city into the forest, what was it looking for?
#
# Correct Facts:  {"['natural habitat', 'hunting grounds', 'shelter from predators', 'food sources in the underbrush', 'a mate during the breeding season']"}
# Incorrect Facts:  {"['pretty flowers.', 'hen house', 'storybook', 'dense forest', 'a picnic spot for humans', 'a safe place to play with other animals', 'a clear stream for swimming', 'an abandoned cabin for shelter', 'a garden filled with vegetables', 'a place to watch the sunset']"}
#
#
# ----------------------------------------
#
# --- Question 6 ---
#   Question: What home entertainment equipment requires cable?
#
# Correct Facts:  {"['television', 'streaming box connected via HDMI', 'cable box interfacing with multiple devices', 'sound system utilizing wired connections', 'projector linked through a cable network']"}
# Incorrect Facts:  {"['radio shack', 'substation', 'cabinet', 'desk', 'gaming console relying solely on Wi-Fi', 'smart speaker operating independently', 'television using only internal antennas', 'portable media player with no cables', 'bluetooth headphones functioning wirelessly', 'digital photo frame powered by solar energy']"}
#
#
# ----------------------------------------
#
# --- Question 7 ---
#   Question: The only baggage the woman checked was a drawstring bag, where was she heading with it?
#
# Correct Facts:  {"['airport', 'traveling to a festival', 'boarding a train for a weekend getaway', 'attending a sports event with essentials', 'heading to a conference with materials']"}
# Incorrect Facts:  {"['garbage can', 'military', 'jewelry store', 'safe', 'carrying items for a garage sale', 'delivering supplies to a construction site', 'transporting food to a picnic', 'taking belongings to a storage unit', 'bringing equipment for a photo shoot', 'moving items for a home renovation']"}
#
#
# ----------------------------------------
#
# --- Question 8 ---
#   Question: The forgotten leftovers had gotten quite old, he found it covered in mold in the back of his what?
#
# Correct Facts:  {"['refrigerator', 'fridge', 'sealed container', 'cooling unit', 'storage compartment']"}
# Incorrect Facts:  {"['carpet', 'breadbox', 'coach', 'shelf in the pantry', 'lunchbox left in the car', 'cooling bag used for picnics', 'drawer in the kitchen', 'oven that was turned off', 'basket in the living room', 'cabinet under the sink']"}
#
#
# ----------------------------------------
#
# --- Question 9 ---
#   Question: What do people use to absorb extra ink from a fountain pen?
#
# Correct Facts:  {"['blotter', 'sponge', 'absorbent paper', 'quick-dry cloth', 'tissue paper']"}
# Incorrect Facts:  {'[\'shirt pocket\', "calligrapher\'s hand", \'inkwell\', \'desk drawer\', \'paper towel\', \'felt tip marker\', \'watercolor brush\', \'plastic wrap\', \'sticky note\', \'pencil eraser\']'}
#
#
# ----------------------------------------
#
# --- Question 10 ---
#   Question: Where is a business restaurant likely to be located?
#
# Correct Facts:  {"['business sector', 'business district', 'near corporate offices', 'adjacent to conference centers', 'within a financial hub', 'close to major transportation routes']"}
# Incorrect Facts:  {"['town', 'at hotel', 'mall', 'yellow pages', 'in residential neighborhoods', 'within tourist attractions', 'near entertainment venues', 'inside community centers', 'at sporting event locations', 'in suburban areas']"}
#
#
# ----------------------------------------
#
# --- Question 11 ---
#   Question: Where do you put your grapes just before checking out?
#
# Correct Facts:  {"['grocery cart', 'newspaper bag', 'reusable shopping tote', 'produce section display', 'checkout conveyor belt']"}
# Incorrect Facts:  {'[\'mouth\', \'super market\', \'fruit basket\', \'fruit market\', \'shopping list pocket\', \'refrigerator drawer\', \'shopping cart handle\', \'countertop display\', \'plastic wrap roll\', "checkout assistant\'s hands"]'}
#
#
# ----------------------------------------
#
# --- Question 12 ---
#   Question: Before getting a divorce, what did the wife feel who was doing all the work?
#
# Correct Facts:  {"['bitterness', 'resentment', 'feeling trapped by obligations', 'exhaustion from constant effort', 'disillusionment with partnership']"}
# Incorrect Facts:  {"['harder', 'anguish', 'tears', 'sadness', 'confusion about feelings', 'contentment from familiarity', 'relief from expectations', 'indifference to outcomes', 'hope for reconciliation', 'satisfaction from responsibility']"}
#
#
# ----------------------------------------
#
# --- Question 13 ---
#   Question: Johnny sat on a bench and relaxed after doing a lot of work on his hobby.  Where is he?
#
# Correct Facts:  {"['garden', 'park', 'near a pond observing wildlife', 'under a tree enjoying the shade', 'on a trail after a long hike']"}
# Incorrect Facts:  {"['state park', 'bus depot', 'gym', 'rest area', 'shopping mall with no seating area', 'beach during peak sun hours', 'train station with constant announcements', 'stadium during a sports event', 'busy street corner with traffic', 'office building lobby with no outdoor access']"}
#
#
# ----------------------------------------
#
# --- Question 14 ---
#   Question: James was cooling off too quickly.  He would die if he didn't find some way to stop what?
#
# Correct Facts:  {"['loss of heat', 'excessive cooling', 'increased body temperature regulation', 'reduction of heat dissipation', 'restoration of thermal balance']"}
# Incorrect Facts:  {"['revenge', 'expansion', 'relaxation', 'calm down', 'increased perspiration rate', 'application of ice packs', 'consumption of cold beverages', 'wearing insulating clothing', 'avoiding physical activity', 'excessive sun exposure']"}
#
#
# ----------------------------------------
#
# --- Question 15 ---
#   Question: Of all the rooms in a house it was his favorite, the aromas always drew him to the what?
#
# Correct Facts:  {"['kitchen', 'pantry', 'oven where bread rises', 'stove simmering with spices', 'countertop covered in herbs']"}
# Incorrect Facts:  {"['yard', 'basement', 'living room', 'garden', 'storage room with old boxes', 'bathroom filled with cleaning supplies', 'garage with paint fumes', 'dining room set for a meal', 'bedroom with scented candles', 'hallway with fresh paint']"}
#
#
# ----------------------------------------
#
# --- Question 16 ---
#   Question: Bill is stuck in marsh when a man comes up to him peaking Cajun, where is he?
#
# Correct Facts:  {"['louisiana', 'bayou where Cajun culture thrives', 'wetlands with diverse wildlife', 'swamp region known for Cajun cuisine', 'area with rich Cajun heritage']"}
# Incorrect Facts:  {"['low lands', 'new york', 'forest', 'everglades', 'damp valley with similar flora', 'coastal region with marshy features', 'southern wetlands known for fishing', 'urban area near marshlands', 'tropical swamp with distinct fauna', 'river delta with Cajun influences']"}
#
#
# ----------------------------------------
#
# --- Question 17 ---
#   Question: What is it called when you slowly cook using a grill?
#
# Correct Facts:  {"['barbeque', 'smoking meats', 'indirect heat grilling', 'low and slow cooking', 'wood chip infusion']"}
# Incorrect Facts:  {'[\'backyard\', \'restaurant\', \'crockpot\', "neighbor\'s house", \'direct flame searing\', \'quick grilling\', \'flash roasting\', \'microwave grilling\', \'instant pot cooking\', \'charcoal ignition\']'}
#
#
# ----------------------------------------
#
# --- Question 18 ---
#   Question: What type of person typically contracts illness?
#
# Correct Facts:  {"['elderly person', 'individual with weakened immune system', 'person living in unsanitary conditions', 'individual who neglects preventive healthcare', 'person with chronic stress exposure']"}
# Incorrect Facts:  {'[\'hospital\', \'head\', \'sick person\', "doctor\'s office", \'individual exercising regularly\', \'person with balanced diet\', \'individual avoiding crowded places\', \'person with strong social support\', \'individual practicing good hygiene\', \'person living in a clean environment\']'}
#
#
# ----------------------------------------
#
# --- Question 19 ---
#   Question: Where would you expect to find a pizzeria while shopping?
#
# Correct Facts:  {"['food court', 'mall atrium dining area', 'restaurant row adjacent to retail stores', 'food truck park near shopping district', 'grocery store prepared food section']"}
# Incorrect Facts:  {"['chicago', 'street', 'little italy', 'capital cities', 'downtown office building cafeteria', 'suburban residential neighborhood', 'airport terminal lounge', 'highway rest stop', 'university campus dining hall', 'historic town square']"}
#
#
# ----------------------------------------
#
# --- Question 20 ---
#   Question: When eating everything on the tasting menu, what does one tend to feel?
#
# Correct Facts:  {"['getting full', 'experiencing culinary overload', 'savoring complex flavors progressively', 'navigating varied textures throughout', 'developing an appreciation for diverse cuisines']"}
# Incorrect Facts:  {"['full stomach', 'gaining weight', 'sick', 'satisfaction', 'feeling energized from the meal', 'experiencing rapid digestion', 'overwhelmed by portion sizes', 'achieving a balanced diet', 'feeling hungry after tasting', 'suffering from food intolerance']"}
#
#
# ----------------------------------------
